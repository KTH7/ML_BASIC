# %%
from konlpy.tag import Komoran
tagger = Komoran()  # 형태소 분석기
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
import requests
import lxml.html
import codecs

#투캅스 시나리오 읽어오기
#이 시나리오 데이터는 제공되어질수 없으며 배포가 불가능하오니 
#http://www.korean.go.kr(국립국어원)에서 회원가입을 하시고 다운을 받아주세요. 
articles = []
fp = codecs.open("투캅스.txt", "r", encoding="utf-8")
soup = BeautifulSoup(fp, "html.parser")
body = soup.select_one("body")
text = body.getText()
articles = text.split("\n")
len(articles)
fp.close()

from sklearn.feature_extraction.text import TfidfVectorizer

#명사만 추출
def get_noun(text):
    nouns = tagger.nouns(text)
    return [n for n in nouns if len(n) > 1]  # 2글자 이상인 명사만 추출

#TF-IDF 행렬구하기
cv = TfidfVectorizer(tokenizer=get_noun, max_features=100)
tdm = cv.fit_transform(articles)

#print(tdm.toarray())
#print(tdm) 

import numpy
import operator
words = cv.get_feature_names()
count_mat = tdm.sum(axis=0)
count = numpy.squeeze(numpy.asarray(count_mat))
word_count = list(zip(words, count))
word_count = sorted(word_count, key=operator.itemgetter(1), reverse=True)
word_count

hot_key = list(dict(word_count[:50]).keys())
hot_key
# Out:
# c:\Users\taehwan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['형사',
#  '장갑',
#  '목장갑',
#  '여자',
#  '경찰',
#  '유괴',
#  '소리',
#  '과장',
#  '사람',
#  '모습',
#  '사장',
#  '순간',
#  '고개',
#  '여미',
#  '투캅스',
#  '강사',
#  '꼴통',
#  '최형',
#  '아버지',
#  '정보원',
#  '경찰서',
#  '회장',
#  '아줌마',
#  '두목',
#  '강도',
#  '아이',
#  '엄마',
#  '가위',
#  '제가',
#  '표정',
#  '사가',
#  '운전',
#  '트레일러',
#  '주먹',
#  '가방',
#  '보스',
#  '서장',
#  '남자',
#  '머리',
#  '반장',
#  '커트',
#  '도굴',
#  '오늘',
#  '얼굴',
#  '인상',
#  '아가리',
#  '어깨',
#  '자식',
#  '이때',
#  '당장']

# %%
word_count
# Out:
# [('형사', 621.8683337405181),
#  ('장갑', 68.8162429389024),
#  ('목장갑', 59.63563524635117),
#  ('여자', 48.27246462792797),
#  ('경찰', 48.14633295692247),
#  ('유괴', 47.476164007832),
#  ('소리', 39.991866218563565),
#  ('과장', 38.02849076335772),
#  ('사람', 34.60412382028107),
#  ('모습', 29.819782157831526),
#  ('사장', 29.216679207432808),
#  ('순간', 24.17791194371099),
#  ('고개', 23.934035654484987),
#  ('여미', 23.223880067130434),
#  ('투캅스', 22.550931517614416),
#  ('강사', 22.36350927677548),
#  ('꼴통', 21.967344101378487),
#  ('최형', 21.50334486164969),
#  ('아버지', 20.334664345791907),
#  ('정보원', 19.97864804852923),
#  ('경찰서', 19.274771656057414),
#  ('회장', 18.914539947042392),
#  ('아줌마', 18.680949299678083),
#  ('두목', 17.529581121905753),
#  ('강도', 17.212276366567632),
#  ('아이', 16.528250260134453),
#  ('엄마', 15.087176882527974),
#  ('가위', 15.081553959563037),
#  ('제가', 14.257037438843106),
#  ('표정', 14.145499669254967),
#  ('사가', 13.878326455140675),
#  ('운전', 13.722274442926064),
#  ('트레일러', 13.238103389149206),
#  ('주먹', 13.168895661706696),
#  ('가방', 13.122418612670955),
#  ('보스', 12.943740717430357),
#  ('서장', 12.817823306363412),
#  ('남자', 12.587840458888978),
#  ('머리', 12.35198877736489),
#  ('반장', 11.992332141166223),
#  ('커트', 11.888564468233215),
#  ('도굴', 11.803994318939202),
#  ('오늘', 11.567273214801416),
#  ('얼굴', 11.440447199018106),
#  ('인상', 11.424392133807592),
#  ('아가리', 11.374781972185612),
#  ('어깨', 11.183729858712221),
#  ('자식', 10.633468590296683),
#  ('이때', 10.628674470076929),
#  ('당장', 10.39302241766637),
#  ('바닥', 9.964640615481017),
#  ('중국', 9.826357468290869),
#  ('말로', 9.72530334148733),
#  ('골목', 9.051638565606986),
#  ('때문', 8.998853944447278),
#  ('이번', 8.85624921737284),
#  ('거리', 8.831613332797183),
#  ('건물', 8.776470622409398),
#  ('도로', 8.618229947978952),
#  ('아니', 8.612369882964096),
#  ('형님', 8.321937975503188),
#  ('시체', 8.24071921226406),
#  ('차림', 8.152288682252935),
#  ('공격', 8.055841139827487),
#  ('아래', 8.049108056066911),
#  ('사와', 7.981428004836542),
#  ('생각', 7.821734732191371),
#  ('미용실', 7.765608839652472),
#  ('침대', 7.7312722446229465),
#  ('운동', 7.682278226248688),
#  ('남편', 7.602993316782622),
#  ('금고', 7.551283331936734),
#  ('전경', 7.423576118491537),
#  ('비명', 7.286662894693581),
#  ('박수', 7.262301231656629),
#  ('용의자', 7.252935190387518),
#  ('부하', 6.988949352474171),
#  ('양복', 6.9249840794838),
#  ('새끼', 6.890184323682842),
#  ('아저씨', 6.816240683587883),
#  ('건달', 6.7815754898798986),
#  ('화면', 6.671973298063512),
#  ('멱살', 6.665775293333057),
#  ('운전수', 6.612904785901789),
#  ('이익', 6.517056290785322),
#  ('박스', 6.2848531877846625),
#  ('난간', 6.274348004858958),
#  ('창문', 6.270814034516991),
#  ('박찬호', 6.244224068826345),
#  ('사이', 6.1648164521983),
#  ('주변', 6.107855807954204),
#  ('고함', 5.986646110772965),
#  ('마약', 5.863514868199333),
#  ('미소', 5.847459364595851),
#  ('수갑', 5.834838690290022),
#  ('서로', 5.811646480624326),
#  ('동시', 5.711355066152029),
#  ('신음', 5.36222684306878),
#  ('뒷편', 4.945064479003425),
#  ('박살', 3.5594466165027354)]

# %%
#word cloud
# %matplotlib inline
from matplotlib import pyplot
from wordcloud import WordCloud
wc = WordCloud(font_path='C:\\Windows\\Fonts\\NGULIM.ttf', background_color='white', width=400, height=300)
cloud = wc.fit_words(dict(word_count))
pyplot.figure(figsize=(12, 9))
pyplot.imshow(cloud)
pyplot.axis("off")
pyplot.show()

# %%
#형태소 분석기 라이브러리 로딩
import codecs
from konlpy.tag import Twitter
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# 텍스트를 처리하기
twitter = Twitter()
results = []
lines = articles
words_all = []

for line in lines:
    # 형태소 분석하기
    malist = twitter.pos(line, norm=True, stem=True)
    r = []
    for word in malist:
        # 명사/동사/부사만 걸러내기 
        if word[1] in ['Noun','Verb','Adjective']:
            r.append(word[0])
            words_all.append(word[0])
    rl = (" ".join(r)).strip()
    results.append(rl)
    #print(rl)
    
# 파일로 저장하기
from gensim.models import word2vec
yang_file = 'yang.model'
with open(yang_file, 'w', encoding='utf-8') as fp2:
    fp2.write("\n".join(results))
    
fp2.close() 

# Word2Vec 모델
data = word2vec.LineSentence(yang_file)
model = word2vec.Word2Vec(data,vector_size=200, window=10, hs=1, min_count=2, sg=1)
model.save("yang_w2v.model")

# %%
model

# %%
results
# Out:
# ['',
#  '씬 달리다 버스 안',
#  '타이틀 끝나다 되다',
#  '경쾌하다 달려오다 서다 시내버스',
#  '치익 소리 문 열리다 기다리다 있다 사람 올라타다',
#  '버스 카드 현금 함 앞 오가다 손 바라보다',
#  '운전 수 그냥 지나치다 사람 발견 곤 아저씨 차비 내다',
#  '하다 운전 수가 노려보다 가방 메다 지나치다 가다가 뒤 돌아보다 꼴통 특유 인상 긁다 들다 볼펜 울다 내미다 시선 피하 차 출발 시키다 운전 수 꼴통 버스 가운데 서서 가방 털썩 내려놓다 볼펜 자루 치켜들다',
#  '꼴통 뒤뚱뒤뚱 인사 하다 차 안 계시다 신사 숙녀 여러분 안녕하십니까 저 홧김 폭력 겁 유괴 불타다 가슴 강간 등 전과 이범 얼마 전 추다 소한 대책 없다 어리다 양 이다 시선 피 승객 볼펜 자루 올려놓다 아프다 과거 잊다 꼬 딱지 포장마차 장만 하다 하니 액땜 하다 생각 하다 가볍다 지갑 열다 바라다 여러분 가정 불행 없다 간절하다 소망 하다 볼펜 들다 보이 이 볼펜 단돈 삼천원 드리다 감사하다',
#  '인사 돈 거둬들이다 돌아다니다 꼴통 험악하다 인상 써다 보이 순순하다 돈 주다 아가씨 깐깐하다 보이다 남자 볼펜 돌려주다',
#  '꼴통 난 열 받다 입 주먹 먼저 나가다 놓다',
#  '하다 사내 앞 주먹 내미다 얼른 지갑 돈 꺼내다 주다 사내 이번 꾸벅 꾸벅 졸다 있다 고등학생 다가가다',
#  '꼴통 툭툭',
#  '깨지다 않다 통수 퍽퍽치',
#  '꼴통 임마 자다 척 하다',
#  '학생 왜 그렇다',
#  '꼴통 삼천원 내',
#  '학생 왜',
#  '꼴통 라면 내 안내',
#  '고등학생 돈 꺼내다 다음 넘어가다 꼴통 아이 안고 창밖 보다 척 하다 아줌마 보다 아이 머리 쓰다듬다',
#  '꼴통 귀엽다',
#  '아줌마 돌아보다',
#  '꼴통 저 겁 유괴 를 두 번 하다 죽이다 놓다',
#  '하다 이번 겁 먹다 아이 볼 살짝 꼬집다 아줌마 얼른 손 쥐 있다 돈 주다 아이 끌어안다 꼴통 몇몇 사람 순순하다 돈 받다 자리 향 하다 버스 안 일어나다 사태 전혀 의식 하다 못 채 귀 이어폰 끼 창 밖 보다 뭔가 메모 있다 하다 여자 앞 다가서다 꼴통 다짜고짜 그녀 어깨 손 올려놓다 특유 인상 긁다 깜짝 놀라다 돌아보다 기다 생머리 시원스럽다 얼굴 여자 바로 이 영화 신임 형사 최 형사',
#  '꼴통 나 강간 도 하다 여자 머리카락 배배 꼬 세 번 하다',
#  '어이 없다 쳐다보다 최 형사 겁 먹다 줄 알 핸드백 자기 손 열다 돈 꺼내다 수갑 권총 발견 곤 굳어지다 꼴통 상대 이다 지라 표정 다시 정리 하다',
#  '꼴통 너 경찰 자다 만나다 난 경찰 라면 이 갈리다 놈',
#  '순간 턱 쪼인트 맞다 꼴통 신음 고개 치켜들다',
#  '꼴통 어쭈 치다 이 내 알',
#  '말 끝나다 전 곧장 날아오다 최 사의 주먹 퍽 뒤 나자빠지다',
#  '꼴통 코피 쓰윽 닦다 질겁 곤 일어나며 피다 이 씨 웃통 벗다 끼어들다 놈 있다 죽이다 버리다',
#  '겁 질리다 피하 사람',
#  '꼴통 버스 머리 받다 씨발 사고 치기 싫다 내 인생 왜 꼬이다 휙 손가락 가리키다 것 니 잘못',
#  '하다 최 형사 향 하다 저돌 돌진 하다 꼴통 달려오다 꼴통 멋지다 업다 받다 넘기다 최 형사 버스 바닥 찌그러지다 정도 떨어지다 꼴통 꼴통 자신 패 인정 곤 최 형사 향 하다 손 모으다 빌다',
#  '꼴통 제 흥분 하다',
#  '최 형사 표정 변하다 않다 채 뚜둑 뚜둑 몸 풀다 다가서다',
#  '꼴통 휘둥그레지다 아니다 왜 이르다 잘못 하다',
#  '최 형사 멱살 잡다 일으키다 세우다 안 끝나다',
#  '씬 거리',
#  '달리다 버스 과장 들려오다 꼴통 비명 소리 퍽 퍽 우두둑 맞다 소리 좌우 요동치다 버스 우지끈 어딘가 부러지다 듯 소리 끼 이익 멈추다 서다 버스 위로 덥다 타이틀 투캅스',
#  '씬 집 거실',
#  '자막 사라지다 선행 하다 초인종 소리 속',
#  '화면 가득 현관문 반투명 유리 남자 형체 보이다 속 끼 리릭 끼 리릭 소리 고리 탁 하다 위로 젖히다 스르르 열리다 문 들어오다 구두 카메라 틸업하 손 목 장갑 끼다 사내 열다 있다 문 장갑 끼다 사내 쌕 맨 채 들어오다',
#  '장갑 날카롭다 눈매 고개 휙 저으 빠르다 움직이다 목 장갑 방문 어보 다가 방 앞 장갑 보다 고개 끄덕이다 곳 걸어가다 장갑',
#  '씬 방안',
#  '금고 청진기 대다 채 번호판 돌리다 있다 장갑 뒤 각종 그림 도자기 등 널린 방 서랍 따위 뒤지다 있다 목 장갑 천원 짜다 몇 장 은장도 씨거 엽전 등 쌕 넣다 장갑 눈치 보다 몰래 천원 짜다 리 주머니 챙기다 기도 하다 목 장갑',
#  '장갑 청진기 대다 채 하다 껀 하다 돈 함부로 쓰다 마르다 상법 왜 잡히다 아 돈 생기다 친구 데리 룸싸롱 쭉쭉 빵빵 죽이다 년 끼 술 졸다 퍼마셨 이 친구 란 새끼 아침 해장국 먹다 갑자기 이렇다 생각 들다 자기 어제 하다 번 얻어먹다 저 새 끼다 그렇다 데 처 먹다 끄다 생각 하다 열 받다 씨발 경찰 수상한 놈 있다 찌르다 잡히다 절대 친하다 놈 돈 쓰다 마르다 알다',
#  '목 장갑 예',
#  '장갑 보다 꼬불치다 생각 하다 마르다 나중 죽다',
#  '목 장갑 주머니 돈 꺼내다 예',
#  '하다 다시 천원 지폐 꺼내다 쌕 안 밀다 놓다 딸칵 소리 미소 지다 금고 손잡이 잡다 여 장갑 목 장갑 뒤 다가오다 장갑 미소 지은 채 금고 열다 잉 표정 확 변하다',
#  '뒤 어어 고개 들이다 밉다 목 장갑 표정 확 굳다 보다 열리다 문 안 금고 하나 더 보이다',
#  '목 장갑 씨발 이 새끼 금고 사하나',
#  '장갑 아니다 도굴',
#  '목 장갑 예 그게 뭡',
#  '장갑 몰래 남 무덤 졸다 파서 골동품 챙기다 팔 먹다 놈',
#  '목 장갑 한마디 벼락 맞다 새끼 들이다',
#  '장갑 자 방출 간걸 보다 또 어떻다 놈 무덤 졸다 파고 있다',
#  '씬 밖',
#  '끼 이익 멈추다 봉고 박스 등 들다 내리다 도굴 꾼 제법 크다 집의 대문 열다 짐 들다 조심 스레 안 들어가다 속 그 뒤 멈추다 서다 차 열리다 차문 내리다 누군가 발 틸업하 바로 우리 형사 도굴 꾼 보다 빠르다 다가가다',
#  '씬 안',
#  '다시 청진기 대고 있다 장갑 뒤 시계 보고 있다 목 장갑',
#  '목 장갑 형님 안 금고 하나 더 있다 게 하자 휙 보다 장갑 목 장갑 머리 배 따위 마구 팬',
#  '장갑 재수없다 소리 하다 임마 안 금고 또 있다 너 죽다 알',
#  '금고 문 여 순간 또 다른 금고 있다',
#  '장갑 목 장갑 팰 듯이 가다 리 새꺄',
#  '하다 순간 현관문 열리다 소리 들리다 표정 굳다 장갑 목 장갑 쪽 바라보다',
#  '씬 거실',
#  '문 열다 들어오다 도굴 뒤 돌아보다',
#  '도굴 조심하다 얼마 짜다 린 줄 알',
#  '무겁다 듯 박스 등 들다 들어오다 도굴 의 모습 속 들리다',
#  '소리 이형 사의 꼼작마 경찰',
#  '휙 뒤 돌아보다 도굴 꾼 인상 확 변하다 어느새다 안 뛰어들다 형사 박스 던지다 피하 형사 뒤 벽 맞다 깨지다 도자기 도굴 형사 향 하다 칼 호미 삽 따위 휘두르다 공격 해보다 뒷걸음질 치다 도굴 편의 방 도망가다',
#  '씬 방안',
#  '문 열다 들어오다 도굴 창문 뛰어넘다 도망가다 장갑 목 장갑 보다',
#  '도굴 너희 뭐',
#  '곧장 목 도망가다 창문 뛰어나가다 들어오다 형사 창문 뒤 쫒다 간다',
#  '형사 거기',
#  '씬 골목',
#  '쫓아가다 형사 앞 도굴 이 달리 그 앞 도망가다 있다 장갑 목 장갑 쫓아가다 카메라',
#  '형사 달려오다 거기',
#  '도굴 도망가다 앞 보고 이 도둑 놈 새끼 감히 누구 집 털다',
#  '목 장갑 뒤 돌아보다 훔치다 하다 임마',
#  '장갑 뒤 돌아보다 새꺄 자꾸 우리 따라오다 따다 데 가다',
#  '다시 뒤따르다 도굴 형사 보여주다 카메라',
#  '도굴 형사 뒤 돌아보다 저 새끼 도둑 놓다',
#  '형사 일단 너 잡다',
#  '장갑 길 하다 켜다 놓이다 휴지통 옆 밀 뛰다 피 하다 도굴 이 몸 틀다 사이 뒤 점프 해오다 형사 도굴 덥다 뒹',
#  '형사 잡히다 도굴 보다 씨익 미소 지은 채 도망가다 목 장갑 옆 스치다 지나가다 차갑다 도굴 수갑 채우다 형사 앞 끼 이익 멈추다 빵빵 클락 션 울리다 대다 차안 자운 전수 짜증 스레 대의 자운 전수 바라보다 형사 도굴',
#  '씬 경찰서 사무실',
#  '수갑 찬 도굴 꾼 툭툭 치 들어오다 형사 다른 경찰 도굴 꾼 유치장 쪽 인계 하다',
#  '형사 또 한껀했 하루 그냥 넘어가다 날 없다',
#  '형사 예 써다 빈 자리 보다 오다 첫날 자각',
#  '형사 신참 차갑다 막히다 보지 차다 자네 파트너 이야기 들다',
#  '형사 아뇨',
#  '때 엉망 몰골 수갑 찬 채 뛰어들다 꼴통 정신 없다 곳 곳 살피',
#  '꼴통 악 사람 살리다',
#  '경찰 꼴통 보다 저 자식 볼때 인상 더러워지다',
#  '꼴통 다가오다 선 형사 제발 살리다',
#  '형사 가석방 되다 몇 일 돼다 또 들어오다',
#  '꼴통 울먹이다 제발 살리다 줄다 완전하다 마녀',
#  '하다 순간 뒤 다가오다 꼴통 뒷덜미 잡다 최 형사',
#  '최 형사 리',
#  '꼴통 울먹이다 최 형사 후다닥 뛰어가다',
#  '형사 누구 입',
#  '형사 모르다 자네 새롭다 파트너 잖다',
#  '형사 예',
#  '다른 경찰 꼴통 넘기다 최 사의 늘씬하다 다리 얼굴 쭈욱 훑다 보고 불만 가득하다 표정 바뀌다 속',
#  '형사 최 형사 보다 자다 빠지다 몇 일 버티다',
#  '형사 형사 보다 만원 꺼내다 일주일 형사 어디가',
#  '형사 일어나다 가다 과장 계시다',
#  '형사 응 만원 꺼내다 내일',
#  '씬 과장 실',
#  '화면 가득 책상 위로 내미다 희다 봉투 집다 들다 과장 맞다 편 서다 형사 보다',
#  '과장 이 뭐',
#  '형사 파트너 바꾸다 시오 아니다 사표 내다',
#  '과장 뭐',
#  '형사 요즘 강력 사건 얼마나 발생 하다 여자 붙이다 어떡하다',
#  '과장 임마 이번 경찰 학교 수석 졸업 하다',
#  '형사 요즘 수석 아무나 하나 보다',
#  '과장 여자 울다 보지 앞 자다 해보다',
#  '형사 안되다 수사 하다 갑자기 사랑 때문 질질 짜다 중요하다 놈 체포 하다 순간 생리 하다 어떡하다 당장 바꾸다 시오',
#  '과장 이 자식 싸움 하다 보다 주다 알다',
#  '형사 예 정말 두다 요',
#  '과장 수리 하다 임마 짜다 식이 건방지다 인사 참견 하다 당장 나가다 임마',
#  '형사 과장',
#  '과장 밀치다 관 두다 관 두다 임마 나가다 짐 싸다 어서',
#  '씬 달리다 차 안',
#  '운전 하다 형사 그 옆 창밖 보다 최 형사',
#  '형사 화난 듯 경찰 학교 수석 졸업 정말',
#  '최 형사 예 선배 세운 기록 깨다',
#  '형사 그렇다 다시 한번 보다 대책 인심 좋아지다 경찰 학교 왜 가다 조용하다 시집 가지',
#  '최 형사 휙 보다 선배 제 온 게 불만 입',
#  '형사 보다 자넬 위해 하다 소리 이다 자고로 남편 사랑 받다 집안 일이 하다 게 최고 그렇다',
#  '최 형사 노려보다 항상 여자 무시 합',
#  '형사 경찰 이란 사기꾼 강간범 도둑 놈 깡패 같다 놈 더럽다 꼴 보다 여차하면 놈 휘두르다 쇠 파이프 뼈 부러지다 칼 찔리다 무식하다 놈 도끼 들다 설치다 대서 병신 되다 쉬다 상이 사랑 결혼 같다 건 꿈 꾸다',
#  '최 형사 알 있다',
#  '형사 그렇다 그렇다 당장 그만두다 뭐 하다 구 해',
#  '최 형사 수 없다 팔자',
#  '형사 뭐',
#  '최 형사 타고나다 운명 고요 태몽 용하다 점 들다 모두 제 사회 악 처단 하다 강직 전사 같다 삶 살다 랬',
#  '형사 태몽',
#  '최 형사 하다 손 불과 다른 손 칼 쥐 있다 대요',
#  '형사 불과 칼 그렇다 주방 아니다',
#  '최 형사 경멸 듯 바라보다',
#  '최 형사 형사 서로 바라보다 형사 편 소매치기 아줌마 지갑 낚아채다 도망가다 모습 보이다',
#  '최 형사 차 세우다',
#  '하다 끼 이익 선행 하다 브레이크 소리',
#  '씬 장통',
#  '핸드백 쥐다 채 빠르다 도망가다 놈 쫓아가다 최 형사',
#  '최 형사 거기',
#  '사람 부닥치다 도망가다 놈 거의 잡기 직전 놈 밀치다 아이 피 하다 다른 곳 부닥치다 넘어지다 최 형사 멀어지다 놈 여유 띤 미소 짓다 불쑥 나타나다 누군가 발 걸리다 넘어지다 말다 넘어지다 놈 뒷덜미 낚아채다 형사',
#  '형사 일어나다 최 형사 다가가다 역시 여자 별 수 없다 범인 체포 기본 달리기 뛰다 누굴 잡다',
#  '하다 여유 부리다 눈치 보다 놈 이형 사의 팔 치다 다시 도망가다 순간 몸 날리다 최 형사 놈 덥다 넘어뜨리다 뒤 핸드백 감다 쥐다 놈 손목 잡다 우두둑 꺽 버리다 비명 지르다 놈 놀란 듯 바라보다 형사',
#  '최 형사 수갑 채우다 이렇다 놈 잠시 방심하다 안되다 다음 주의 하다',
#  '하다 놈 끄다 최 형사 뻥 찌다 바라보다 형사',
#  '씬 햄버거 집 안',
#  '햄버거 가져오다 앉다 형사 맞다 편 있다 최 형사',
#  '형사 팔 부러 뜨릴 필요 없다',
#  '최 형사 눈 눈 이 이 나쁘다 짓 하다 놈 다시다 그 짓 못 하다 만들다 놓다 범죄 재발 막 수 있다',
#  '형사 햄버거 먹다',
#  '최 형사 햄버거 안 있다 고기 치즈 등 빼다 도둑질 하다 놈 손가락 부러 뜨다 리 공갈 협박 놈 다시다 입 못 놀리다 하다 거',
#  '형사 그렇다 강간 놈',
#  '최 형사 거길 자르다 버리다',
#  '형사 말 하다 뭐 하다 다이어트 하나 여자 안되다 먹다 운동 하다 생각 하다 먹다 운동 하다 비실 비실 하다 정말 한심하다',
#  '최 형사 저 보이다',
#  '형사 먹다 응',
#  '씬 곳',
#  '멈추다 서다 차 내리다 형사 최 형사',
#  '형사 관내 발생 연쇄 강도 범 목숨 아깝다 줄 모르다 살벌하다 놈',
#  '최 형사 요청 하다',
#  '형사 손가락 두둑 거리 혼자 몸 풀기 모자라 어깨 짚다 위험하다 최 형사 안 콜라 마시다 김 빠지다 전 돌아오다',
#  '씩씩하다 건물 쪽 들어가다 형사 바라보다 최 형사',
#  '씬 마약 아지트 안',
#  '꽝 문 박차다 들어오다 형사 보고 놀라다 마약상',
#  '마약상 튀어',
#  '이 동시 역 적 보이다 가방 들다 튀다 마약상 뒤 칼 쇠 파이프 따위 쥐다 채 도망가다 마약상 쫓아오다 형사 보다 마약상 가다 형사 칼 쇠 파이프 따위 휘두르다 공격 해보다 이형 사의 화려하다 액션 나가떨어지다 형사 마약상 이 나가다 뒷문 뒤 쫓다 간다',
#  '씬 밖',
#  '문 열다 나오다 형사 작다 골목 꺽 들어가다 마약상 의 뒤 쫓다 달려가다 달리다 이형 사의 모습 위로 들리다 꺄악 하다 여자 비명 소리 퍽 쾅 하다 소리 아차 하다 생각 들다 형사',
#  '형사 가만있다 이렇다 멍청하다',
#  '하다 총 꺼내다 달려가다 형사',
#  '씬 다른 골목',
#  '총 빼다 채 달려오다 형사',
#  '형사 꼼짝 마',
#  '하다 둘러보다 하다 여자 겁 질린다 채 웅크리다 있다 옆 놈 널 부러지다 있다 최 형사 하다 놈 수갑 채우다 있다',
#  '최 형사 비실 비다 보이다',
#  '형사 제법 하다 죽다 노력 하다 하다 뒤 내 수준 근처 오다',
#  '최 형사 선배 제 오기 전 제법 말 들다',
#  '형사 호 좋다 자신감 대단하다 어디 하다 번 제대로 해보다',
#  '최 형사 처단 하다 하다 놈 있다 곳 라면 어디 요',
#  '형사 좋다 렛츠 고',
#  '최 형사 오케이',
#  '씬 거리',
#  '경쾌하다 음악 속 화려하다 밤 거리 씩씩하다 걸어가다 투캅스 호객 행위 하다 삐끼 형사 보고 숨기 하다 중년 사람 사장 들이다 반갑다 인사 건네다 덩치 서로 패싸움 하다 듯 각목 철봉 체인 등 들다 숨기 쩔쩔매다 표정 도로 인사 하다 하다 이렇다 사람 보다 고개 끄덕 지나가다 형사 어이없다 표정 보다 최 형사',
#  '최 형사 경찰 하다 전 깡패 이다',
#  '형사 이렇다 최 형사 인상 쓸다 채 쳐다보다',
#  '씬 나이트 클럽 안',
#  '터지다 나오다 음악 휘황 찬란하다 돌아가다 조명 속 춤추다 사람 너머 보이다 투캅스',
#  '형사 유리 되다 룸 안 보이다 많다 건달 가운데 있다 험악하다 생기다 명 가리키다',
#  '형사 김 한철 폭력 전과 범 수배 혼자 잡 수 있다',
#  '최 형사 맥주 말다 김 빠지다 전 잡다 오다',
#  '하다 씩씩하다 걸어가다 점점 가까워지다 룸 안 모습 보다 미니스커트 끼 십 여명 우락부락하다 건달 술 말다 그 앞 웨이터 명 완전 쫄아 도 절 해대 있다 최 형사 긴장 듯 심호흡 하다 모습 뒤 저 편 형사 쪼개다 바라보다 있다 몸 두둑 룸 걸어가다 최 형사 때 룸 나오다 웨이터 다짜고짜 최 사의 팔 잡다',
#  '웨이터 아가씨 나 좀 살리다',
#  '최 형사 왜 이다',
#  '웨이터 제발 살리다 부킹 한번 해 부킹 부킹',
#  '최 형사',
#  '최 사의 팔 잡고 룸 안 데리 들어가다 웨이터 최 형사 룸 밀다 빠지다 나오다 안도 한숨 쉬다 건달 최 형사 보다 고개 끄덕 하다 어깨 손 올리다 휘 쳐다보다 최 형사',
#  '건달 덥다 썩 최 형사 안다 순간 빠르다 올라가다 최 사의 무릎 곳 강타 하다 신음 내미다 내려앉다 건달 잡다 최 형사 입구 문 내다 버리다 유리 문 박살 내미다 나자빠지다 건달 손 칼 병 따위 들다 벌떡 일어나다 건달 끄다 약 비명 내 지르다 나가다 미니스커트 옆 병 들다 설치다 대다 건달 의 팔목 병 리치 손 비명 지르다 놈 차 발 많다 건달 맞서다 홀홀 단신 싸우다 최 형사 겁 질린다 사람 비명 지르다 뒤 물러나다 뒤 저 편 형사 팔짱 끼 서서 바라보다 최 형사 향 하다 공격 하다 들어가다 건달 최 사의 무자비하다 강하다 몸 놀림 하나 둘 쓰러지다 테이블 부수 디제이 박스 박살 내미다 날아가다 놈 물러나다 사람 탄성 지르다 하나 둘 앞 다가오다 구경 하다 속 서다 형사',
#  '사람 오다 저 여자 죽이다',
#  '사람 정말 폼 나다 끝내다 끝내주다 햐',
#  '이렇다 사람 오다 최 형사 번갈아 가다 보다 형사 때 최 형사 뒤 놈 칼 휘두르다 순간 퍼벅 리치 싸움판 끼어들다 형사',
#  '최 형사 놈 해치다 도망가다 놈 잡다 왜 끼어들다',
#  '형사 도와주다 잔소리',
#  '하다 다시 사람 사이 들어가다 형사 최 형사 건달 쓰러지다 나가다 안되다 보스 듯 놈 사람 헤집다 뒷문 도망가다',
#  '최 형사 뭐 하다',
#  '형사 인상 구기다 사람 사이 튀어 나가다 뒤따르다 나가다 최 형사',
#  '씬 밖',
#  '허겁지겁 튀어나오다 최 형사 형사 보다 저 편 차 막다 세우다 울다 밀치다 보스 달려가다 형사 보스 향 하다 점프 문 닫다 안 들어가다 보스 쓰러지다 형사 옆 휭하 차 몰다 가버리다 넘어지다 형사 옆 곧장 끼 이익 멈추다 서다 차안 최 형사 보이다 형사 타다 급 출발 차',
#  '씬 도로',
#  '끼 이익 빠르다 달리다 투캅스 차 다른 차 젖히다 급회전 하다 반대편 차선 달린다',
#  '씬 차 안',
#  '마주 보고 달려오다 차 클락 션 울리다 대다 속 당황 하다 형사 결의 가득 찬 최 사의 표정 속',
#  '씬 도로',
#  '엉망 진창 뒤 키 차 속 달려가다 투캅스 차 오른쪽 보이다 차안 놈 보다 핸들 꺽 늘다 순간 끼 이익 급회전 하다 부닥치다 들어오다 투캅스 차 끼 이익 쿵 부닥치다 다른 도로로 급회전 하다 들어가다',
#  '씬 차 안',
#  '공사 도로 가설 밀치다 놈 차 들이다 받다 속',
#  '형사 혹시 최 사도 폼 나 경찰 건가',
#  '최 형사 그렇다 정신 나가다 놈 있다',
#  '인상 팍 구기다 형사',
#  '씬 도로',
#  '투캅스 차 뒤 채 끼 이익 도로 가로수 들이다 받다 멈추다 서다 차 허겁지겁 내리다 보스 쇼핑 타운 안 뛰어들다 간다',
#  '씬 달리다 차 안',
#  '인도 보다 액셀 레이 터 밟다 최 형사 형사 휘둥그레지다',
#  '형사 돼다 멈추다',
#  '최 형사 결의 찬 얼굴 밀다 부치다',
#  '씬 쇼핑 타운',
#  '밀고 들어오다 투캅스 차 비명 지르다 피하 사람 놈 들어가다 쇼핑 타운 안 곧장 밀고 들어가다 차 쾅 가제 대형 쇼 윈도우 박살 내미다 멈추다 서다 차 보스 뒤 돌아보다 겁 질린다 채 내달 음 치다 차 튀어나오다 최 형사',
#  '최 형사 달려가다 거기',
#  '최 형사 뒤 삐 덕 열리다 문 거의 넋 나가다 듯 나오다 형사',
#  '형사',
#  '씬 건물 안',
#  '도망가다 보스 향 하다 저돌 달려가다 최 형사 꺄 아악 비명 내 지르다 사람 사이 달려가다 보스 최 형사 간격 좁히다 힘껏 점프 하다 보스 덥다 최 형사 다른 가게 문 박살 내미다 뒹구 사람 보스 틈 지다 칼 꺼내다 들다 최 형사 향 하다 휘두르다 멋지다 보스 쓰다 뜨다 리 최 형사 보스 팔 내리다 다리 우지끈 차 버리다 비명 지르다 완전 맛 간 보스 목 확 꺽 버리다 듯 하다 최 형사 보다 질겁 채 달려오다 형사',
#  '형사 돼다',
#  '하다 최 형사 덥다 치다',
#  '바닥 최 형사 덥다 친 채 엎어지다 이형 사의 모습 속',
#  '씬 경찰서 과장 실',
#  '인상 쓸다 채 버럭 버럭 고함 지르다 대다 과장 앞 고개 숙이다 있다 형사 최 형사',
#  '과장 도대체 뭐 하다 서류 들다 보이 나이트클럽 자동차 대다 쇼 윈도우 전부 얼마 알',
#  '형사 고개 숙이다 채',
#  '과장 지금 전쟁 나다 기다리다 나오다 때 잡다 그 자식 썩다 없다 지기 해',
#  '형사 죄송하다',
#  '과장 형사 여자 신참 오다 오버 하다 임마 보다 훤해 감봉 개월',
#  '형사 예 써다',
#  '과장 최 사의 어깨 토닥 자마자 하필 이렇다 놈 만나다 억울하다 하다 수 없다 감봉 개월 미안하다 최 형사',
#  '최 형사 앞 나서다 과장 징계 내다 시오 저 개월 하다',
#  '과장 뭐 최 형사 이쁘다 의리 있다',
#  '형사 아니다 상사 제 잘못 더 크다 모두 제 책임지다',
#  '과장 형사 나다 그렇다 싶다 임마 최 형사 보다 징계 문제 더 가볍다 것 위 건의 하다 보지',
#  '최 형사 예 고맙다',
#  '형사 과장 최 형사 번갈아 보다',
#  '과장 최 사의 어깨 다독 차근차근 일 배우다 이형 사의 귀 잡아당기다 성 깔다 좀 죽이다 알다',
#  '씬 사무실',
#  '과장 실 문 열다 나오다 투캅스',
#  '최 형사 죄송하다 선배 저 때문',
#  '형사 아니다 괜찮다 가지',
#  '최 형사 요',
#  '형사 손 두둑 거리 일 하다',
#  '씬 대연 회장 입구',
#  '회 단합 대회 플랭카드 걸리다 회장 주차장 정차 하다 차 내리다 형사 뒤따르다 나오다 최 형사 보다',
#  '형사 이번 내 차례',
#  '최 형사 네',
#  '형사 자네 구경 하다 있다',
#  '하다 걸어가다 형사 다가오다 중년 사장',
#  '사장 지하 듯 손 내미다 오늘 손님 받다',
#  '형사 형사 증 내보이다',
#  '사장 아니다 저 형사',
#  '하다 다가오다 양복 차림 건달',
#  '건달 뭐',
#  '하다 다가오다 건달 를 보다 곧장 퍼버벅 주먹 눕다 안 들어가다 형사',
#  '씬 회장 안',
#  '문 열다 들어오다 형사 뒤 다가오다 사장',
#  '사장 형사 여기 이르다 있다',
#  '형사 그렇다 사장 밀 보다 폭력 조직 듯 놈 좌악 주다 앉다 있다 일제 휙 바라보다 건달 의 고개 짓 따르다 형사 향 하다 일제 일어나다 건달 형사 손 두둑 거리 미소 지은 채 놈 다가가다 울상 되다 채 이 모습 바라보다 사장 뒤 최 형사 들어오다',
#  '기합 내 지르다 덩치 좋다 건달 화면 향 하다 달려오다 순간 구둣발 하나 치솟다 오르다 건달 면상 강타 하다 쿵 테이블 박살 내미다 나자빠지다 건달 보다 이번 더 많다 놈 형사 향 하다 쇠 파이프 야구 방망이 회칼 등 들다 공격 해오다 몸 날리다 놈 쓰다 뜨다 리 형사 순식간 아수라 되다 회장 익 울상 되다 채 바라보다 사장 누군가 던지다 칼 날아오다 몽둥이 카운터 아래 몸 숙이다 쿵 쾅 퍽 부러지다 맞다 박살 나 소리 속 사장 주변 날아오다 온갖 병 의자 건달 등 일어서다 번번하다 몸 피하 사장 편 지켜보다 두목 몇몇 부하 안되다 싶다 뒷문 도망가다 형사 놈 쫓아가다 순간 뒷문 앞장서다 도망가다 부하 이 면상 맞다 뒤 나자빠지다 칼 휘두르다 나서다 부하 또한 복부 맞다 움찔 하다 사이 누군가 단수 우두둑 손목뼈 부러지다 정도 내다 치다',
#  '악 비명 지르다 나자빠지다 부하 보다 두목 부하 앞 최 형사 막다 서다 있다 형사 의외 듯 바라보다 다가가다 움찔 하다 두목 등 중 부하 이 쇠 파이프 휘두르다 공격 하다 보지 이형 사의 화려하다 발차기 진열 박살 내미다 뻗다 말다 형사 어깨 두둑 거리 어떻다 듯 최 형사 바라보다 순간 최 형사 향 하다 발차기 하다 공격 하다 부하 최 사의 맞다 발차기 우두둑 다리 뼈 부러지다 듯 하다 비명 지르다 다른 테이블 박살 내미다 쓰러지다 이번 최 형사 고개 돌리다 어떻다 듯 형사 보다 완전하다 갇히다 버리다 두목 부하 등 양쪽 나뉘다 공격 하다 최 형사 형사 마치 경쟁 듯 달려들다 놈 처치 하다 형사 체인 들다 달려들다 놈 몸 숙이다 피다 멋지다 훅 방 박살 곤 형사 보다 보다 형사 어쭈 달려들다 엄청나다 덩 치르다 잡다 빗장 걸이 한판 창문 내다 것 안되다 걸 보다 최 형사 겨우 그 정도 더욱 엄청나다 덩 치르다 업다 기해 또 다른 창문 확 던지다 버리다 난 정도',
#  '으잉 제 여자 하다 보다 달려들다 놈 턱 하다 대다 얻어맞다 형사 열 확 받다 휘 돌리다 차기 처리 곤 머쓱하다 얼굴 최 형사 보다 휘둥그레지다 형사 놈 최 형사 향 하다 라이트 훅 날리다 있다 최 형사 급하다 팔 들다 막다 놈 턱 강타 곤 이단 옆 차기 마무리 하다 어떻다 차례 한번 서로 멋지다 공격 교차 하다 마지막 남다 두목 둘 사이 울상 서다 있다 최 형사 형사 마지막 남다 두목 향 하다 동시 주먹 내 지르다 털썩 바닥 무릎 꿇다 살리다 달라 두목 위로 서로 뻗다 주먹 잡고 있다 최 형사 형사 서로 노려보다 이렇다 투캅스 모습 경 보이 매달리다 형광등 박살 테이블 의자 깨지다 유리창 등 완벽하다 폐허 되다 버리다 회장 모습 과장 보이다',
#  '씬 경찰서 과장 실',
#  '이형 사의 멱살 잡고 있다 과장',
#  '과장 차라리 날 죽이다 죽이다 이 인간 파트너 바꾸다 주다 나 짤리 만들다 응',
#  '형사 고개 숙이다 채 죄송하다',
#  '과장 마구 흔들다 이 죄송하다 되다 일이 나 감봉 당하다 인간',
#  '씬 형사 집 앞',
#  '단아 옥 대문 옆 초인종 누르다 형사',
#  '소리 엄마 누구세요',
#  '형사 접다 경찰',
#  '삐 소리 문 열리다 안 들어가다 형사',
#  '씬 마당',
#  '자 형태 집 작다 마당 걸어오다 형사 마당 하다 켜다 태권도 복 입다 채 심호흡 하다 왓 격파 하다 아버지',
#  '형사 지나치다 다녀오다',
#  '아버지 보다 응 이제 여섯 가뿐하다 어떻다 내기 한번 하다 응',
#  '엄마 마루 다가오다 그만하다 태풍 불면 지붕 날아가다',
#  '아버지 지붕 중요하다 건강 중요하다',
#  '형사 들어가다 들어가다 아버지',
#  '아버지 임마 자식 왜 젖다 풀빵 축 늘어지다',
#  '씬 방안',
#  '군대 용 식 판이 놓이다 술상 술잔 도로 절도 있다 꺽 들다 말다 있다 아버지 형사',
#  '아버지 이 자식 나가다 죽다 죽다 내 겨우 그 정도 로 키우다',
#  '형사 죄송하다',
#  '아버지 세상 휘 잡다 모자라다 놈 여자 하나 때문 쩔쩔매다',
#  '때 소주 가져오다 엄마',
#  '엄마 난 니 일찍 오니 좋다',
#  '아버지 좋다 뭐 좋다 남자 집 있다 시간 많다 밖 밀리다 법 하여튼 여자 단순하다',
#  '엄마 요즘 가정 남자 성공하다',
#  '아버지 어떻다 놈 그렇다 말 해 제발 티브이 하다 말 좀 믿다 응 부자 간 모처럼 이야기 하다 방해 하다 가다 노가리 굽다',
#  '눈 흘기 엄마 일어나다 형사 술 따르다 아버지',
#  '아버지 임마 여자 초반 기선 제압 하다 끝장',
#  '형사 걘 자기 쟌다르크 줄 알다',
#  '아버지 그렇다 보다 여자 임마 여자 하자 대로 일일이 받다 피곤하다 임마',
#  '형사 그렇다 어떻다',
#  '아버지 니 엄마 보다 임마 첨 대들다 젠 말 한마디 되다 임마 상대방 약점 생각 하다 이다 여자 일 수 없다 걸 보여주다 알다',
#  '형사 아버님',
#  '아버지 왜',
#  '형사 두 손 잔 들다 존경 하다',
#  '아버지 잔 부닥치다 완 샷',
#  '씬 고수부지',
#  '여명 비추다 은 새벽 고수부지 규칙 발 소리 따르다 추리 닝 차림 조깅 하다 있다 형사 최 형사',
#  '형사 달리 상쾌하다 않다 좋다 경찰 되다 우선 체력 강하다 돼다 범인 추적 하다 보다 몇 일 밤새기 일쑤',
#  '최 형사 달리 모처럼 뛰다 사람 있다 좋다 요',
#  '형사 매일 조깅 하다',
#  '최 형사 예 하루 킬로',
#  '형사 그으',
#  '최 형사 이제 몸 좀 풀리다',
#  '하다 빠르다 뛰어가다 최 형사 보다 달려가다 형사',
#  '씬 헬스장',
#  '땀 젖다 채 헬스기구 운동 하다 투캅스 서로 뒤지다 않다 듯 구운동 모습 보이다 뒤',
#  '형사 최 형사 보다 제법 하다 일어나다 최 형사 보다 벌써 지치다 건 아니다',
#  '최 형사 다가오다 선 지치다 긴요',
#  '하다 서로 기구 바꾸다 운동 하다 투캅스',
#  '최 형사 기구 운동 하다 간 하다 하다 좀 더 올리다',
#  '뒤지다 않다 이형 사도 무게 올린다 투캅스 땀 뻘뻘 절 채 서로 노려보다 힘겹다 운동 하다',
#  '씬 수영장',
#  '출발점 수영복 차림 몸 풀 있다 투캅스',
#  '형사 유연성 지구력 키우다 덴 수영 최고 열 번 왕복 한번 쉬다 오케이',
#  '최 형사 그냥 하다 심심하다 점심 내기 하다',
#  '형사 첫날 무리하다 거 알다',
#  '최 형사 출발점 서다 괜찮다 어리다 적 선수 이다',
#  '인상 찌푸리다 형사 보다 수경 쓰다 최 형사 동시 풀 점프 하다 들어가다 투캅스 자유형 빠르다 허다 부적 형사 한참 잠수 뒤 불쑥 솟아오르다 최 형사 형사 한참 앞 지르다 채 헤엄 치다',
#  '자유형 꿋꿋하다 헤엄 치다 형사 맞다 편 버터플라이 헤엄 치다 최 형사 중간 엇갈리다 채 스치다',
#  '최 형사 벌써 지치다 건 아니다',
#  '여유만만 하다 바라보다 이르다 악물다 지나치다 가다 형사 다리 쥐라 난 듯 다리 움켜쥐다 채 물속 빠져들다 최 형사 이렇다 형사 보다 뒤 돌다 헤엄 치다 간다 물 속 허다 부적 거리 형사 다가가다 물 속 더 치다 박아 버리다 최 형사 힘 빠지다 듯 축 늘어지다 형사 보고서 뒤 안다 채 밖 데리다 간다',
#  '씬 달리다 차 안',
#  '심각하다 표정 말 운전 하다 형사 하품 쩌억 하다 옆 보다 최 형사 보다',
#  '최 형사 수영장 한마디 안 거 알다 여자 도움 받다 고맙다 말 정돈 하다 되다 거 녜',
#  '형사 고맙다',
#  '최 형사 차 하다 켜다 끼익 세우다 도대체 왜 그렇다 아침 불다 갑자기 조깅 헬스장 수영 강행 시키다 하다 날 그만두다 하다 싶다 거 나 일 하다 불편하다',
#  '형사 좋다 나다 최 형사 위해 솔직하다 이야기 하다 최 형사 무술 제법 하다 인정 하다 그만두다 개 소나 경찰 하다 세상 여자 돼다 경찰 일 남자 하다',
#  '최 형사 좋다 만약 여자 해선 안되다 라면 그만두다 오케이',
#  '형사 오케이',
#  '씬 락 까페 안',
#  '크다 않다 락까페 음산하다 음악 맞추다 사람 북적 거리 오가다 하다 켜다 바라보다 형사 최 형사',
#  '형사 여자 상황 판단 느리다 지금 곳 무슨 벌어지다 있다',
#  '최 형사 마약 거래',
#  '형사 찍다 어떻다 놈 알다',
#  '최 형사 쟈켓 입다 나가다 하다 놈 보고 일어나며 지금 나가다 형사 어떻다 알다 듯 보다 여자 직감 가장 정확하다',
#  '씬 다른 거리',
#  '편의점 계산 하다 나오다 쟈켓 바라보다 최 형사 형사',
#  '형사 여자 미행 하다 때 금방 눈 띄다',
#  '나가다 쟈켓 뒤 따라가다 최 형사',
#  '씬 호텔 앞',
#  '걸어가다 쟈켓 뒤따르다 최 형사 쟈켓 호텔 앞 침 탁 뱉다 뒤 돌아보다 최 형사 윙크 호텔 안 들어가다 최 형사 저 편 형사 다가오다',
#  '최 형사 여자 한텐 방심하다 마련',
#  '형사 좋다 여자 갈다 수 없다 곳 놈 거래 하다 경우 많다 호텔 사우나 가리키다 잡 수 있다',
#  '씬 싸우다 안',
#  '옷 벗다 있다 남자 카메라 보다 익 놀란 채 몸 가리다 기도 하다 속 꿋꿋하다 걸어가다 최 형사 카메라 탈의실 지나 사우나 안 들어가다 최 형사 뒤따르다 익 놀라다 물 속 뛰어들다 남자 몸 가리다 남자 등 욕탕 지나 한증막 안 들어가다 그 안 수건 교환 하다 쟈켓 남자 문신 하다 남자 뻥 찌다 최 형사 보다 곧장 경찰 증 보이다 최 형사 이렇다 놀란 쟈켓 문신 최 형사 향 하다 덤비다 최 사의 화려하다 공격 퍽 두둑 발차기 엎 치기 창문 깨다 날아가다 놈 모습 보다 뭐 저런 있다 듯 바라보다 형사 득 만만하다 바라보다 최 형사',
#  '씬 경찰서 사무실',
#  '최 형사 쟈켓 문신 데리 들어오다 다른 경찰 인도 하다 저 편 앉다 투 피스 젊다 여자 사이 두다 중년 남녀 마구 다투다 있다 모습 보이다',
#  '중년 강사 머리 타락 잡다 채 이 자식 내 딸 어떻다 하다 끄다 너 같다 놈 콩밥 먹다 돼다',
#  '강사 왜 러시 겁',
#  '이렇다 두 사람 다가가다 말리다 최 형사 형사',
#  '최 형사 미니 무슨 입',
#  '중년 우리 애가 대학생 이자 식이 저녁 먹다 꼬셔 술 먹이다 뒤 다시 강사 덥다 나쁘다 놈',
#  '강사 뿌리치다 점잖다 제 억지로 데려가다 게 아니다 말씀드리다',
#  '중년 술취했다 거짓말 하다 이 나쁘다 놈',
#  '강사 명백하다 저항 하다 않다 강간 볼 수 없다 판례 아시 물어보다 내 강간 하다 응',
#  '투 피스 고개 흔들다 모르다',
#  '강사 보다 난 이혼 상태 간통죄 아니다 법대 해결 하다 되다',
#  '중년 법 그렇다 이 더럽다 놈 너 배우다',
#  '하다 덤비다 중년 를 잡다 형사',
#  '형사 이르다 말다 저희 알다 하다',
#  '강사 여유 있다 그렇다 법대 하다 응',
#  '하다 간 갑자기 멱살 움켜쥐다 손 끌리다 일어나다 강사 보다 최 형사 강사 잡고 있다',
#  '강사 왜 아가 씬 뭐',
#  '최 형사 나 경찰',
#  '하다 곧장 강사 면상 갈기 뒤 확 나자빠지다 강사',
#  '최 형사 강사 일으키다 도장 퍼버벅 난타 하다 일어나다 법보 더 중요하다 게 있다 힘없다 여자 나쁘다 짓 뭐 법대',
#  '주변 형사 과장 등 놀란 듯이 모습 바라보다',
#  '과장 다가오다 잡다 이 보다 최 형사 경찰 이르다 돼다',
#  '최 형사 놓다 이렇다 자식 죽이다 버리다 돼다',
#  '하다 말리다 과장 확 밀치다 버리다 뒤 나자빠지다 형사 안되다 다가가다 강사 다시 주먹 내 지르다 최 사의 손목 낚아채다',
#  '형사 그만하다',
#  '최 형사 놓다',
#  '형사 경찰서 이 무슨 짓 당장 과장 이 남자 사과 하다',
#  '최 형사 노려보다 좋다 사과 하다',
#  '엉거주춤 일어나다 강사 다가가다 최 형사 다시 강사 그 곳 퍽 발 차 버리다 돌아서다 나 가버리다 익 다시 고꾸라지다 강사 돌아서다 나가다 최 형사 뻥 찌다 바라보다 과장 등 경찰',
#  '형사 따르다 나가다 하다 최 형사 저 정말',
#  '과장 형사 귀 잡다 도망가다 이 자식 누구 때문 너 다니다 최 형사 개 망나니 돼다 임마',
#  '팍 인상 일그러지다 이형 사의 모습',
#  '형사 모두 빠져나가다 텅 빈 사무실 최 형사 다그치다 형사',
#  '형사 도대체 위계 질서 어떻다 알다 군 경찰 제일 중요하다 건 첫째 복종 둘째 복종 거 모르다 하다 여자 군 가다 오다 모르다 모든 팀웍 부하 절대 복종 나오다 알다',
#  '최 형사 죄송하다 저 때문 선배 내근 하다 되다',
#  '형사 보지 않다 채 돼다 그 아주머니 나 다음 인사 드리다 강사 폭행죄 최 형사 고소하다 걸 아주머니 나서다 서로 고소 않다 것 합의 해주다 망정 안 그렇다 구속 돼다 끄다',
#  '인상 굳어지다 최 형사',
#  '최 형사 그렇다',
#  '형사 혼잣말 여자 나서다 되다 일도 안되다 하다',
#  '최 형사 뭐라다 선배 지금 말 심하다 하다 것 아니다',
#  '형사 또 대들다 방금 내 이야기 들다 거 안 거',
#  '화난 듯 서로 노려보다 투캅스 때 울리다 전화 벨소리 동시 손 뻗다 투캅스 최 형사 빠르다',
#  '최 형사 예 경찰서 이다',
#  '소리 아줌마 절박 우리 아이 유괴 당하다',
#  '최 형사 예',
#  '씬 피해자 집 거실',
#  '의아 표정 보다 형사 최 형사 두 손 내 젖다',
#  '아저씨 유괴 뇨 그렇다 일 없다',
#  '최 형사 분명하다 신고 들어오다',
#  '아저씨 가요 다른 지다 자 그렇다',
#  '하다 투캅스 막다 아저씨 뒤 부엌 투캅스 눈치 보다 불안하다 표정 아줌마 발견',
#  '최 형사 다가서다 아주머니 신고 하다',
#  '아줌마 전 전',
#  '망설이다 아줌마 뭔가 말 하다 하자 아저씨 먼저 말 하다',
#  '남편 자기 자식 없어지다 숨다 부모 어딨다',
#  '형사 최 형사 또 장난 전화 았 구만 도대체 일 어떻다 하다',
#  '최 형사 아주머니 사실 말씀 해주다 저희 해결 하다',
#  '남편 안되다 듯 전화하다 적 없다 왜 귀찮다 하다 자 나가다',
#  '최 형사 아주머니 왜 두렵다',
#  '형사 최 형사 남자 아니다 아줌마 왜 자꾸 물어 아저씨 착오 있다 보다 죄송하다',
#  '남편 현관 몰다 아니다 괜 걸음 하다 거 약소 하다 차비 하다',
#  '안 주머니 돈 꺼내다 최 형사 건내다 남편',
#  '최 형사 유괴 범한 테 돈 해결 할껀 가요',
#  '때 탁 자위 있다 전화 린다',
#  '순간 남편 아줌마 긴장 듯 전화기 바라보다 투캅스 눈치 보다 아줌마 남편 하다 모습 보다',
#  '최 형사 제 받다',
#  '아줌마 동시 돼다',
#  '남편 동시 돼다',
#  '씬 유괴 범의 아지트',
#  '화면 가득 겁 질린다 아이 모습 속',
#  '아이 핸드폰 대고 엄마 살리다 나 무섭다',
#  '소리 아줌마 지선 지선',
#  '어둡다 허름 창고 같다 곳 있다 유괴 범 세 명 아이 목 팔로 조르다 있다 놈 핸드폰 빼앗다',
#  '유괴 범 돈 준비 하다 좋다 설마 경찰 신고 하다',
#  '아이 겁 질린다 채 울먹이다 엄마',
#  '유괴 범 아이 때리다 시끄럽다 핸드폰 대고 만약 경찰 그림자 보이 애 죽다',
#  '씬 곳',
#  '어둠 가르다 달리다 그랜져 지나치다 한적하다 도로 변 커다랗다 가방 들다 서다 아줌마 모습 어둠 속 보이다 주변 편의점 안 직원 복장 하다 채 바라보다 형사 카세트 테이프 가판 장사 하다 형사 그 옆 주차 어 두운 차안 엎드리다 숨다 형사 맞다 편 도로 어 두운 골목 세워지다 차 안 있다 형사 등 모습 빠르다 보이다',
#  '오가다 사람 바라보다 형사 눈빛 너머 건너편 도로로 그랜져 지나가다',
#  '형사 손목 시계 대고 안 오다 같다',
#  '형사 귀 찬 이어폰 만지다 거기 히터 나오다 지금 월 왜 춥다 젠장',
#  '형사 바닥 엎드리다 손목시계 대고 그렇다 사다리 자다 타다',
#  '씬 달리다 차 안',
#  '이동 하다 차 안 시점 보이다 아줌마 주변 모습 운전 하다 밖 바라보다 유괴 범 미러 보이다 아줌마 모습 작아지다 간다',
#  '씬 곳',
#  '어둠 가르다 달려오다 자가용 불빛 비치',
#  '형사 손목시계 대고 뻐꾸기 하나 뻐꾸기 하나',
#  '형사 진돗개 대기',
#  '다가오다 자가용 휭하 지나치다 가버리다 커다랗다 가방 들다 서다 아줌마 모습 어둠 속 보이다 때 저 편 도로 비치다 불빛 달려오다 차갑다 내뿜는 헤드라이트 비치다 아줌마 모습 바로 변장 최 사이다 눈 부신 듯 고개 돌리다 최 형사 앞 끼 이익 멈추다 서다 차 재빠르다 내리다 유괴 범',
#  '유괴 범 돈',
#  '최 형사 가방 어보',
#  '유괴 범 액수 정확하다',
#  '최 형사 아이 어딨다',
#  '유괴 범 다른 곳 있다 걱정 하다 돌아가다',
#  '최 형사 돼다 돈 가져오다 아이 풀다',
#  '유괴 범 가방 잡다 시간 없다 내 안 돌아가다 애 죽다',
#  '최 형사 가방 꽉 움켜쥐다 그렇다 가요 내 데려가다',
#  '하다 잡다 당기다 가방 꽉 감싸다 앉다 최 형사 긴장 채 최 형사 유괴 범 지키다 보다',
#  '형사 어떻다 하다',
#  '형사 애 차안 없다 일단 최 형사 맡기다',
#  '최 형사 가방 잡다 하다 유괴 범 확 밀치다',
#  '최 형사 애 풀다 전 절대 주다',
#  '유괴 범 안 놓다 이 개 같다 년 확',
#  '하다 주먹 내 지르다 유괴 범 의 뺨 번쩍 오다 닿다 최 사의 손 퍽 소리 고개 돌아가다 유괴 범',
#  '유괴 범 어쭈',
#  '하다 다시 주먹 내 지르다 유괴 범 어느새다 최 사의 가방 휙 날아오다 유괴 범의 머리 친 퍽 뒤 자빠지다 유괴 범',
#  '최 형사 애 어딨다',
#  '씬 부근',
#  '나무 뒤 오토바이 이 모습 바라보다 있다 형사 아줌마 놀란 표정',
#  '아줌마 작다 어머 왜 저러다 거',
#  '형사 작다 저 모르다',
#  '아줌마 나가다 저러다 우리 애 죽다 돼다',
#  '형사 말리 괜찮다 겁니다 안심 하다',
#  '아줌마 형사 퍽 치 안심 하다 뭘 안심 하란 말 놓다',
#  '형사 막다 안되다',
#  '나가다 아줌마 잡다 형사 아줌마 몸부림 마구 맞다',
#  '씬 그 곳',
#  '뒤 자빠지다 일어나다 유괴 범',
#  '유괴 범 이 누굴 패 난 유괴 범 니 애 데리 있다 이 멍청하다 년',
#  '최 형사 애 데리 오다 그렇다 가방 못 주다',
#  '유괴 범 너 혹시 계모 알다 가다 애 죽다 이 또 라이 같다 년',
#  '하다 순간 저 편 패 트롤 카 다가오다 멈칫 하다 바라보다 두 사람',
#  '유괴 범 이 년 경찰 불다',
#  '최 형사 알다 내 부르다 게 아니다',
#  '유괴 범 작다 내 잡히다 니 애 바로 죽다 알',
#  '하다 멈추다 패 트롤 카 내리다 경찰',
#  '경찰 거기 뭐 하다 겁',
#  '최 형사 아뇨 유괴 범 툭치 남편 절 마중 나오다 이제 가다',
#  '유괴 범 예 맞다',
#  '경찰 이 가방 뭡',
#  '최 형사 이 가방',
#  '씬 근처',
#  '하다 이 모습 바라보다 아줌마 형사',
#  '아줌마 도대체 뭐 하다 거',
#  '형사 걱정 하다 말다 되다 겁니다',
#  '아줌마 자다 되다 뭐 돼다 이형 사의 멱살 잡다 우리 애 되다 죽 줄 알',
#  '씬 그 곳',
#  '최 형사 유괴 범 앞 서다 있다 경찰 유괴 범 주머니 칼 빼다',
#  '경찰 두 분 싸우다 것 같다',
#  '최 형사 아뇨 그렇다 리가 있다 팔짱 끼 그치다 자기',
#  '유괴 범 어색하다 웃다 그렇다',
#  '경찰 이상하다 듯 두 사람 다시 보다 어색하다 미소 짓다 최 형사 얼굴 맞다 부어 오른 유괴 범',
#  '경찰 부부 싸움 집 하다',
#  '하다 엉망 되다 유괴 범 한심하다 듯 보다 경찰차 올라타다 최 형사 유괴 범 긴장 채 지나치다 가다 경찰차 보다',
#  '씬 달리다 차 안',
#  '운전 하다 유괴 범 옆 최 형사 가방 안고 있다',
#  '유괴 범 모처럼 경찰 하다 번 죽이다 보나 하다 씨발',
#  '최 형사 경찰 죽이다 적 있다',
#  '유괴 범 그렇다 날 귀찮다 쫓다 다니다 놈 있다 야구 방망이 내리다 친 뒤 살리다 달라 애원 하다 걸 보다 생매장 하다 그때 느끼다 거 역시 경찰 죽이다 때 제일 스릴 있다 말',
#  '최 형사 정말 죽이다 놓다',
#  '유괴 범 뭐 이 썅년 아깝다 계속 성질 돋다',
#  '하다 때리다 하다 먼저 최 사의 손바닥 유괴 범 의 뺨 때리다',
#  '최 형사 운전 똑바로 해',
#  '유괴 범 씨발 무슨 엄마 이렇다',
#  '씬 도로',
#  '인적 없다 도로 달리다 차 뒤 라이트 끈 채 형사 아줌마 오토바이 타고 간다',
#  '씬 유괴 범의 아지트',
#  '인적 없다 한적하다 야외 어두컴컴하다 허름 창고 앞 멈추다 서다 차 내리다 유괴 범 과 최 형사',
#  '유괴 범 문 세 번 한번 두드리다 나야 유괴 범',
#  '씬 아지트 안',
#  '문 여 유괴 범 유괴 범 뒤 최 형사 들어오다 놀라다 최 형사 안 보다 아이 묶인 채 바닥 앉다 옆 유괴 범 이 담배 피우다 있다',
#  '유괴 범 이다 왜 데리 오다',
#  '유괴 법 어차피 내 얼굴 보다 애 새끼 죽이다 버리다',
#  '유괴 범 아이 툭 치 임마 엄마 오다',
#  '최 형사 다가가다 지선 괜찮다',
#  '아이 우리엄마 어딨다',
#  '휙 쳐다보다 유괴 범',
#  '최 형사 지선 엄마',
#  '아이 줌 누구',
#  '유괴 범 다가오다 최 형사 보다 아이 목 칼 갖다 대다',
#  '유괴 범 움직 이지마 너 누구',
#  '최 형사 도대체 아이 무슨 짓 거 엄마 알아보다 임마 자세하다 보다 엄마 잖다',
#  '유괴 범 아이 니 엄마 맞다',
#  '아이 알다 우리엄마 어딨다 울다 엄마 엄마',
#  '유괴 범 그렇다 줄 알다 이 썅년',
#  '유괴 범 죽이다',
#  '유괴 범 재빠르다 칼 꺼내다 들다 유괴 범 를 돌려차기 날다 버리다 최 형사 휘둥그레지다 유괴 범 금방 팰 듯이 가다 최 형사 휙 뒤 돌아보다 겁 질린다 듯 멈칫 하다',
#  '유괴 범 뭐 하다 새꺄',
#  '하다 순간 어느새다 총 꺼내다 들다 최 형사 유괴 범 겨누',
#  '최 형사 유괴 범 겨눈 채 꼼짝 마',
#  '유괴 범 아이 목 칼 대다 채 총 버리다 안 버리다 죽이다 버리다 아이 목 대다 칼 힘 주다 하나 울',
#  '최 형사 바라보다 좋다 대신 아이 살리다',
#  '유괴 범 알다 약속 하다',
#  '총 내다 총알 밖 빼 버리다 채 저 편 던지다 최 형사 유괴 범 신경질 아이 뒤 밀치다 최 형사 다가가다',
#  '유괴 범 이 년 겁',
#  '유괴 범 바닥 떨어지다 총 총알 집다 임마 저 여자 싸움 졸 자다 해',
#  '유괴 범 병신 같다 게 집년 겁 먹기 비키다 임마',
#  '하다 칼 휘두르다 공격 하다 들어가다 유괴 범 최 형사 피하 칼 들다 손 우두둑 꺽으 바닥 댕 치다 바닥 널 부러지다 유괴 범 보다 허겁지겁 총 총알 들다 유괴 범 총알 넣다 긴장 듯 번번하다 떨어지다 하다 어느새다 다가오다 최 형사 보다 곧장 총 바닥 떨어뜨리다 손 들다 이 동시 문 쾅 차고 들어오다 형사 아줌마 울먹이다 아이 엄마 포옹 하다 모습 바라보다 투캅스 모습 속',
#  '씬 서장 실',
#  '선행 하다 박수 소리 정복 차림 최 사의 어깨 위 잎 파리 세 개 계급 달다 서장',
#  '서장 악수 하다 축하 하다 최경 최단 기간 승진 기록 개 망신 당하다 뻔하다 우리 경찰서 최 형사 구 해주다',
#  '최 형사 감사하다',
#  '편 박수 치다 동료 형사 속 이형 사도 보이다',
#  '씬 복도',
#  '커피 자판기 앞 있다 최 형사 다가가다 형사',
#  '형사 축하 하다 최 형사',
#  '최 형사 돌아보다 고맙다 형사 한잔 하다',
#  '형사 뭐 지금 나 반말 하다',
#  '대뜸 나오다 최 사의 반말 어이 없다 최 형사 돌아보다 형사 뽑다 커피 내미다',
#  '최 형사 같다 경장 끼리 앞 해보다 응',
#  '형사 하루 잎 파리 호봉 무섭다 줄 모르다 같다 경장 맞먹다 자다',
#  '최 형사 응 젠 상사 부하 아니다 동등 파트너 관계 일 해보다 똑같다 조건 경쟁 하다 만하 않다',
#  '형사 정면 노려보다 지금 나 도전 하다',
#  '최 형사 어깨 툭툭 치 지나치다 아니다 분발 커피 말다 음 커피 맛 좋다',
#  '휙 고개 돌리다 지나치다 최 형사 노려보다 형사 커피 곧장 휴지통 확 버리다',
#  '씬 은행 계단',
#  '은행 유리 문 보다 계단 꺽 지다 들어가다 장갑 목 장갑 둘 모자 누르다 쓸다 채 계단 모퉁이 멈추다 서다',
#  '장갑 지난 번 실패 거울 삼다 이번 제대로 하자 위험 크다 만큼 더 짭짤하다 남자 은행 정도 털다 하다 어리다 때 다지다 하다',
#  '목 장갑 형님 어리다 때 꿈 은행강도 이다',
#  '장갑 담배 꺼내다 물다 그렇다 넌',
#  '목 장갑 제 꿈 우리 같다 은행강도 빵 빵 총 쏘다 죽이다 경찰 되다 거 이다',
#  '장갑 답배 피우다 팰 듯이 개새꺄 개 소리 계속 하다 개패 듯이 패 버리다 알다',
#  '목 장갑 벽 붙다 금연 표시 보다 행 여기 금연 구역 요',
#  '장갑 휙 보더 마구 때리다 씨발 놈 법 지키다 경찰 하다 미치다 은행강도 하다',
#  '하다 계단 하다 여자 올라오다 멈칫 하다 어색하다 목 장갑 옷 털다 장갑 목 장갑 소매 숨다 쇠 파이프 흘러나오다 쓸다 올리다 자신 소매 숨다 쇠 파이프 감추다 장갑 치마 입다 올라가다 여자 보다 미소 짓다 목 위로 향 하다 여자 보다 고개 숙이다 둘 눈 마주치다',
#  '장갑 모자 다시 누르다 쓰다 시작 하다 은행 안 들어가다 수표 절대 챙기다',
#  '씬 은행 안',
#  '제법 사람 있다 은행 뒷문 들어오다 장갑 목 장갑 장갑 신호 따르다 청원경찰 쪽 고개 숙이다 채 다가가다 목 장갑 목 장갑 청원 경찰 뒤 다가가다 안 있다 쇠 파이프 꺼내다 팔꿈치 걸리다 당황 목 장갑 뒤 돌아서다 청원경찰 굳다 표정 바라보다 순간 퍽 하다 소리 목 장갑 앞 쓰러지다 청원경찰 의 아스 레 바라보다 은행강도 이 총 들다 서다 이 동시 창구 위로 훌쩍 뛰다 올라가다 은행강도',
#  '강도 총 꺼내다 들다 모두 엎드리다 움직이다 놈 죽이다 버리다',
#  '하다 천장 대고 총 쏜다',
#  '꺄악 비명 지르다 바닥 엎드리다 사람 속 장갑 목 장갑 바닥 엎드리다 채 서로 보다',
#  '목 장갑 바닥 엎드리다 채 형님 어떻다 되다 겁',
#  '장갑 바닥 엎드리다 채 내 알다 임마',
#  '목 장갑 우리 은행강도 잖다 그냥 당하다 있다 껍',
#  '장갑 그렇다 동업 하자 해보다 임마',
#  '강도 다가오다 선 조용하다 안해 죽다',
#  '겁 질린다 듯 바닥 얼굴 묻다 목 장갑 모습',
#  '씬 은행 앞',
#  '많다 경찰차 경찰 북적 거리 곳 걸다 들어오다 투캅스 하다 경찰 형사 알아보다 경례 하다 통과 하다 형사 뒤 걸어가다 최 형사 잡다 경찰 최 형사 경찰 증 보이 형사 뒤따르다 간다',
#  '형사 몇 명',
#  '경찰 두 놈 이다',
#  '형사 그렇다',
#  '경찰 인질 잡고 대치 이다 총 가지 있다',
#  '형사 최 형사 수준 차이 보여주다 자다 보다',
#  '하다 권총 뽑다 아들 건물 뒤 달려가다',
#  '씬 은행 안',
#  '엎드리다 사람 속 가방 두 개 들다 불안 스레 밖 보다 강도',
#  '소리 경찰 확성기 너희 완전하다 포위 돼다 무기 버리다 투항',
#  '강도 게',
#  '강도 씨발 어떻다 하다 장갑 툭툭 차다 일어나다',
#  '장갑 예 저',
#  '강도 죽다 싶다',
#  '장갑 벌떡 일어나며 아뇨 사실 우리 당신',
#  '강도 시끄럽다 장갑 뒷덜미 잡다 일으키다 머리 총 대보 비키다 안 하다 명 죽이다 버리다',
#  '장갑 겁 먹다 채 살리다 제 제발',
#  '목 장갑 이렇다 장갑 모습 보다 안도 한숨 내쉬다 뒷문 쾅 열다 들어오다 형사 총 들다 있다',
#  '형사 총 겨누 꼼짝 마',
#  '강도 장갑 머리 총 겨눈 채 총 버리다 죽이다 버리다',
#  '장갑 제발 살리다',
#  '형사 여기 미국인 줄 알 가짜 인지 알 있다',
#  '강도 가짜 알다',
#  '하다 천장 향 하다 총 쏜다 탕 총 맞다 깨지다 형광등 소리 놀라다 비명 지르다 사람 다가가다 형사 멈칫 하다 강도 인질 잡히다 장갑 완전 사색 되다 채 오줌 싸다 듯 바지 물 흘러내리다',
#  '강도 장난 보이다',
#  '형사 나다 장난 알다 임마 총 버리다',
#  '하다 천장 대고 총 쏘다 형사 탕 총 맞다 다른 형광등 깨지다 거의 실신 장갑 다리 풀리다 강도 이 힘겹다 부축 하다',
#  '형사 다음 니 머리 총 버리다',
#  '강도 다가오다',
#  '장갑 제발 살리다',
#  '형사 사건 따르다 때론 약간 희생 불가피하다 죄송하다',
#  '강도 거 미치다 놈 알다',
#  '형사 셋 둘 노리쇠 당기다 후',
#  '하다 순간 뒤 누군가 손 이형 사의 뒷덜미 내리다 치다 퍽 힘없다 바닥 쓰러지다 형사 뒤 보이다 목 장갑 모습',
#  '강도 총 겨누 넌 뭐',
#  '목 장갑 움찔 하다 총 좀 치우다 저 형 나다 원래',
#  '강도 알다 사이',
#  '목 장갑 예 사실 우리 은행 털리다 오다 형 들이다',
#  '강도 목 장갑 목 총 대고 개 소리 마 시간 없다 새꺄 따라오다',
#  '하다 끌 뒷문 쪽 나가다 문 앞 최 형사 버티고 서다',
#  '강도 뭐 비키다',
#  '하다 최 형사 위협 밀 가다 순간 장갑 부부 퍽 발 차고 장갑 앞 몸 숙이다 순간 강도 의 면상 그대로 주먹 갈기 최 형사 비틀 거리 강도 를 화려하다 발차기 퍼억 쓰다 뜨다 리 최 형사 익 놀란 듯 최 형사 총 겨누 강도',
#  '순간 더 빠르다 총 꺼내다 들다 최 형사 타 총성 어깨 총 맞다 뒤 튕겨나 강도 쾅 강도 의 총 허공 쏘다 순간 재빠르다 강도 덥다 최 형사 총 집다 들다 강도 의 손 밟다 최 형사 두둑 아악 비명 지르다 강도 최 형사 강도 의 손 철컥 수갑 채우다 모습 뒤 겁 질린다 채 옴짝 달싹 못 있다 장갑 부축 하다 빨 리도 기어 도망가다 목 장갑 등 우스 꽝 스레 보이다',
#  '씬 서장 실',
#  '선행 하다 박수 소리 속 최 사의 어깨 잎 파리 네 개 계급 달다 서장',
#  '서장 축하 하다 최 경사 경찰 사상 최고 빠르다 승진 기록',
#  '최 형사 감사하다 장님',
#  '편 박수 치다 경찰 속 이형 사의 모습 보이다',
#  '서장 여성 최초 강력 형사 반장 자다 해내다 수 있다',
#  '최 형사 주위 도와주다',
#  '서장 주위 보다 호통 치다 모두 들다 형사 반 앞 나이 어리다 여자 말 안 들다 짤 버리다 알다',
#  '경찰 힘차다 네',
#  '씬 달리다 차안',
#  '보조 석 앉다 형사 옆 운전 하다 최 형사',
#  '형사 보다 축하 하다 최 형사 제대로 되다 사람 올라가다 겸손하다 최 형사 운전 하다 하다 줄 모르다 이번 내 진 걸 인정 하다 최 형사 말 앞 해보다',
#  '최 형사 형사 반말 하다',
#  '형사 놀라다 뭐',
#  '최 형사 이전 상관 항상 반말 하다',
#  '형사 아니다 최 형사',
#  '최 형사 말 막다 나 위계 질서 강조 사람 형사 아니다 일 하다 동안 상사 로써 대우 하다 알다',
#  '형사 끓다 듯 바라보다',
#  '최 형사 만약 형사 평생 내 부하 일 하다 대답 안해 돼다',
#  '형사 바라보다 하다 예 써다',
#  '씬 대학교 정문',
#  '경례 하다 수위 뒤 하다 채 학교 들어가다 차',
#  '씬 강의실',
#  '여성 사회 지위 향상 등 쓰이다 칠판 앞 강의 하다 강사',
#  '강사 나라 과연 얼마만큼 진보 하다 알다 그 사회 여성 지휘 보다 되다 하다',
#  '하다 순간 문 벌컥 열다 들어오다 최 형사 웅성거리다 학생 보다 당황 하다 강사',
#  '강사 학생 잠깐 최 형사 다가가다 아니다 강의 하다 들어오다 어떡하다',
#  '하다 순간 곧장 강사 배 퍽 갈기 최 형사 말 하다 곧장 힘없다 앞 쓰러지다 강사 올리다 매다 최 형사',
#  '오다 어머 웅성거리다 학생',
#  '최 형사 강사 올리다 맨 채 오늘 강의 것 마치다 이상',
#  '하다 밖 나가다 최 형사',
#  '씬 다른 곳',
#  '공사 하다 건물 벽 손 발 벌린 채 묶이다 강사 버럭 버럭 고함 지르다',
#  '강사 당장 풀다 지난 번 보다 주다 또 무슨 짓 불법 감금 인권 유린 거 모르다 나가다 당장 고발 하다',
#  '하다 고함 지르다 강사 앞 뒤 돌아서다 형사',
#  '형사 다시 뒤 돌아서다 수 없다 잠시 기다리다',
#  '강사 이 여자 어디 가다 당장 데려오다',
#  '하다 선행 하다 최 사의 목소리',
#  '최 형사 크다 소리',
#  '휙 뒤 돌아보다 형사',
#  '형사 최 장님 우선 풀다 정식 절차 밟다',
#  '최 형사 커다랗다 가위 들다 보이 구 해오다',
#  '형사 질겁 하다 예 최 장님 설마',
#  '최 형사 다가가다 법 악 막 수 없다 힘 막다 돼다',
#  '형사 잡다 경찰 임무 아니다',
#  '최 형사 때론 범인 체포 범죄예방 더 중요하다',
#  '형사 안되다',
#  '강사 분위기 파악 못 채 지금 뭘 짜르 겠다',
#  '최 형사 뿌리치다 저런 놈 화장실 갈다 자격 없다 가위 높이 들다 비키다',
#  '강사 돼다 하다 제발 것',
#  '최 형사 가위 자크 자르다 뭘 잘못 하다 강간 게 아니다',
#  '형사 다시 잡다 최 장님',
#  '강사 여자 반항 하다 제 강간 하다 제 가슴 보다 상처 있다 제발 구속 시키다 제발',
#  '이렇다 강사 보다 형사 최 사의 모습',
#  '씬 달리다 차 안',
#  '운전 하다 최 형사 옆 앉다 형사',
#  '형사 최 장님',
#  '최 형사 왜',
#  '형사 사적 질문 하나 해도 괜찮다',
#  '최 형사 뭐',
#  '형사 혹시 가족 친척 중 아내 버리다 도망가다 남편 있다',
#  '최 형사 바라보다 지금 비거',
#  '형사 아뇨 그냥 물어보다 싶다',
#  '최 형사 없다',
#  '형사 그렇다 이전 남자 심하다 배신 적 있다',
#  '최 형사 그 전 내 먼저 물어보다 혹시 형사 가족 중 정신 이상자 없다',
#  '형사 바라보다 돼다',
#  '최 형사 제발 바보 같다 질문 하다 알다',
#  '씬 계곡',
#  '사람 없다 야산 추리 닝 차림 달리다 장갑 목 장갑',
#  '목 장갑 형님 언제 달리기 할껍',
#  '장갑 백 번 성공하다 것 한번 잡히다 않다 게 더 중요하다',
#  '목 장갑 전 잡히다 좋다 뭐 한번 성공 해봤다 좋다',
#  '장갑 새꺄 감방 들어가다 대통령 보다 몇 천억 있다 뭐 하다 써다 보지 못 인생 쫑쳤잖 임마',
#  '목 장갑 그 사람 달리기 하다 잡히다',
#  '장갑 씨발 놈 말 그렇다 거지 이 개새끼',
#  '하다 휙 주먹 휘두르다 피하 목 장갑 도망가다',
#  '장갑 어쭈 안',
#  '목 장갑 산 쪽 도망가다 또 팰라구',
#  '장갑 쫓아가다 안 때리다 새꺄 하나님 걸다 맹세 하다',
#  '목 장갑 도망가다 형 믿다 않다',
#  '장갑 바닥 돌 던지다 이 새끼 맹세 다니다 너 잡히다 죽다',
#  '하다 산 쪽 빠르다 도망가다 목 장갑 무언가 걸리다 듯 넘어지다 그 위로 덥다 장갑',
#  '장갑 손 두둑 꺽으 넘어지다 줄 알다 이 새끼',
#  '목 장갑 발 아래 보다 경악 스레 저기 저기',
#  '장갑 째다 쓰다 새꺄',
#  '위협 다가가다 장갑 목 장갑 겁 질린다 눈 발 아래 가리키다 곳 보다 나무 가지 속 누군가 팔이 터 나오다 비명 내 지르다 장갑 목 장갑 모습',
#  '타임 컷',
#  '패 트롤 카 사이렌 소리 속 카메라 빨갛다 불 뿜으 돌아가다 광등 경찰차 너머 이동 하다 검시관 등 북적 거리 사이 걸어가다 투캅스',
#  '목 머리 피 흘리다 채 죽다 여자 보다 다가가다 형사',
#  '형사 최 형사 보다 어디 하다 번 살펴보다',
#  '하다 여자 눈동자 살피다 목 깊이 패인 상처 보다',
#  '형사 목 살피 이렇다 잔인하다 놈 가위 하다 번 목 따다 칼 그으 오른쪽 왼쪽 깊이 차이나다 수 없다',
#  '검시관 크다 가위 보이 범행 현장 발견 되다 겁니다',
#  '형사 날카롭다 면 왼 쪽 있다 걸 보다 놈 왼손잡이',
#  '이렇다 형사 뒤 다가오다 바라보다 최 형사 형사 이번 목 난 피 스윽 닦다 입가 가져가다',
#  '형사 피 맛보다 하루 정도 지나다',
#  '검시관 혈 채취 저희 하다',
#  '최 형사 형사 그렇다 건 검시관 맡기다',
#  '하다 형사 보지 아무렇다 반응 없다',
#  '형사 이번 더 찌르다 대다 아니다 이틀 오늘 점심 뭘 먹다 장탕 어떻다',
#  '최 형사 뒤 팔 확 꺽으 하다 말 하다 죽다 사람 무슨 짓 당신 드라큐라 응',
#  '형사 이 사건 제 맡다 하다',
#  '최 형사 사건 맡다 하다 시체 주무르다 하다 죽다 사람 함부로 대해 되다 팔 꺽 채 이형 사의 얼굴 시체 밀치다 당장 사과 하다',
#  '형사 눈 뜨다 죽다 시체 얼굴 맞대다 채 죄송하다',
#  '최 형사 나 이 여자',
#  '형사 눈 뜨다 죽다 시체 코앞 보다 이 여자 요',
#  '최 형사 그렇다 해',
#  '형사 시체 보다 아가씨 미안하다',
#  '최 형사 더 크게',
#  '형사 시체 얼굴 맞대다 채 미안하다',
#  '씬 공사 건물 계단',
#  '공사 건물 계단 올라가다 투캅스',
#  '최 형사 여기다 왜 오다',
#  '사장 턱 넘다 최 사의 모습 위로 선행 하다',
#  '소리 정보원 여덟 아홉 열 번호 끝',
#  '씬 안',
#  '의아 표정 들어오다 최 형사 어깨 잔뜩 힘 들어가다 형사 앞 일렬 정열 하다 있다 인상 더럽다 정보원 경례 하다',
#  '정보원 추웅 성',
#  '형사 정보원 앞 걸다 오늘 내 제군 집합 시키다 이유',
#  '최 형사 형사 이 사람 뭐',
#  '형사 최 형사 저 하늘 믿다 따르다 정보원 들이다 정보원 우리 구역 발생 살인 사건 모두 알 것',
#  '형사 폼 잡고 오다 가다 말 하다 동안 정보원 쭉 둘러보다 최 형사 가운데 있다 하다 정보원 앞 서다',
#  '최 형사 너 이한구',
#  '정보원 왜 그렇다',
#  '최 형사 절도 특수강 합 전과 범 맞다',
#  '정보원 왜',
#  '최 형사 정보원 퍽 끄다 말 높이다 임마 나다 경찰 또 하다 명 발견 곤 너 강간 폭행 하다 김한일',
#  '정보원 그렇다 왜',
#  '최 형사 다시 퍽 끄다 말 높이',
#  '정보원 당황 듯 형사',
#  '최 형사 명 툭툭 치 강간 폭행 절도 관내 우범 자 모두 모이다 형사 이 뭐',
#  '형사 수갑 채우다 최 형사 잡다 지금 모두 손 씻다 제 정보원 하다 있다',
#  '최 형사 뭐 손 끊다 말 안되다 소리 하다 이렇다 놈 필요 없다 정보원 모두 해산 하다',
#  '어리둥절하다 정보원 웅성거리다 이형 사의 눈치 보다 형사 보다 어떻다 된거 등등 말 하다 웅성거리다 정보원',
#  '형사 정보원 무슨 수사 한단 말입 최 장님 현실 모르다',
#  '최 형사 범죄자 손잡다 하다 해산 하다 모두 연행 하다 하나 둘',
#  '정보원 형사 죄송하다 등 말 하다 가다',
#  '형사 정보원 모두 움직 이지마 최 형사 당신 정말 이렇다 식 하다 겁',
#  '최 형사 지금 항 하다',
#  '형사 화난 듯 예 써다',
#  '최 형사 하다 번 해보다',
#  '형사 가소롭다 듯 바라보다 허다 차다',
#  '하다 순간 날아오다 최 사의 주먹 맞다 자빠지다 형사 정보원 일제 형사 죄송하다 따위 말 하다 일순간 흩어지다 속 일어나다 형사',
#  '정보 경찰 신고 하다 되다 알다',
#  '정보 놔두다 지다 들다 끼리 싸우다 뭐',
#  '씬 무도관',
#  '텅빈 무도관 무도 복 차림 최 형사 앞 화려하다 예비 동작 몸 푸다 형사 멈추다 뒤 돌아서다',
#  '형사 여지 껏 여자 때리다 놈 한심하다 놈 없다 믿다 지금 예외 날 원망하다',
#  '최 형사 그렇다 말 끝나다 시작 하다',
#  '형사 선제 공격 하다 그 정돈 접다',
#  '최 형사 오해',
#  '형사 기합 내 지르다 햐',
#  '최 사의 빠르다 발 놀림 피하 형사 최 형사 내 뻗다 주먹 피하 엎 치기 하다 듯 가슴 팍 확 잡다 놀란 듯 멈칫 하다 바라보다 날아오다 최 사의 발차기 뒤 나자빠지다 다시 겨루기 하다 투캅스 이번 서로 공격 자다 막다 형사 주먹 최 사의 가슴 때리다 움찔 하다 어느새다 최 형사 퍼버벅 타 공격 해 뒤 나자빠지다 형사',
#  '형사 더 이상 보다',
#  '고함 지르다 최 형사 다시 겨루다 형사 사람 화려하다 공격 하다 간 서로 동시 발차기 맞다 넘어지다 동시 훌쩍 일어난다',
#  '난타 전 벌이다 도중 서로 지치다 상태 형사 최 사의 가슴 팍 때리다 최 형사 가슴 잡고 움찔 하다 힘껏 올라오다 발 이형 사의 사타구니 강타 하다 그 곳 맞다 채 완전하다 몸 굳다 형사 손 그 곳 가져가다 순간 최 사의 주먹 은 발차기 강타 하다',
#  '퍽 뒤 나자빠지다 형사',
#  '최 형사 것 상사 로써 아니다 여지 껏 여자 무시 대가 억울하다 소문 내다 다니다',
#  '하다 휙 돌아서다 최 형사 뒤 곳 만지다 웅크리다 있다 이형 사의 모습 속',
#  '씬 형사 집 방 안',
#  '화면 가득 멍 들다 눈 하다 형사 아버지 술 말다 있다 인상 쓸다 채 술 말다 잔 내려놓다 아버지',
#  '아버지 뭐 사표',
#  '형사 더 이상 스타일 구기다 다니다 수 없다',
#  '아버지 통수 때리다 임마 구기다 펴다 도망가다 어떻다 해 너 만약 최 사의 마수 벗어나다 수만 있다 뭐 지다 하다 수 있다',
#  '형사 예 뭐 요',
#  '아버지 그렇다 돼다 최 형사 애인 있다',
#  '형사 그 성격 남아나다 남자 있다',
#  '아버지 이르다 갈다 임마 들다 정 공법 남자 로써 접근 하다',
#  '형사 예',
#  '아버지 니 엄마 옛날 여장 부옇다 임마 리 주먹 나가다 나다 방 기절 하다 날 물레 방앗간 별 보다 하룻밤 보내다 난 뒤론 내 말 하다 고개 숙이다 예 그냥 방 바뀌다 더',
#  '형사 예 그렇다 최 형사 질겁 안되다',
#  '아버지 왜 돼다 임마 넌 결혼 하다 니 당하다 평생 복수 하다 살 수 있다',
#  '하다 없다 듯 아버지 보다 형사',
#  '형사 그냥 사표 쓰다 아버지',
#  '씬 경찰서',
#  '깔끔하다 정장 쫙 빼 입다 무스 뿌리다 채 걸어오다 형사 주변 형사 의아 하다 바라보다 가운데 최 사도 보다',
#  '형사 오다 형사 멋지다 오늘 선 보다',
#  '형사 아뇨 스타일 바꾸다 미소 괜찮다 최 장님',
#  '최 반장 무시 일어나며 자 모이다 조례 시작 하다 오늘',
#  '김 빠지다 형사 때 배달 기웃 거리 다가오다',
#  '배달 저 최 형사',
#  '최 형사 그렇다',
#  '배달 꽃 내미다 어떻다 남자 분 전화 주문 하다 서류 내미다 여기 사인 좀',
#  '형사 오다 죽이다 아침 꽃 선물 받다',
#  '형사 너스레 최 장님 좋다',
#  '최 형사 배달 인사 하다 가면 재채기 꽃 휴지통 확 내다',
#  '최 형사 아이 증말 어떻다 놈 꽃 알레르기 있다 사람 죽다 뭐 아침 재수없다 에취',
#  '이렇다 최 형사 보다 인상 쓸다 채 고개 돌리다 형사',
#  '씬 달리다 차 안',
#  '부드럽다 음악 흐르다 속 운전 하다 형사 옆 앉다 최 형사',
#  '형사 날씨 정말 좋다 이렇다 날 산 강 쫘악 펼쳐지다 야외 드라이브 가면 끝내주다 안 그렇다',
#  '최 형사 재채기 인상 쓰다 형사 향수 뿌리다',
#  '형사 네 어떻다',
#  '최 형사 창문 열 갑자기 왜 하다 짓 하다 그렇다 나 토 하다 하다',
#  '씬 골목',
#  '작다 골목 꽃집 건너편 멈추다 서다 투캅스 차',
#  '씬 차 안',
#  '정차 하다 차 운전 하다 형사 옆 앉다 최 형사',
#  '최 형사 놀란 듯 그게 사실',
#  '형사 예 확실하다 정보원 제보 이다 현재 선 가장 유력하다 용의자 이다',
#  '최 형사 어떻다 놈',
#  '형사 꽃집 가리키다 저기 저 놈 이다',
#  '하다 보다 험악하다 생기다 놈 크다 가위 들다 꽃 가지 치다 대고 있다',
#  '형사 바람 피우다 마누라 잠들다 순간 가위 목 따다 살인 얼마 전 추다 하다 항상 가위 들다 가방 들다 다니다 하다',
#  '최 형사 그렇다 나가다 그렇다 잡다',
#  '형사 잡다 지금 체포 하다 안되다 확실하다 물증 잡다',
#  '씬 꽃집',
#  '형사 장미 가리키다 용의자 장미 빼다 가위 자르다 뒷쪽 포장 하다 동안 하다 켜다 놓다 가방 다가가다 형사 몰래 가방 옆 쪽 작다 기계 부착 하다 보다 용의자 눈 마주치다 윙크 하다 형사 고개 끄덕 장미 포장 하다 용의자',
#  '씬 차 안',
#  '들어오다 형사 꽃 최 형사 건네다',
#  '형사 설치 하다',
#  '최 형사 재채기 하다 에취 고개 돌리다 채 저리 치우다',
#  '타임 컷',
#  '어느덧다 밤 되다 거리 바라보다 앉다 최 형사 꽃 가게 불 켜다 있다 하다 여자 용의자 웃음 교환 하다 용의자 나오다 가게 불 끄다 용의자 보다 졸다 형사 툭툭 치다 최 형사',
#  '최 형사 놈 움직이다',
#  '형사 졸다 깨선 시동 걸 저 보다',
#  '씬 러브 텔 안',
#  '망원경 보이다',
#  '여자 속옷 가위 자르다 용의자',
#  '소리 꼭 하다 돼다',
#  '소리 난 가위 없다 흥분 돼다',
#  '소리 키스 하다 오빠 속옷 사 주다 돼다',
#  '불 꺼지다 방안 망원경 건너편 바라보다 있다 최 형사 소형 카세트 조작 하다 형사',
#  '최 형사 다가오다 선 이렇다 건 언제 구 하다',
#  '형사 항상 비상 용 가지 다니다 망원경 뺏다 젠 내 감시 하다',
#  '최 형사 다시 뺏다 보다 뭘 보다',
#  '뽀뽀 하다 소리 여자 간드러지다 소리 신음 소리 바뀌다 형사 최 형사 서로 눈 마주치다 뒤 물러나다 앉다',
#  '최 형사 이제 끄다',
#  '형사 끄다',
#  '최 형사 계속 들리다',
#  '형사 도청기 소리 아니다',
#  '양 쪽 벽 들리다 여자 신음 소리 어색하다 듯 일어나다 최 형사 방 둘러보다 다시 앉다 형사 이렇다 최 형사 보다 침대 하다 켜다 걸터 앉다 투캅스 옆방 들리다 신음 소리 속 침대 양 구석 서로 앉다 있다 어색하다 듯 일어나다 형사',
#  '형사 티브이 켜다 요',
#  '최 형사 재빠르다 그렇다 그게 좋다',
#  '형사 앞쪽 티브이 켜다 다시 앉다 티브이 애로 영화 숨가쁘다 진행중 투캅스 그렇다 티브이 보다 다시 눈 마주치다',
#  '최 형사 시비쪼 뭐 하다 끄다',
#  '형사 보다 겁',
#  '최 형사 보다 뭘 보다 나다 보다',
#  '최 형사 말 보다 이상하다 듯 다시 형사 눈 마주치다',
#  '형사 그렇다 보다 요 특별하다 하다 것 없다',
#  '최 형사 그렇다 알다 해',
#  '하다 다시 화면 보다 더 육감 살결 오가다 옆방 소리 점점 고조 되다 있다 투캅스 서로 티브이 보지 않다 척 고개 거리 면서 화면 보다 침 꿀꺽 삼키다 소리 과장 들리다 점점 극 달 하다 화면 형사 이렇다 티브이 보다 최 형사 보다',
#  '형사 음료수 들다',
#  '최 형사 돼다',
#  '형사 혹시 제 필요하다 일 없다',
#  '최 형사 없다',
#  '형사 콜라 캔 뒤 마구 흔들다 뒤 최 형사 쪽 따다 순간 뿜어져 나오다 거품 최 사의 옷 덥다 치다',
#  '형사 이렇다 최 사의 옷 닦다 닦다',
#  '최 형사 이형 사의 손 닦다 괜찮다 돼다',
#  '형사 괜찮다 긴요 휴지 론 안되다 벗다 얼룩지다 전 닦다 오다',
#  '최 형사 여기 벗다 구',
#  '형사 뭐 어떻다 동료 끼리 일 하다 보다 그렇다 수도 있다',
#  '최 형사 돼다 내 옷 형사 왜 맡기다 형사 옷 신경 써다',
#  '형사 옷 보다 이렇다 나다 엉망 이군',
#  '하다 웃통 벗다 최 형사 앞 근육 질의 몸 으쓱 하다 보이다 최 형사 다가오다 진지하다 표정 바라보다',
#  '형사 최 형사',
#  '최 형사 왜 그렇다',
#  '형사 다시 으쓱 하다 살다보면 때론 이성 본능 충실하다 싶다 때 있다 않다',
#  '최 형사 무슨 말 싶다',
#  '형사 다시 묻다 전 마음 준비 돼다 있다 편하다 대답 하다 정말 저 원하다 거 없다',
#  '최 형사 있다',
#  '형사 다가오다 뭡',
#  '최 형사 보기 흉하다 벌겋다 벗다 다니다 욕실 가다 벗다',
#  '형사 활짝 미소 예 써다 가다가 뒤 돌아보다 비디오 보고 계시다 샤워 얼른 나오다',
#  '형사 욕실 들어가다 불 꺼지다 건너편 방 보다 최 형사 소형 카세트 작동시키다 계속 여자 신음 소리 들리다',
#  '씬 건너편 모텔 방',
#  '규칙 반동 주다 삐 덕 거리 불다 방 침대 떨어지다 앉다 있다 용의자 여자 가방 앞 두다 신음 소리 내다 있다',
#  '여자 작다 목 아프다 작다 언제 래야 돼다',
#  '용의자 건너편 불다 방 보다 작다 조금 더 해',
#  '여자',
#  '하다 순간 문 박차다 들어오다 최 형사',
#  '최 형사 총 겨눈 채 꼼짝 마',
#  '하다 보다 용의자 여자 침대 걸터 앉다 손 들다',
#  '씬 모텔 방 안',
#  '문 열다 들어오다 최 형사 방안 보다 형사 팬티 입다 채 침대 점프 듯 눕다',
#  '형사 고통스럽다 신음 소리 내미다 어디 가다 오다',
#  '최 형사 왜 그렇다',
#  '형사 엎어지다 누운 채 목욕탕 밉다 끌다 겹 질린다 것 같다',
#  '최 형사 다가오다 그렇다 내 치료 하다 주다',
#  '형사 그렇다 주다',
#  '최 형사 어깨 만지다 쪽',
#  '형사 아뇨 약간 더 아래',
#  '하다 순간 이형 사의 두 팔 확 꺽 늘다 최 형사',
#  '형사 고통스럽다 듯 왜 이르다',
#  '하다 돌아보다 문 앞 용의자 여자 고개 숙이다 채 서다',
#  '형사',
#  '하다 순간 더 세다 팔 꺽 늘다 최 형사 이형 사의 등짝 손바닥 찌 리나 때리다 흐윽 벌겋다 손 자국 남다 등짝 굳다 표정 비명 지르다 형사',
#  '최 형사 일어나다',
#  '형사 자 하다',
#  '하다 순간 이형 사의 면상 쩌억 정통 강타 하다 최 사의 손바닥',
#  '뒤 나자빠지다 침대 떨어지다 형사 보다 겁 질린다 용의자 여자 슬금슬금 문밖 도망치다',
#  '최 형사 아침 꽃 보내다 것 너',
#  '형사 멍 채 고개 끄덕 사실 제',
#  '최 형사 어느새다 이형 사의 등짝 발 내리다 꽂다 필요없다 하루 종일 공무 집행 방해 상사 성희롱 하다 구 해',
#  '형사 바닥 완전 퍼지다 채 잠깐 잠깐',
#  '최 형사 흥 당장 사표 구속 시키다 수도 있다 내 성질 맞다 아깝다 옷벗다 싶다 하다 따르다',
#  '하다 이형 사의 머리 잡다 일으키다',
#  '형사 아니다 최 형사',
#  '최 형사 퍼억 이형 사의 배 주먹 꽂다 시끄럽다 확실하다 버릇 고치다',
#  '씬 거리',
#  '지나가다 사람 키키 덕 거리 웃다 곳 보다 운전 하다 있다 최 사의 차 미러 연결 되다 수갑 손목 찬 채 팬티 차림 빠르다 쫓아가다 형사 등짝 얼굴 멍 들다 손짓 하다 키키 덕 거리 사람 시선 피하 창문 두 기도 하다 속 무표정 하다 운전 하다 최 형사',
#  '형사 난감하다 듯 고개 숙이다 가다 사람 많다 곳 점점 속도 줄이다 차 화려하다 네온사인 속 조명 받다 형사 이렇다 형사 바라보다 최 사의 모습 위로 들리다',
#  '무전 여기다 여기다',
#  '씬 강변 곳',
#  '누군가 손 가운 벗기다 목 상처 입다 발가벗기다 채 눈 뜨다 죽다 여자 시체 모습 뒤 최 형사 살펴보다 뒤 최 형사 이글거리다 증오 감속 바라보다 형사',
#  '최 형사 휙 뒤 돌아보다 공과 사도 구분 하다 일 하다 당장 사표 써다 불명예 퇴직 시키다',
#  '형사 좋다 일단 사건 해결 보다',
#  '하다 시체 옆 다가가다 형사 눈 뜨다 죽다 시체 목 난 상처 살피다',
#  '형사 같다 놓다 하다 간 시체 얼굴 가까이 다가가다 냄새 맡다',
#  '최 형사 뒤 다가오다 또 뭐 하다',
#  '형사 휙 뒤 돌아보다 그냥 보다 것 안되다 또 사과 하다 요 다시 시체 대고 장난 스레 아가씨 미안하다 응 미안하다',
#  '하다 최 형사 노려보다 지나치다 형사',
#  '씬 경찰서 사무실',
#  '피곤하다 듯 하품 쩍쩍 해대 형사 호통 있다 최 형사',
#  '최 형사 도대체 뭘 하다 겁 몇 일 야근 걸 갖다 벌써 지치다 어떻다 해',
#  '형사 이 보다 최 반장 집 좀 가다 속옷 좀 갈아입다',
#  '이렇다 형사 앞 전화기 붙잡다 있다 어딘가 통화 있다',
#  '형사 수화기 들다 채 그렇다 사체 발견 되다 화학 약품 없다 분명 이상하다 냄새 나다 요',
#  '이 동시 뒷모습 보이다 최 형사 등 모습',
#  '최 형사 범인 잡기 전 집 들어가다 생각 말다 알다',
#  '형사 예',
#  '형사 고개 돌리다 채 작다 정말 악질 악질',
#  '형사 수화기 들다 채 조사 안 뭐 하다 겁 일 좀 하다',
#  '하다 수화기 끊다 최 형사 등 형사 바라보다',
#  '형사 왜 그렇다',
#  '형사 아니다 하다 다시 전화 버튼 누르다',
#  '최 형사 박수 탁탁 치 자 그렇다 모두 힘내다',
#  '형사 모두 등 한숨 쉬 일어난다',
#  '형사 도대체 몇 일 이르다 밖 우리 마누라 보다 알다 보다 젠장',
#  '형사 전 집 제대로 찾아가다 수 있다 지다 모르다',
#  '하다 나가다 형사',
#  '형사 수화기 들다 예 경찰 이다 가지 물어 볼 게 있다',
#  '때 제복 입다 경찰 지나가다 휙 뒤 돌아보다 형사',
#  '형사 벌떡 일어나며 잠깐 잠깐',
#  '여경 뒤 돌아보다 예 저 말',
#  '형사 다가가다 머리카락 킁킁거리다 흠 흠',
#  '여경 왜 이르다',
#  '형사 이 무슨 냄새 응 흠 흠',
#  '여경 움찔 하다 물러나다 왜 어제 파마 하다 왜 그렇다',
#  '최 형사 다가서다 왜 그렇다',
#  '형사 진지하다 표정 미용실 피해자 모두 파 마약 냄새 나다 가다',
#  '하다 나가다 형사 뒤 쫓아가다 최 사의 모습',
#  '씬 미용실 안',
#  '여자 머리 지고 있다 하다 생기다 커트 김 옆 서다 형사 최 형사 대기 하다 여자 손님 다음 피해자 과 종업원 보다',
#  '커트 김 사진 건네주다 처음 보다 얼굴 끄다',
#  '형사 친구 통해 이 미용실 자주 오다 거 알 있다 다시 하다 번 보다',
#  '커트 김 글세 모르다 하다 간 어떻다 사진 보다 잠깐 이 언니 이 미용실 아니다 잠깐 나오다',
#  '하다 투캅스 데리 밖 나가다',
#  '씬 밖 복도',
#  '가게 안이 보이지 않다 코너 서다 미용사 투캅스',
#  '커트 김 이 여자 모두 여기 단골 건 사실 이다 정말 우리 가다 아무렇다 상관없다 이렇다 불미 일 우리 가게 어떻다 건 관련 되다 알려지다 우린 끝장 종이 내미다 여기 나 뿐 아니다 우리 애 연락처 있다 협조 필요하다 영업 마치 오다 표정 바꾸다 그게 아니다 영장 가지 오시 요 그렇다',
#  '하다 안 들어가다 버리다 커트 김 형사 뒤 쫓아가다 하다 최 형사 붙잡다',
#  '최 형사 그만두다',
#  ...]

# %%
list(model.wv.key_to_index)
# Out:
# ['형사',
#  '하다',
#  '최',
#  '장갑',
#  '보다',
#  '있다',
#  '씬',
#  '놈',
#  '목',
#  '뒤',
#  '채',
#  '안',
#  '사의',
#  '들다',
#  '이',
#  '여자',
#  '그렇다',
#  '총',
#  '듯',
#  '속',
#  '소리',
#  '경찰',
#  '유괴',
#  '차',
#  '되다',
#  '다시',
#  '사람',
#  '범',
#  '손',
#  '바라보다',
#  '모습',
#  '잡다',
#  '없다',
#  '뭐',
#  '앞',
#  '왜',
#  '순간',
#  '이렇다',
#  '과장',
#  '내',
#  '알다',
#  '말',
#  '고개',
#  '문',
#  '돼다',
#  '저',
#  '가다',
#  '다가가다',
#  '투캅스',
#  '임마',
#  '이형',
#  '그',
#  '아니다',
#  '버리다',
#  '서다',
#  '예',
#  '들어오다',
#  '맞다',
#  '보이다',
#  '보스',
#  '지르다',
#  '죽다',
#  '옆',
#  '다가오다',
#  '어떻다',
#  '들어가다',
#  '등',
#  '나가다',
#  '두목',
#  '몸',
#  '겁',
#  '곳',
#  '꼴통',
#  '거',
#  '오다',
#  '더',
#  '우리',
#  '도망가다',
#  '미용',
#  '다른',
#  '강사',
#  '운전',
#  '편',
#  '가위',
#  '앉다',
#  '죽이다',
#  '내미다',
#  '아줌마',
#  '일',
#  '향',
#  '돈',
#  '것',
#  '돌아보다',
#  '나오다',
#  '달려가다',
#  '아이',
#  '수',
#  '꺼내다',
#  '정보원',
#  '제',
#  '강도',
#  '이다',
#  '회장',
#  '빠르다',
#  '두',
#  '표정',
#  '일어나다',
#  '사장',
#  '치다',
#  '좋다',
#  '달리다',
#  '때',
#  '아버지',
#  '받다',
#  '좀',
#  '가방',
#  '나',
#  '번',
#  '주먹',
#  '서로',
#  '모두',
#  '않다',
#  '거리',
#  '열다',
#  '공격',
#  '트레일러',
#  '휙',
#  '같다',
#  '응',
#  '확',
#  '남자',
#  '위로',
#  '눈',
#  '안되다',
#  '칼',
#  '멈추다',
#  '나다',
#  '집',
#  '대다',
#  '얼굴',
#  '바닥',
#  '먹다',
#  '비명',
#  '끼',
#  '무슨',
#  '엄마',
#  '게',
#  '경찰서',
#  '도굴',
#  '머리',
#  '또',
#  '곧장',
#  '방',
#  '어깨',
#  '인상',
#  '전',
#  '작다',
#  '난',
#  '줄',
#  '부하',
#  '애',
#  '지금',
#  '알',
#  '도로',
#  '건달',
#  '주다',
#  '밖',
#  '정말',
#  '너',
#  '쪽',
#  '해',
#  '놓다',
#  '때리다',
#  '이번',
#  '퍽',
#  '김',
#  '들리다',
#  '새꺄',
#  '아가리',
#  '모르다',
#  '말다',
#  '쏘다',
#  '중국말',
#  '죄송하다',
#  '발',
#  '아래',
#  '내리다',
#  '하나',
#  '쓰다',
#  '서장',
#  '침대',
#  '돌아서다',
#  '돌리다',
#  '놀란',
#  '지다',
#  '팔',
#  '보고',
#  '뜨다',
#  '질린다',
#  '살리다',
#  '꺽',
#  '숙이다',
#  '도대체',
#  '커트',
#  '쾅',
#  '오늘',
#  '덥다',
#  '내다',
#  '이르다',
#  '위',
#  '열리다',
#  '자다',
#  '당장',
#  '자식',
#  '떨어지다',
#  '양복',
#  '거기',
#  '걸',
#  '씨발',
#  '강',
#  '그만두다',
#  '박사',
#  '실',
#  '사이',
#  '이익',
#  '요',
#  '걸어가다',
#  '박살',
#  '창문',
#  '박수',
#  '시키다',
#  '쓰러지다',
#  '노려보다',
#  '괜찮다',
#  '미소',
#  '달려오다',
#  '해보다',
#  '동시',
#  '화면',
#  '나자빠지다',
#  '싶다',
#  '용의자',
#  '여기',
#  '켜다',
#  '끄다',
#  '짓',
#  '살피다',
#  '리',
#  '운동',
#  '크다',
#  '간다',
#  '금고',
#  '대고',
#  '조폭',
#  '제발',
#  '전경',
#  '주변',
#  '골목',
#  '차림',
#  '따르다',
#  '모이다',
#  '아뇨',
#  '막다',
#  '시체',
#  '형님',
#  '개',
#  '입다',
#  '많다',
#  '때문',
#  '미용실',
#  '생각',
#  '한번',
#  '그냥',
#  '지나치다',
#  '날',
#  '건',
#  '두다',
#  '잡히다',
#  '피하',
#  '니',
#  '들이다',
#  '당신',
#  '신음',
#  '밀치다',
#  '새끼',
#  '술',
#  '불',
#  '간',
#  '지나가다',
#  '보지',
#  '박스',
#  '놀라다',
#  '사실',
#  '박찬호',
#  '수갑',
#  '벗다',
#  '종업원',
#  '다니다',
#  '의',
#  '선',
#  '사과',
#  '써다',
#  '건물',
#  '휘두르다',
#  '화려하다',
#  '어느새다',
#  '점점',
#  '움찔',
#  '멱살',
#  '어디',
#  '던지다',
#  '남편',
#  '장님',
#  '검시관',
#  '갑자기',
#  '중년',
#  '옷',
#  '고함',
#  '정도',
#  '쫓아가다',
#  '잠깐',
#  '익',
#  '쓸다',
#  '보이',
#  '몇',
#  '올라가다',
#  '가득',
#  '못',
#  '아저씨',
#  '선행',
#  '올리다',
#  '가지',
#  '마',
#  '겨누',
#  '고맙다',
#  '스레',
#  '난간',
#  '입',
#  '누구',
#  '라면',
#  '넘어지다',
#  '정문',
#  '찬',
#  '선배',
#  '버스',
#  '음악',
#  '꼼짝',
#  '아지트',
#  '차안',
#  '가리키다',
#  '멈칫',
#  '발견',
#  '곤',
#  '끌다',
#  '바꾸다',
#  '두둑',
#  '강간',
#  '웨이터',
#  '시위',
#  '누군가',
#  '전화',
#  '쌕',
#  '부러지다',
#  '책상',
#  '잡고',
#  '자기',
#  '은행',
#  '년',
#  '풀다',
#  '엎드리다',
#  '빠지다',
#  '마구',
#  '채우다',
#  '시오',
#  '경찰차',
#  '이제',
#  '넌',
#  '사건',
#  '누르다',
#  '패',
#  '계속',
#  '사표',
#  '이야기',
#  '발차기',
#  '명',
#  '네',
#  '완전하다',
#  '구',
#  '바로',
#  '사도',
#  '자',
#  '어딨다',
#  '짓다',
#  '걸리다',
#  '쟈켓',
#  '날리다',
#  '해주다',
#  '졸다',
#  '둘',
#  '열',
#  '꽃',
#  '룸',
#  '돌아가다',
#  '인사',
#  '수건',
#  '뒷문',
#  '파이프',
#  '불다',
#  '쇠',
#  '석',
#  '사무실',
#  '구조대',
#  '시작',
#  '따다',
#  '집다',
#  '카메라',
#  '강타',
#  '먼저',
#  '벌떡',
#  '햄버거',
#  '절대',
#  '데리',
#  '날아오다',
#  '총알',
#  '마주치다',
#  '왕복',
#  '자네',
#  '재빠르다',
#  '만들다',
#  '매달리다',
#  '벽',
#  '치',
#  '스포츠카',
#  '티브이',
#  '뭘',
#  '마약상',
#  '눈치',
#  '일어나며',
#  '자르다',
#  '닦다',
#  '짜다',
#  '어색하다',
#  '따위',
#  '정신',
#  '피',
#  '일제',
#  '흔들다',
#  '뒤따르다',
#  '거의',
#  '올라오다',
#  '버럭',
#  '상처',
#  '세',
#  '중요하다',
#  '선동렬',
#  '지치다',
#  '낚아채다',
#  '건너편',
#  '뛰어내리다',
#  '계단',
#  '폼',
#  '늘다',
#  '숨다',
#  '기도',
#  '다음',
#  '젠장',
#  '귀',
#  '맡다',
#  '울리다',
#  '위해',
#  '미안하다',
#  '명의',
#  '당황',
#  '뻗다',
#  '그게',
#  '여',
#  '핸드폰',
#  '파트너',
#  '데',
#  '제법',
#  '스치다',
#  '아무',
#  '당기다',
#  '굳다',
#  '악',
#  '하루',
#  '도둑',
#  '점프',
#  '힘없다',
#  '흠',
#  '차다',
#  '하자',
#  '걱정',
#  '배',
#  '걸다',
#  '방해',
#  '가버리다',
#  '안해',
#  '화난',
#  '혼자',
#  '가슴',
#  '테이블',
#  '여기다',
#  '형',
#  '반장',
#  '상사',
#  '얼마',
#  '창밖',
#  '넘어가다',
#  '구형',
#  '를',
#  '휘청거리다',
#  '가져가다',
#  '긴장',
#  '가게',
#  '바람',
#  '살다',
#  '기다',
#  '아가씨',
#  '면상',
#  '역시',
#  '가운데',
#  '겨눈',
#  '믿다',
#  '겁니다',
#  '성공하다',
#  '냄새',
#  '웃다',
#  '적',
#  '다리',
#  '제대로',
#  '움직이다',
#  '오케이',
#  '젖히다',
#  '대신',
#  '당하다',
#  '볼펜',
#  '툭툭',
#  '축하',
#  '승진',
#  '울다',
#  '우두둑',
#  '휘둥그레지다',
#  '은행강도',
#  '시선',
#  '가져오다',
#  '병',
#  '싸우다',
#  '따라오다',
#  '갈다',
#  '나쁘다',
#  '한숨',
#  '빼다',
#  '비실',
#  '완전',
#  '아깝다',
#  '수화기',
#  '일단',
#  '너머',
#  '끄덕',
#  '위험하다',
#  '덤비다',
#  '범인',
#  '혹시',
#  '구기다',
#  '체포',
#  '증',
#  '퍼버벅',
#  '눕다',
#  '야구',
#  '질',
#  '의자',
#  '학교',
#  '허겁지겁',
#  '남다',
#  '인간',
#  '걸어오다',
#  '바뀌다',
#  '법',
#  '뒷덜미',
#  '손님',
#  '나서다',
#  '최고',
#  '미용사',
#  '션',
#  '클락',
#  '더럽다',
#  '떨구다',
#  '물',
#  '울먹이다',
#  '힘',
#  '공사',
#  '해오다',
#  '쿵',
#  '부닥치다',
#  '급회전',
#  '뛰다',
#  '너희',
#  '소원',
#  '살',
#  '치우다',
#  '훌쩍',
#  '비키다',
#  '잘못',
#  '유리',
#  '지갑',
#  '꾼',
#  '장난',
#  '드리다',
#  '뭔가',
#  '동안',
#  '부축',
#  '위협',
#  '조물',
#  '방안',
#  '오해',
#  '그대로',
#  '만지다',
#  '깨지다',
#  '통수',
#  '아침',
#  '밀다',
#  '학생',
#  '커다랗다',
#  '끝',
#  '어리다',
#  '짐',
#  '멋지다',
#  '긁다',
#  '뿌리치다',
#  '뛰어들다',
#  '커피',
#  '주머니',
#  '안심',
#  '해결',
#  '듯이',
#  '세우다',
#  '일으키다',
#  '갈기',
#  '기다리다',
#  '오가다',
#  '찌르다',
#  '아주머니',
#  '구속',
#  '달',
#  '미치다',
#  '달다',
#  '거실',
#  '언제',
#  '묶이다',
#  '보조',
#  '턱',
#  '항상',
#  '웅성거리다',
#  '서류',
#  '개월',
#  '벌컥',
#  '로써',
#  '삐',
#  '이상',
#  '덕',
#  '뛰어넘다',
#  '어쭈',
#  '쏜다',
#  '마치',
#  '반말',
#  '중',
#  '사진',
#  '싸움',
#  '자신',
#  '보이지',
#  '대치',
#  '코피',
#  '손가락',
#  '대형',
#  '내쉬다',
#  '탕',
#  '싫다',
#  '온',
#  '질겁',
#  '분위기',
#  '스윽',
#  '쳐다보다',
#  '계시다',
#  '입구',
#  '배달',
#  '증말',
#  '확실하다',
#  '올려놓다',
#  '속옷',
#  '양',
#  '잡',
#  '뒷모습',
#  '폭력',
#  '캔',
#  '밟다',
#  '콜라',
#  '출발',
#  '밤',
#  '등짝',
#  '근처',
#  '널',
#  '나가떨어지다',
#  '끝나다',
#  '쫓다',
#  '붙잡다',
#  '사내',
#  '멍',
#  '리치',
#  '물러나다',
#  '터',
#  '머리카락',
#  '팍',
#  '그녀',
#  '다가서다',
#  '저기',
#  '쥐다',
#  '사이렌',
#  '여유',
#  '볼',
#  '나타나다',
#  '달려들다',
#  '타다',
#  '몰다',
#  '이유',
#  '척',
#  '구경',
#  '손목',
#  '날아가다',
#  '뻥',
#  '기자',
#  '수사',
#  '치기',
#  '룸싸롱',
#  '놓이다',
#  '생기다',
#  '밀',
#  '늘어지다',
#  '북적',
#  '축',
#  '젖다',
#  '움켜쥐다',
#  '피해자',
#  '심하다',
#  '꽉',
#  '뭐라다',
#  '엉망',
#  '린다',
#  '나무',
#  '만약',
#  '뒤지다',
#  '차갑다',
#  '녜',
#  '챙기다',
#  '총구',
#  '모처럼',
#  '몰래',
#  '넣다',
#  '뺨',
#  '시간',
#  '잖다',
#  '세상',
#  '한마디',
#  '신고',
#  '키우다',
#  '잔',
#  '고수부지',
#  '헤엄',
#  '오토바이',
#  '자막',
#  '금방',
#  '어둠',
#  '빼앗다',
#  '처리',
#  '며',
#  '달라',
#  '물어보다',
#  '발생',
#  '밉다',
#  '호텔',
#  '빼',
#  '지선',
#  '시끄럽다',
#  '어제',
#  '좌우',
#  '끼다',
#  '거짓말',
#  '허다',
#  '자꾸',
#  '마당',
#  '뭡',
#  '맨',
#  '날카롭다',
#  '어떡하다',
#  '불빛',
#  '힘겹다',
#  '다시다',
#  '감사하다',
#  '험악하다',
#  '아파트',
#  '지은',
#  '뒹',
#  '담',
#  '섹스',
#  '서고',
#  '얼른',
#  '꾸벅',
#  '돌려주다',
#  '찌다',
#  '기대다',
#  '마스크',
#  '겁나다',
#  '목숨',
#  '방아쇠',
#  '튀어',
#  '서서',
#  '어지럽다',
#  '박차다',
#  '사격',
#  '망',
#  '특유',
#  '훔치다',
#  '털다',
#  '헬멧',
#  '팰',
#  '쫓아오다',
#  '후진',
#  '달리',
#  '경쾌하다',
#  '누가',
#  '타이틀',
#  '마약',
#  '내려놓다',
#  '씩씩하다',
#  '마시다',
#  '바라다',
#  '가볍다',
#  '포장마차',
#  '한심하다',
#  '아프다',
#  '관내',
#  '손잡이',
#  '요청',
#  '휴지통',
#  '전과',
#  '궤짝',
#  '길',
#  '진짜',
#  '치켜들다',
#  '보여주다',
#  '대의',
#  '졸업',
#  '감다',
#  '인생',
#  '저으',
#  '질리다',
#  '고생',
#  '끼어들다',
#  '표창장',
#  '기록',
#  '깨다',
#  '웃통',
#  '피다',
#  '조용하다',
#  '끄덕이다',
#  '우산',
#  '만원',
#  '청진기',
#  '금',
#  '밑',
#  '떨다',
#  '휴일',
#  '치면',
#  '누굴',
#  '희다',
#  '사랑',
#  '어딘가',
#  '변하다',
#  '요즘',
#  '흥분',
#  '모으다',
#  '인정',
#  '풍구',
#  '환',
#  '자고',
#  '넘기다',
#  '비',
#  '초인종',
#  '탁',
#  '식이',
#  '뺑',
#  '관',
#  '일이',
#  '가득하다',
#  '회사',
#  '무시',
#  '면허증',
#  '면허',
#  '몇몇',
#  '멀어지다',
#  '친구',
#  '수석',
#  '빵빵',
#  '쓰다듬다',
#  '막히다',
#  '안고',
#  '푹',
#  '핫팬츠',
#  '빈',
#  '별',
#  '땐',
#  '안내',
#  '달리기',
#  '살피',
#  '측정기',
#  '브레이크',
#  '핸드백',
#  '새롭다',
#  '이란',
#  '갈리다',
#  '굳어지다',
#  '깡패',
#  '여러',
#  '천원',
#  '병신',
#  '덮다',
#  '쉬다',
#  '꿈',
#  '함부로',
#  '어이',
#  '사회',
#  '마르다',
#  '도',
#  '빛',
#  '사체',
#  '갖다',
#  '제일',
#  '번번하다',
#  '처음',
#  '보내다',
#  '천장',
#  '묻다',
#  '경례',
#  '혼잣말',
#  '복종',
#  '인질',
#  '겨우',
#  '분명하다',
#  '군',
#  '차기',
#  '급하다',
#  '형광등',
#  '바지',
#  '텅빈',
#  '접다',
#  '빠져나가다',
#  '때론',
#  '의아',
#  '몽둥이',
#  '음',
#  '물어',
#  '붙다',
#  '친',
#  '엎어지다',
#  '장미',
#  '범의',
#  '전화기',
#  '감봉',
#  '괜',
#  '꽃집',
#  '에취',
#  '뿌리다',
#  '재채기',
#  '플랭카드',
#  '청원경찰',
#  '차례',
#  '가면',
#  '불안하다',
#  '울상',
#  '기합',
#  '가요',
#  '약간',
#  '후',
#  '해산',
#  '쓰이다',
#  '이전',
#  '빨갛다',
#  '컷',
#  '타임',
#  '산',
#  '문신',
#  '개새끼',
#  '야산',
#  '한참',
#  '돌다',
#  '식',
#  '하품',
#  '강의',
#  '벌린',
#  '따라가다',
#  ...]

# %%
################ 테스트 ##########################################

model.wv.most_similar(positive=["경찰"])    #경찰과 가장 가까운 단어는?
model.wv.most_similar(positive=["여자"])    #여자와 가장 가까운 단어는?
model.wv["장갑"]                            #장갑의 데이터 임베딩
model.wv["유괴"]                            #유괴의 데이터 임베딩
model.wv.most_similar(positive=["경찰","유괴"] , negative=["여자"])    #경찰 + 유괴 - 여자

#차원축소를 위한 라이브러리
from IPython.display import Image
from sklearn.decomposition import PCA

#차원을 줄여주기(그래프를 그려주기 위함) 
words = list(model.wv.key_to_index)
X = model.wv[model.wv.key_to_index]
pca = PCA(n_components=2)
result = pca.fit_transform(X)

#word의 군집화 
result2 = StandardScaler().fit_transform(result)
db = DBSCAN(eps=0.3, min_samples=10).fit(result2)
labels = db.labels_

import collections
import math
import numpy as np 

myCounter = collections.Counter(words_all)
#print('myCounter:', myCounter)

radiuds = np.array([i for i in list(myCounter.values())]) #word의 중요도
area = np.pi * (radiuds)**2  * 5
table_words = list(myCounter.keys()) 
table_counts = list(list(myCounter.values()))

import matplotlib.pyplot as plt
import matplotlib
from matplotlib.font_manager import FontProperties
import matplotlib.font_manager as fm 

#top50의 단어를 선별하여 word2vec을 계산하고 좌표로 찍어준다. 

# font_location = "C:\\Windows\\Fonts\\NGULIM.TTF"
# font_name = fm.FontProperties(fname=font_location).get_name()
# matplotlib.rc('font', family=font_name)
plt.rcParams['font.family'] = 'NanumGothic'
valid_words = [hot_key[i] for i in range(0,50) if hot_key[i] in words]
valid_labels = [words.index(hot_key[i]) for i in range(0,50) if hot_key[i] in words]
valid_index = [words.index(str_temp) for str_temp in valid_words]   
valid_area = area[[table_words.index(str_temp) for str_temp in valid_words]]   
zip_index = zip(valid_index,valid_words)

plt.figure(figsize=(50, 25))
plt.scatter(result[valid_index, 0], result[valid_index, 1] , c = valid_labels , s = valid_area , alpha=0.2)
for i, word in zip_index:
    plt.annotate(word, xy=(result[i, 0], result[i, 1]))
    
plt.show()
# Out:
# c:\Users\taehwan\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
model.wv.most_similar(positive=["경찰"])
# Out:
# [('이르다', 0.9700140357017517),
#  ('해', 0.9649214148521423),
#  ('정말', 0.9572992920875549),
#  ('자다', 0.9549316763877869),
#  ('나다', 0.9542215466499329),
#  ('열', 0.9523378014564514),
#  ('인간', 0.9522426128387451),
#  ('좀', 0.9519628286361694),
#  ('믿다', 0.9511005282402039),
#  ('성공하다', 0.9507084488868713)]

# %%
model.wv.most_similar(positive=["여자"])
# Out:
# [('시작', 0.9503136277198792),
#  ('개', 0.950105607509613),
#  ('꼬', 0.9495433568954468),
#  ('모르다', 0.9493494629859924),
#  ('드리다', 0.9472899436950684),
#  ('강간', 0.9451598525047302),
#  ('자네', 0.9450918436050415),
#  ('않다', 0.9443750381469727),
#  ('잊다', 0.9439809322357178),
#  ('자루', 0.9437516927719116)]

# %%
model.wv["장갑"]
# Out:
# array([ 2.00196907e-01,  1.21194152e-02,  5.92136057e-03,  8.72047171e-02,
#         6.59830272e-02,  1.32601857e-01, -1.27802312e-01,  6.82934970e-02,
#         1.93682779e-03,  1.63319722e-01, -1.68800294e-01, -2.54529625e-01,
#        -7.04461988e-03,  1.32404044e-01, -1.68323904e-01,  1.27814179e-02,
#        -5.59802726e-02, -1.33980751e-01, -4.53230329e-02, -3.30392182e-01,
#         1.31442010e-01,  6.88736066e-02, -5.26088029e-02, -7.88433403e-02,
#        -1.25849470e-01,  7.29725324e-03, -5.82546145e-02,  5.82702905e-02,
#         5.69106527e-02, -1.55764809e-02,  4.03905123e-01, -8.65703449e-02,
#        -2.77028143e-01,  1.47293717e-01, -9.02391300e-02,  1.03842825e-01,
#         1.66618913e-01,  5.68664186e-02,  6.64675459e-02, -7.84282088e-02,
#        -5.94462715e-02, -6.41793683e-02,  2.04341616e-02,  9.88416374e-02,
#         4.27983284e-01,  1.19433783e-01,  3.24800275e-02, -2.65500456e-01,
#         1.40477180e-01, -3.00161988e-02,  3.78741995e-02, -2.66733840e-02,
#        -4.00803275e-02, -9.63108018e-02,  1.02875762e-01, -4.56198826e-02,
#         9.78201851e-02, -2.83228576e-01, -1.05597422e-01, -1.77262768e-01,
#        -5.61213158e-02,  2.23437082e-02,  7.06529319e-02,  7.66655505e-02,
#        -6.85741901e-02,  3.64627302e-01, -1.07100420e-01,  1.08967409e-01,
#        -2.98559032e-02,  1.78095132e-01,  4.94735641e-03, -1.46161690e-01,
#         6.09610826e-02,  1.53988093e-01,  9.63512734e-02,  5.31039201e-02,
#         4.15058620e-02, -1.44055620e-01, -1.14647396e-01,  6.73036575e-02,
#         4.98076715e-02, -8.35045204e-02, -1.54825479e-01,  1.63608834e-01,
#         2.46921971e-01, -1.37708103e-03,  1.35371052e-02, -1.45415515e-01,
#         3.71304154e-02, -5.74760661e-02,  4.80094478e-02,  4.22791056e-02,
#         1.16774321e-01,  2.33230770e-01,  1.63530648e-01,  2.24503890e-01,
#        -1.56453922e-02, -1.05659142e-01, -3.79449055e-02, -5.58403973e-03,
#        -5.64659797e-02,  7.66168907e-02,  8.83319825e-02,  1.13708369e-01,
#        -1.34561047e-01, -2.34677732e-01,  1.00951672e-01,  1.00282431e-01,
#         1.35884866e-01,  1.21596744e-02, -1.46875858e-01, -5.21173179e-02,
#        -4.16490845e-02, -1.96311548e-01,  1.75747201e-01, -1.20368063e-01,
#         4.68961969e-02, -1.96850240e-01,  8.23460668e-02, -6.96637705e-02,
#        -4.05318625e-02,  2.13858664e-01,  8.82957801e-02, -8.19460005e-02,
#        -3.11948843e-02,  1.31199267e-02, -2.33464912e-02,  1.81903154e-01,
#        -1.14451595e-01, -1.67178432e-03, -3.05927033e-03,  1.47692144e-01,
#        -6.26321211e-02, -3.20986174e-02, -2.22568791e-02,  5.21960016e-03,
#        -1.56570837e-01, -2.53115922e-01, -1.54316172e-01, -1.76605061e-01,
#         1.99268341e-01, -2.56869435e-01,  7.61133581e-02,  5.94820604e-02,
#        -4.74722870e-02, -1.28326356e-01, -2.56083846e-01,  2.61917971e-02,
#        -5.86089641e-02, -3.10900100e-02, -7.65977129e-02,  1.03288285e-01,
#         1.38263389e-01,  5.60405739e-02, -9.17623192e-02,  5.24200462e-02,
#        -1.95294350e-01,  4.87543531e-02, -8.24189931e-02,  3.82470824e-02,
#         1.67526454e-01, -5.52541912e-02, -1.60231411e-01,  1.20996065e-01,
#         9.72104892e-02, -2.51172832e-03, -5.49207143e-02,  1.95544675e-01,
#        -1.28182814e-01, -2.19860114e-02, -7.35686049e-02, -8.94104689e-03,
#         8.03372338e-02, -6.35235608e-02,  1.31025389e-01,  1.48506165e-01,
#         2.46882647e-01, -6.72905743e-02,  1.26417682e-01,  1.40650282e-02,
#         7.84241334e-02,  5.73384129e-02,  2.83736736e-02,  3.00150782e-01,
#         1.33457199e-01,  1.04254298e-01,  8.31819489e-05,  2.45131940e-01,
#         1.24237522e-01,  9.62173194e-02,  5.52177988e-02,  1.18403614e-01,
#        -3.03977840e-02, -7.34931527e-05,  7.44173080e-02,  2.46980637e-01,
#         2.86365338e-02, -1.76992208e-01, -6.75237030e-02, -1.43446028e-01],
#       dtype=float32)

# %%
model.wv["유괴"]
# Out:
# array([ 0.14246331,  0.11351775,  0.14373726,  0.2828911 , -0.03784274,
#         0.16988683, -0.11121362, -0.02251062, -0.06611288,  0.25068116,
#        -0.11007027, -0.24273266,  0.08309206, -0.06910692, -0.23250218,
#        -0.04230304, -0.01435524, -0.30742562, -0.08187577, -0.48248926,
#         0.08371395,  0.13724978, -0.07306486, -0.09932438, -0.19408935,
#        -0.04969411, -0.10202599, -0.11487584,  0.05030864,  0.00314872,
#         0.3320243 , -0.0285263 , -0.46579057,  0.23425277, -0.11260498,
#         0.06795178,  0.24617638,  0.00409835,  0.16960545, -0.09140474,
#        -0.08761937,  0.03421421, -0.09726   , -0.03152497,  0.62286353,
#        -0.02532181,  0.1463457 , -0.12100536,  0.38584656, -0.10931943,
#         0.04462536,  0.09912178, -0.04999472, -0.31417552,  0.08579044,
#        -0.16996783,  0.04837936, -0.22947861,  0.11921848, -0.1804775 ,
#        -0.14989455,  0.08980586,  0.123555  , -0.03901254, -0.20449063,
#         0.3004906 , -0.23988245,  0.12130217, -0.02678667,  0.06210488,
#        -0.01450632, -0.18214919,  0.2612649 ,  0.17289959,  0.2620248 ,
#         0.08140379,  0.02807092, -0.29207096, -0.16347238, -0.07627594,
#         0.04875689, -0.22066419, -0.17064035,  0.29174697,  0.1719174 ,
#        -0.01195748,  0.01915292, -0.1858252 ,  0.05821043, -0.12131637,
#         0.13978752,  0.13303027,  0.19021276,  0.40027374,  0.32938477,
#         0.3344806 , -0.21161035, -0.02662407, -0.0475569 , -0.06980839,
#        -0.03001394,  0.1579197 , -0.15684403,  0.13361464, -0.13184118,
#        -0.22542791,  0.01181919,  0.11114484,  0.10712949,  0.17117557,
#        -0.18762699,  0.07334005, -0.05120207, -0.07530978,  0.35483098,
#        -0.05611051,  0.12095705, -0.14464225,  0.19093613,  0.0295048 ,
#        -0.07820274,  0.0776213 ,  0.23770204, -0.00264127,  0.03812649,
#        -0.10699861, -0.17457657,  0.21411236, -0.21696985,  0.1512082 ,
#         0.03669123, -0.01212292,  0.17322579,  0.08123452, -0.04295754,
#        -0.12127772, -0.13054939, -0.15935601, -0.16221322, -0.05785493,
#        -0.09576416, -0.13252439,  0.17074522,  0.11321656, -0.24761608,
#        -0.0203172 , -0.18106686,  0.03908874, -0.11100655, -0.06343292,
#        -0.15056671,  0.06866816, -0.020822  ,  0.06001924,  0.11123133,
#        -0.09333599, -0.18848997,  0.11866906, -0.10925411, -0.02290892,
#         0.17430179, -0.08317649, -0.10445601,  0.10849655, -0.01249015,
#         0.00972014,  0.00508404,  0.02866851, -0.14989968,  0.06274949,
#        -0.2440913 ,  0.02237751,  0.08513083, -0.15024747,  0.07230195,
#         0.0478004 ,  0.12930022, -0.19839498,  0.16406396, -0.1533242 ,
#        -0.0322086 , -0.01544559, -0.01698106,  0.28642288,  0.01794882,
#         0.04726159, -0.02750301,  0.15778868,  0.2322342 , -0.01505253,
#        -0.00774007,  0.06693202, -0.15004712, -0.09474391,  0.1156819 ,
#         0.07217133,  0.01880921, -0.00363433, -0.24798617, -0.11285147],
#       dtype=float32)

# %%
model.wv.most_similar(positive=["경찰","유괴"] , negative=["여자"])
# Out:
# [('아이', 0.8064321279525757),
#  ('버리다', 0.7863120436668396),
#  ('돈', 0.7709444761276245),
#  ('겁', 0.7546163201332092),
#  ('꺼내다', 0.7501411437988281),
#  ('머리', 0.7437183260917664),
#  ('이', 0.7429560422897339),
#  ('범', 0.7414811253547668),
#  ('확', 0.7401788830757141),
#  ('칼', 0.7099025249481201)]

# %%
lines
# Out:
# ['',
#  '씬 1 달리는 버스 안',
#  '타이틀이 끝나고 F.I 되면―',
#  '경쾌하게 달려와 서는 시내버스.',
#  '치익, 소리와 함께 문이 열리자 기다리고 있던 사람들이 올라탄다.',
#  '버스카드 혹은 현금함 앞으로 오가는 손들을 바라보던',
#  '운전수:(그냥 지나치는 사람을 발견하곤)아저씨, 차비 내셔야죠?',
#  '하며 운전수가 노려보면, 가방을 메고 지나쳐 가다가 뒤돌아보는 꼴통, 특유의 인상을 긁으며 들고있던 볼펜을 운전수에게 내민다. 시선을 피하며 차를 출발시키는 운전수, 꼴통, 버스 가운데쯤에 서서 가방을 털썩 내려놓더니 볼펜 한자루를 치켜들며',
#  '꼴통:(뒤뚱뒤뚱 인사를 하고)차 안에 계신 신사, 숙녀 여러분 안녕하십니까. 저는 홧김에 폭력, 겁도 없이 유괴, 불타는 가슴으로 강간 등 도합, 전과 십이범으로 얼마전에 출소한 대책없는 어린양입니다.(시선을 피한 승객들에게 볼펜을 한자루씩 올려놓으며)아픈 과거는 잊고 꼬딱지만한 포장마차라고 장만할까하니, 액땜한다 생각하시고 가볍게 지갑을 열어주시기 바랍니다. 여러분의 가정에 불행이 없기를 간절히 소망하며(볼펜을 들어보이며)이 볼펜을 단돈 삼천원에 드리겠습니다. 감사합니다.',
#  '인사를 하고는 돈을 거둬들이려 돌아다니는 꼴통, 험악한 인상을 써보이자 순순히 돈을 주는 아가씨. 깐깐해 보이는 남자가 볼펜을 돌려주자',
#  '꼴통:난 열받으면 입보다 주먹이 먼저 나가는 놈이지요.',
#  '하며 사내 앞으로 주먹을 내밀자, 얼른 지갑에서 돈을 꺼내 주는 사내. 이번엔 꾸벅 꾸벅 졸고 있는 고등학생에게 다가가',
#  '꼴통:(툭툭)야, 야!',
#  '하지만 깨지 않자 뒷통수를 퍽퍽치며',
#  '꼴통:임마, 자는 척 하지마.',
#  '학생:왜 그러세요?',
#  '꼴통:삼천원 내.',
#  '학생:왜요?',
#  '꼴통:내라면 내, 빨리 안내!',
#  '고등학생이 돈을 꺼내자 다음으로 넘어간다. 꼴통, 아이를 안고 창밖을 보는 척 하는 아줌마를 보곤 아이의 머리를 쓰다듬으며',
#  '꼴통:아이구 귀여워라.',
#  '아줌마, 돌아보자',
#  '꼴통:저는 겁도 없이 "유괴"를 두 번이나 했던 죽일 놈이지요.',
#  '하며 이번엔 겁먹은 아이의 볼을 살짝 꼬집는다. 아줌마, 얼른 손에 쥐고 있던 돈을 주며 아이를 끌어안는다. 꼴통, 몇몇 사람에게 순순히 돈을 받으며 뒷자리로 향하다가 버스 안에서 일어난 사태를 전혀 의식하지 못한 채 귀엔 이어폰을 끼고 창 밖을 보며 뭔가를 메모하고 있는 한 여자 앞에 다가선다. 꼴통, 다짜고짜 그녀의 어깨에 손을 올려놓고 특유의 인상을 긁으면 깜짝 놀라 돌아보는 긴 생머리의 시원스런 얼굴의 여자, 바로 이 영화의 신임 여형사인 최형사다.',
#  '꼴통:나는 "강간"도(하며 여자의 머리카락을 배배 꼬며)세 번이나 했던…',
#  '어이가 없어 쳐다보는 최형사가 겁이라도 먹은 줄 알고 핸드백을 자기 손으로 열어 돈을 꺼내려다간 수갑, 권총을 발견하곤 굳어지는 꼴통, 하지만 상대가 여잔지라 표정을 다시 정리하며',
#  '꼴통:너 경찰야? 잘 만났다. 난 경찰이라면 이가 갈리는 놈이야!',
#  '순간, 턱! 쪼인트를 맞는 꼴통, 신음과 함께 고개를 치켜들며',
#  '꼴통:어쭈? 쳤어? 이게 내가 누군지 알고…',
#  '하지만 말이 끝나기도 전에 곧장 날아오는 최형사의 주먹에 퍽! 뒤로 나자빠진다.',
#  '꼴통:으…(코피를 쓰윽 닦더니, 질겁하곤 일어나며)피잖아? 이 씨!(웃통을 벗으며)끼어드는 놈 있으면 죽여버릴꺼야!',
#  '겁에 질려 피하는 사람들.',
#  '꼴통:(괜히 버스를 머리로 받으며)씨발, 사고치기 싫다니까, 내 인생은 왜 이렇게 꼬이는 거야?(휙 손가락으로 가리키며)이건 니 잘못이야!',
#  '하며 최형사를 향해 저돌적으로 돌진하는 꼴통! 하지만 달려오는 꼴통을 멋지게 업어치기로 받아넘기는 최형사. 꽈당! 버스 바닥이 찌그러질 정도로 떨어지는 꼴통이다. 꼴통, 자신의 K.O 패를 인정하곤 최형사를 향해 두손을 모아 빌며',
#  '꼴통:아이고, 제가 그만 흥분을 해서……',
#  '최형사, 표정조차 변하지 않은 채 뚜둑 뚜둑, 몸을 풀며 다가선다.',
#  '꼴통:(휘둥그레지며)아니 왜 이러세요? 잘못 했다구요!',
#  '최형사:(멱살을 잡아 일으켜 세우며)아직 안 끝났어!',
#  '씬 2 거리',
#  '달리는 버스에서 과장되게 들려오는 꼴통의 비명소리. 퍽! 퍽! 우두둑! 맞는 소리와함께 좌우로 요동치는 버스. 우지끈! 어딘가 부러지는 듯한 소리와 함께 끼이익 멈춰서는 버스 위로 덥치는 타이틀―<투캅스 3>',
#  '씬 3 어느 집 거실',
#  '자막이 사라지면 선행하는 초인종 소리 속에―',
#  '화면 가득 현관문의 반투명 유리로 남자의 형체가 보이는 속에 끼리릭～끼리릭～ 소리와 함께 문고리가 탁! 하며 위로 젖혀지면, 스르르 열리는 문으로 들어오는 구두에서부터 카메라 틸업하면, 손에 목장갑을 낀 사내가 열고 있는 문으로 흑장갑을 낀 사내가 쌕을 맨 채 들어온다.',
#  '흑장갑이 날카로운 눈매로 고개를 휙 저으면 빠르게 움직이는 목장갑, 방문들을 열어보다가 어느 방 앞에서 흑장갑을 보며 고개를 끄덕이면 그곳으로 걸어가는 흑장갑.',
#  '씬 4 동 방안',
#  '금고에 청진기를 댄 채 번호판을 돌리고 있는 흑장갑 뒤로 각종 그림, 도자기 등이 널린 방의 서랍 따위를 뒤지고 있는 목장갑, 천원짜리 몇 장과 은장도, 씨거, 엽전 등을 쌕에 넣다가 흑장갑의 눈치를 보며 몰래 천원짜리를 주머니에 챙기기도 하는 목장갑.',
#  '흑장갑:(청진기를 댄 채)한 껀 했다고 돈 함부로 쓰지 마라. 상법이가 왜 잡혔는지 아나? 돈 생겼다고 친구들 데리고 룸싸롱에서 쭉쭉빵빵 죽이는 년들 끼고 술 졸나게 퍼마셨지, 근데 이 친구란 새끼들이 아침에 해장국 먹는데 갑자기 이런 생각이 든 거야. 자기들은 어제 한 번 얻어먹었지만 저 새낀 그런 데서 맨날 처먹을 꺼라고 생각하니 괜히 열받잖아? 씨발, 그래서 경찰에 수상한 놈 있다고 찔러서 잡힌거다. 절대 친한 놈들한테 돈쓰지 마라, 알겠냐?',
#  '목장갑:예.',
#  '흑장갑:안본다고 꼬불칠 생각하지 마라, 나중에 죽는다.',
#  '목장갑:(주머니에서 돈을 꺼내며)예.',
#  '하며 다시 천원권 지폐를 꺼내 쌕 안으로 밀어 놓는다. 딸칵! 소리와 함께 미소지으며 금고 손잡이를 잡아 천천히 여는 흑장갑. 목장갑, 재빨리 뒤로 다가온다. 흑장갑, 미소지은 채 금고를 열다간 잉?～ 표정이 확 변한다.',
#  '뒤어어 고개를 들이미는 목장갑의 표정도 확 굳어서 보면, 열린 문 안으로 금고가 하나 더 보인다.',
#  '목장갑:씨발…. 이 새끼는 금고장사하나?',
#  '흑장갑:아니, 도굴꾼이야.',
#  '목장갑:예? 그게 뭡니까?',
#  '흑장갑:몰래 남의 무덤 졸나게 파서 골동품 챙겨다가 팔아먹는 놈이지.',
#  '목장갑:한마디로 벼락맞을 새끼들이네요.',
#  '흑장갑:자방출장 간걸 보면 또 어떤 놈 무덤 졸나게 파고 있을거야.',
#  '씬 5 동 밖',
#  '끼이익! 멈추는 봉고에서 박스 등을 들고 내리는 도굴꾼들. 제법 큰 집의 대문을 열고 짐을 들고 조심스레 안으로 들어가는 속에 그 뒤로 멈춰서는 차. 열리는 차문에서 내리는 누군가의 발에서 틸업하면 바로, 우리의 이형사가 도굴꾼들을 보며 빠르게 다가간다.',
#  '씬 6 동 안',
#  '다시 청진기를 대고 있는 흑장갑 뒤로 시계를 보고 있는 목장갑.',
#  '목장갑:형님, 근데 안에 금고 하나 더 있으면 어떡하죠?하자 휙 보는 흑장갑, 목장갑의 머리, 배 따위를 마구 팬다.',
#  '흑장갑:재수없는 소리하지마, 임마, 안에 금고 또 있으면 너가 죽을줄 알아.',
#  '하고는 금고 문을 여는 순간, 또 다른 금고가 있다.',
#  '흑장갑:(목장갑을 팰 듯이 가며)이리와, 새꺄.',
#  '하는 순간 현관문이 열리는 소리가 들리자 표정이 굳는 흑장갑과 목장갑, 문쪽을 바라본다.',
#  '씬 7 동 거실',
#  '문을 열고 들어오는 도굴꾼1, 뒤돌아보며',
#  '도굴꾼1:조심해, 얼마짜린 줄 알아?',
#  '무거운 듯 박스 등을 들고 들어오는 도굴꾼2, 3, 4 의 모습 속에 들리는',
#  '소리: (이형사의)꼼작마! 경찰이다!',
#  '휙 뒤돌아보는 도굴꾼들, 인상이 확 변하더니 어느새 안으로 뛰어들어오는 이형사에게 박스를 던지지만 피하는 이형사 뒤의 벽에 맞고 깨지는 도자기. 도굴꾼 2, 3, 4. 이형사를 향해 칼, 호미, 삽 따위를 휘두르며 공격해보지만 뒷걸음질치는 도굴꾼1, 뒷편의 방으로 도망간다.',
#  '씬 8 동 방안',
#  '문을 열고 들어오는 도굴꾼1, 창문을 뛰어넘어 도망가는 흑장갑, 목장갑을 보곤',
#  '도굴꾼1:너희들 뭐야?',
#  '하곤 곧장 흑·목이 도망간 창문으로 뛰어나가면 곧이어 들어오는 이형사, 재빨리 창문으로 뒤쫒아간다.',
#  '이형사:거기서!',
#  '씬 9 어느 골목',
#  '쫓아가는 이형사 앞으로 도굴꾼1이 달리고, 그 앞으로 도망가고 있는 흑장갑과 목장갑에게로 쫓아가는 카메라.',
#  '이형사:(달려오며)거기서!',
#  '도굴꾼1:(도망가며, 앞을 보고)야, 이 도둑놈 새끼들아! 감히 누구 집을 털어?',
#  '목장갑:(뒤돌아보며)훔치지도 못했어, 임마.',
#  '흑장갑:(뒤돌아보며)새꺄, 자꾸 우리 따라오지마! 딴 데로 가!',
#  '다시 뒤따라오는 도굴꾼과 이형사를 보여주는 카메라.',
#  '도굴꾼1:(이형사에게 뒤돌아보며)저 새끼들도 도둑놈이예요.',
#  '이형사:일단 너부터 잡을꺼야!',
#  '흑장갑, 길 한켠에 놓인 휴지통을 옆으로 밀치고 뛰면 피하려던 도굴꾼1이 몸을 트는 사이 뒤에서 점프해오는 이형사, 도굴꾼1을 덥치며 뒹군다.',
#  '이형사에게 잡히는 도굴꾼1을 보며 씨익 미소지은 채 도망가는 흑·목장갑 옆으로 스쳐 지나간 차가 도굴꾼1에게 수갑을 채우는 이형사 앞에서 끼이익! 멈춰서 빵빵 클락션을 울려대는 차안의 여자운전수. 짜증스레 40대의 여자운전수를 바라보는 이형사와 도굴꾼1.',
#  '씬 10 경찰서 사무실',
#  '수갑을 찬 도굴꾼들을 툭툭 치며 들어오는 이형사, 다른 경찰에게 도굴꾼들을 유치장 쪽으로 인계하는데',
#  '형사1:또 한껀했나? 하루도 그냥 넘어가는 날이 없구만.',
#  '이형사:예 써.(빈 자리를 보곤)아직 안왔습니까? 첫날부터 자각이야?!',
#  '형사1:아? 신참? 차가 막히나 보지? 참, 자네 파트너 이야기 들었나?',
#  '이형사:아뇨.',
#  '이때 엉망인 몰골로 수갑을 찬 채 뛰어들어오는 꼴통, 정신이 없는지 이곳저곳을 살피며',
#  '꼴통:악! 사람살려!',
#  '경찰1:(꼴통을 보곤)저 자식은 볼때마다 인상이 더러워져?',
#  '꼴통:(다가와선)이형사님! 제발, 살려주세요.',
#  '이형사:가석방 된지 몇 일 됐다고 또 들어왔어?!',
#  '꼴통:(울먹이며)제발 살려만 주세요, 완전히 마녀예요.',
#  '하는 순간 뒤에서 다가와 꼴통의 뒷덜미를 잡는 최형사.',
#  '최형사:이리와!',
#  '꼴통, 울먹이며 최형사에게 후다닥 뛰어가면',
#  '이형사:누굽니까?',
#  '형사1:몰라? 자네의 새로운 파트너잖아?',
#  '이형사:예?!',
#  '다른 경찰에게 꼴통을 넘기는 최형사의 늘씬한 다리에서부터 얼굴까지 쭈욱 훑어보고는 불만이 가득한 표정으로 바뀌는 속에',
#  '형사1:(최형사를 보며)잘 빠졌는데? 몇 일 버틸까?',
#  '형사2:(이형사를 보며 슬쩍 만원을 꺼내며)일주일. 어? 이형사, 어디가?',
#  '이형사:(일어나 가며)과장님 계시지요?',
#  '형사2:응.(만원을 꺼내며)내일.',
#  '씬 11 동 과장실',
#  '화면 가득 책상위로 내민 흰 봉투를 집어드는 과장, 맞은 편에 서있는 이형사를 보며',
#  '과장:이게 뭐야?',
#  '이형사:파트너 바꿔 주십시오, 아니면 사표 내겠습니다.',
#  '과장:뭐어～?!',
#  '이형사:요즘 강력사건이 얼마나 많이 발생하는데 여자를 붙이시면 어떡합니까?',
#  '과장:임마. 그래도 이번에 경찰학교 수석 졸업했어.',
#  '이형사:요즘엔 수석을 아무나 하나보죠?',
#  '과장:여자라고 우습게 보지 말고 앞으로 잘 해봐.',
#  '이형사:안됩니다. 수사하다가 갑자기 사랑 때문에 질질 짜고, 중요한 놈을 체포하려는 순간에 생리라도 하면 어떡합니까? 당장 바꿔 주십시오.',
#  '과장:이 자식이 싸움 잘한다고 봐줬더니…. 알았어.',
#  '이형사:예? 정말 그만 둔다니까요.',
#  '과장:수리했다니까 임마, 짜식이 건방지게 인사권까지 참견하려해? 당장 나가, 임마.',
#  '이형사:과장님!',
#  '과장:(밀치며)관둘려면 관둬! 임마, 나가서 짐이나 싸! 어서!',
#  '씬 12 달리는 차 안',
#  '운전을 하는 이형사, 그 옆에 창밖을 보는 최형사.',
#  '이형사:(화난 듯)경찰학교 수석졸업, 정말이야?!',
#  '최형사:예. 선배님이 세운 기록도 깼습니다.',
#  '이형사:그래?(다시 한번 보곤)대책없이 인심이 좋아졌군. 근데 경찰 학교엔 왜 갔나? 조용히 시집이나 가지!',
#  '최형사:(휙 보며)선배님, 제가 온 게 불만입니까?!',
#  '이형사:(힐끗보며)자넬 위해서 하는 소리야. 여잔 자고로 남편 사랑 받으면서 집안 일이나 하는 게 최고야. 안그래?',
#  '최형사:(노려보며)항상 그렇게 여자를 무시합니까?',
#  '이형사:경찰 일이란게 사기꾼, 강간범, 도둑놈, 깡패 같은 놈들의 더러운 꼴만 보는 거야. 여차하면 놈들이 휘두른 쇠파이프에 뼈가 부러지고, 칼에 찔리고, 무식한 놈은 도끼까지 들고 설쳐대서 병신되기 쉽상이지. 사랑이고 결혼같은 건 꿈도 못꿔.',
#  '최형사:알고 있습니다.',
#  '이형사:그래? 그럼, 당장 그만둬. 뭐할려구 해?',
#  '최형사:근데 어쩔 수 없어요. 팔자예요.',
#  '이형사:뭐?',
#  '최형사:타고난 운명이라구요. 태몽에서부터 용하다는 점쟁이들까지 모두 제가 사회의 악을 처단하는 강직한 전사같은 삶을 살꺼랬어요.',
#  '이형사:태몽?',
#  '최형사:한 손엔 불과 다른 손엔 칼을 쥐고 있었대요.',
#  '이형사:불과 칼이라…. 그럼 주방장 아닌가?',
#  '최형사:(경멸하듯 바라보며)….',
#  '최형사와 이형사, 서로를 바라보는데 이형사 뒷편으로 소매치기가 어느 아줌마의 지갑을 낚아채 도망가는 모습이 보인다.',
#  '최형사:차 세워요!',
#  '하면 끼이익～ 선행하는 브레이크 소리와 함께―',
#  '씬 13 어느 시장통',
#  '핸드백을 쥔 채 빠르게 도망가는 놈을 쫓아가는 최형사.',
#  '최형사:거기서!',
#  '사람들을 부닥쳐가며 도망가는 놈을 거의 잡기 직전, 놈이 밀친 아이를 피하려다 다른 곳에 부닥치며 넘어지는 최형사. 멀어져가는 놈, 여유 띤 미소를 짓는데 불쑥 나타난 누군가의 발에 걸려 넘어지고 만다. 넘어진 놈의 뒷덜미를 낚아채는 이형사.',
#  '이형사:(일어나는 최형사에게 다가가)역시 여자라 별 수 없군. 범인 체포의 기본을 달리기야! 그렇게 뛰어서 누굴 잡겠나?',
#  '하며 여유를 부리는데 눈치를 보던 놈, 이형사의 팔을 쳐내곤 다시 도망간다. 순간, 몸을 날리는 최형사, 놈을 덥치며 넘어뜨린 뒤 핸드백을 감아쥔 놈의 손목을 잡아 우두둑 꺽어버린다. 비명을 지르는 놈. 놀란 듯 바라보는 이형사.',
#  '최형사:(수갑을 채우며)이런 놈들을 잠시도 방심하면 안되죠. 다음부턴 주의하세요.',
#  '하며 놈을 끌고가는 최형사를 뻥찐듯 바라보는 이형사다.',
#  '씬 14 햄버거 집 안',
#  '햄버거를 가져와 앉는 이형사 맞은 편에 있는 최형사.',
#  '이형사:팔까지 부러뜨릴 필요는 없었잖아?',
#  '최형사:눈에는 눈, 이에는 이. 나쁜짓을 한 놈은 다신 그 짓을 못 하게 만들어 놔야 범죄 재발을 막을 수 있습니다.',
#  '이형사:(햄버거를 먹으며)그래서?',
#  '최형사:(햄버거 안에 있는 고기, 치즈 등을 빼내며)도둑질 한 놈은 손가락을 부러뜨리고, 공갈협박한 놈은 다신 입을 못 놀리게 하는 거죠.',
#  '이형사:그럼 강간한 놈은?',
#  '최형사:거길 잘라버려야죠.',
#  '이형사:말은 잘하는군. 근데 뭐하는거야? 다이어트 하나? 여자들은 그래서 안되는거야. 잘먹고 운동할 생각해야지, 안먹고 운동도 안하니까 비실비실 하잖아? 정말 한심해서……',
#  '최형사:저도 그렇게 보입니까?',
#  '이형사:(먹으며)응.',
#  '씬 15 어느 곳',
#  '멈춰서는 차에서 내리는 이형사와 최형사.',
#  '이형사:관내에서 발생한 연쇄 강도범들이야. 목숨 아까운 줄 모르는 살벌한 놈들이지.',
#  '최형사:지원요청은 하셨습니까?',
#  '이형사:(손가락을 두둑거리며)혼자 몸풀기에도 모자라.(어깨를 짚으며)위험하니까 최형사는 안에서 콜라나 마셔. 김빠지기 전에 돌아오지.',
#  '씩씩하게 건물 쪽으로 들어가는 이형사를 바라보는 최형사.',
#  '씬 16 마약 아지트 안',
#  '꽝 문을 박차고 들어오는 이형사를 보고 놀라는 마약상들.',
#  '마약상1:튀어!',
#  '이와 동시에 역동적으로 보여지는, 가방을 들고 튀는 마약상1 뒤로 칼, 쇠파이프 따위를 쥔 채 도망가는 마약상 2, 3, 4, 5. 쫓아오는 이형사를 보곤 마약상 4, 5가 이형사에게 칼, 쇠파이프 따위를 휘두르며 공격해보지만 이형사의 화려한 액션에 나가떨어진다. 이형사, 마약상 1, 2, 3이 나간 뒷문으로 뒤쫓아나간다.',
#  '씬 17 동 밖',
#  '문을 열고 나오는 이형사, 작은 골목으로 꺽어 들어가는 마약상 1, 2, 3의 뒤를 쫓아 달려간다. 달리는 이형사의 모습 위로 들리는 꺄악! 한 여자의 비명소리와 함께 우당탕! 퍽! 쾅! 하는 소리에 아차～ 하는 생각이 드는 이형사.',
#  '이형사:가만있으라니까, 이런 멍청한!',
#  '하며 총을 꺼내며 달려가는 이형사.',
#  '씬 18 동 다른 골목',
#  '총을 빼든 채 달려오는 이형사.',
#  '이형사:꼼짝마!',
#  '하고 둘러보면, 한 여자가 겁에 질린 채 웅크리고 있는 옆에서 놈들이 널부러져 있고 최형사가 한 놈에게 수갑을 채우고 있다.',
#  '최형사:아직도 비실비실해 보이나요?',
#  '이형사:제법하는데? 죽도록 노력하면 한 5년 뒤엔 내 수준 근처까지 오겠어.',
#  '최형사:선배님도 제가 오기 전까진 제법한다는 말 많이 들었겠는데요?',
#  '이형사:호? 좋아. 자신감이 대단하군. 어디 한 번 제대로 해보겠나?',
#  '최형사:처단해야 할 놈들이 있는 곳이라면 어디든지요!',
#  '이형사:좋아! 렛츠 고!',
#  '최형사:오케이!',
#  '씬 19 거리(N)',
#  '경쾌한 음악 속에 화려한 밤거리를 씩씩하게 걸어가는 투캅스. 호객행위를 하던 삐끼들이 이형사를 보고 숨기도 하고, 중년의 사람(사장)들이 반갑게 인사도 건네고, 덩치들이 서로 패싸움이라도 하려는 듯 각목, 철봉, 체인 등을 들고 숨기고 쩔쩔매는 표정으로 90도로 인사를 하기도 한다. 이런 사람들을 보며 고개를 끄덕이며 지나가는 이형사를 어이없는 표정으로 보던 최형사.',
#  '최형사:경찰하기 전에 깡패였어요?',
#  '이형사, 이런 최형사를 인상을 쓴 채 쳐다본다.',
#  '씬 20 나이트 클럽 안',
#  '터져 나오는 음악과 휘황찬란하게 돌아가는 조명 속에 춤추는 사람들 너머로 보이는 투캅스.',
#  '이형사, 유리로 된 룸 안에 보이는 많은 건달들 가운데에 있는 험악하게 생긴 한명을 가리키며',
#  '이형사:김한철! 폭력전과 10범에 수배중이지. 혼자 잡을 수 있겠나?',
#  '최형사:맥주나 마시세요. 김빠지기 전에 잡아올게요.',
#  '하며 씩씩하게 걸어간다. 점점 가까워지는 룸 안의 모습을 보면, 미니스커트들을 끼고 십 여명의 우락부락한 건달들이 술을 마시고 그 앞에 웨이터 두명이 완전 쫄아서 90도 씩 절을 해대고 있다. 최형사, 긴장한 듯 심호흡을 하는 모습 뒤로 저 편에서 이형사가 씩 쪼개며 바라보고 있다. 몸을 두둑이며 룸으로 천천히 걸어가는 최형사. 이때, 룸에서 나온 웨이터가 다짜고짜 최형사의 팔을 잡는다.',
#  '웨이터:아가씨, 나 좀 살려주세요.',
#  '최형사:왜 이래요?',
#  '웨이터:제발 살려주세요. 부킹 한번만 해요 부킹. 부킹.',
#  '최형사:어?',
#  '최형사의 팔을 잡고 룸 안으로 데리고 들어가는 웨이터, 최형사를 룸에 밀어놓고는 재빨리 빠져 나와 안도의 한숨을 쉰다. 건달들, 최형사를 보며 고개를 끄덕이기도 하며 어깨에 손을 올리자 휘 쳐다보는 최형사.',
#  '건달1, 덥썩 최형사를 안는 순간 빠르게 올라가는 최형사의 무릎이 그곳을 강타한다. 읔, 신음을 내며 내려앉는 건달1을 잡는 최형사, 입구의 문으로 내던져버린다. 와장창! 유리문을 박살내며 나자빠지는 건달1. 손에 칼과 병 따위를 들고 벌떡 일어나는 건달들, 까약! 비명을 내지르며 나가는 미니스커트들 옆으로 병을 들고 설쳐대는 건달2의 팔목을 병으로 내리치는 손, 비명을 지르는 놈을 내차는 발. 많은 건달들에 맞서 홀홀 단신으로 싸우는 최형사. 겁에 질린 사람들, 비명을 지르며 뒤로 물러나는 뒤로 저 편에 이형사가 팔짱을 끼고 서서 바라본다. 최형사를 향해 공격해 들어가는 건달들, 하지만 최형사의 무자비하리만치 강한 몸놀림에 하나 둘 쓰러진다. 테이블을 부수고, 디제이박스를 박살내며 날아가는 놈들. 물러나있던 사람들이 탄성을 지르며 하나 둘 앞으로 다가와 구경하는 속에 서있는 이형사.',
#  '사람1:와… 저 여자 죽이는데?',
#  '사람2:정말 폼 나는데! 끝내준다. 끝내줘 햐……',
#  '이런 사람1, 2와 최형사를 번갈아가며 보는 이형사. 이때 최형사 뒤에서 한놈이 칼을 휘두르는 순간 퍼벅! 내리치며 싸움판에 끼어드는 이형사.',
#  '최형사:(한놈을 해치우곤)도망가는 놈들이나 잡으라니까 왜 끼어들어요?',
#  '이형사:도와줘도 잔소리군!',
#  '하며 다시 사람들 사이로 들어가는 이형사. 최형사에게 건달들이 쓰러져 나가자 안되겠는지 보스인 듯한 놈이 사람들을 헤집고 뒷문으로 도망간다.',
#  '최형사:뭐해요?!',
#  '이형사, 인상을 구기곤 사람들 사이로 튀어나가면 뒤따라 나가는 최형사.',
#  '씬 21 동 밖',
#  '허겁지겁 튀어나오는 최형사와 이형사. 보면 저 편에서 차를 막아 세우며 운전수를 밀쳐내는 보스. 달려가는 이형사, 보스를 향해 점프하지만 문을 닫고 안으로 들어가는 보스, 쓰러진 이형사 옆으로 휭하니 차를 몰고 가버린다. 넘어진 이형사 옆으로 곧장 끼이익 멈춰서는 차안에 최형사가 보인다. 이형사가 타면 급출발하는 차.',
#  '씬 22 도로',
#  '끼이익! 빠르게 달리는 투캅스의 차. 다른 차들은 이리저리 젖히다간 급회전해 반대편 차선으로 달린다.',
#  '씬 23 차 안',
#  '마주보고 달려오는 차들의 클락션을 울려대는 속에 당황해하는 이형사와 결의에 가득찬 최형사의 표정속에―',
#  '씬 24 도로',
#  '엉망진창으로 뒤엉키는 차들 속에 달려가는 투캅스의 차. 오른쪽으로 보이는 차안에서 놈이 힐끗 보곤 핸들을 꺽는 순간 끼이익! 급회전하며 부닥쳐 들어오는 투캅스의 차. 끼이익! 쿵! 부닥치면서 다른 도로로 급회전해 들어간다.',
#  '씬 25 차 안',
#  '공사중인 도로의 가설대를 밀쳐내며 놈의 차와 들이받는 속에',
#  '이형사:혹시 최형사도 폼 나니까 경찰한건가?',
#  '최형사:그런 정신나간 놈도 있나요?',
#  '인상이 팍 구겨지는 이형사.',
#  '씬 26 도로',
#  '투캅스의 차를 뒤로한 채 끼이익! 도로 가로수를 들이받으며 멈춰서는 차. 허겁지겁 내리는 보스, 어느 쇼핑타운 안으로 뛰어들어간다.',
#  '씬 27 달리는 차 안',
#  '인도를 보며 액셀레이터를 밟는 최형사. 이형사, 휘둥그레지며',
#  '이형사:안돼, 멈춰!',
#  '하지만 최형사는 결의에 찬 얼굴로 밀어 부친다.',
#  '씬 28 쇼핑타운',
#  '밀고 들어오는 투캅스의 차에 비명을 지르며 피하는 사람들. 놈이 들어가는 쇼핑타운 안으로 곧장 밀고 들어가는 차. 쾅! 가제의 대형 쇼윈도우를 박살내며 멈춰서는 차. 보스, 힐끗 뒤돌아보곤 겁에 질린 채 내달음친다. 차에서 튀어나오는 최형사.',
#  '최형사:(달려가며)거기서!',
#  '최형사 뒤로 천천히 삐그덕 열리는 문으로 거의 넋이 나간 듯 나오는 이형사.',
#  '이형사:헉……?',
#  '씬 29 동 건물 안',
#  '도망가는 보스를 향해 저돌적으로 달려가는 최형사. 꺄아악! 비명을 내지르는 사람들 사이로 달려가는 보스와 최형사. 간격이 좁혀지자 힘껏 점프해 보스를 덥치는 최형사. 다른 가게문을 박살내며 뒹구는 두사람. 보스, 어느 틈엔지 칼을 꺼내들고 최형사를 향해 휘두른다. 멋지게 보스를 쓰러뜨리는 최형사. 보스의 팔을 내리치고, 다리를 우지끈 차버린다. 비명을 지르며 완전 맛이 간 보스의 목이라도 확 꺽어버릴 듯 하는 최형사를 보곤 질겁한 채 달려오는 이형사.',
#  '이형사:안돼!',
#  '하며 최형사를 덥친다.',
#  '바닥에 최형사를 덥친 채 엎어지는 이형사의 모습 속에서―',
#  '씬 30 경찰서 과장실',
#  '인상을 쓴 채 버럭 버럭 고함을 질러대는 과장 앞에 고개를 숙이고 있는 이형사와 최형사.',
#  '과장:도대체 뭐하는 거야!(서류를 들어 보이며)나이트클럽, 자동차 8대에 쇼윈도우까지 전부 얼만지 알아?',
#  '이형사:(고개를 숙인채)….',
#  '과장:지금 전쟁났어?! 기다렸다가 나올 때 잡으면 그 자식이 썩어 없어지기라도 해?',
#  '이형사:죄송합니다.',
#  '과장:(이형사에게)여자 신참 왔다고 너무 오버하지마! 임마. 안봐도 훤해! 감봉 10개월.',
#  '이형사:예 써.',
#  '과장:(최형사의 어깨를 토닥이며)오자마자 하필 이런 놈 만나 억울하겠지만 할 수 없네. 감봉 1개월. 미안해 최형사.',
#  '최형사:(앞으로 한발 나서며)과장님. 똑같이 징계내려 주십시오. 저도 10개월로 하겠습니다.',
#  '과장:뭐? … 최형사는 이쁜데다가 의리까지 있구만.',
#  '이형사:아닙니다. 상사인 제 잘못이 더 큽니다. 모두 제가 책임지겠습니다.',
#  '과장:(이형사에게)나도 그러고 싶어. 임마! 최형사를 봐서 징계문제는 더 가벼운 걸로 위에 건의해 보지.',
#  '최형사:예. 고맙습니다.',
#  '이형사:(과장과 최형사를 번갈아보며)….',
#  '과장:(최형사의 어깨를 다독이며)차근차근 일 배우고(이형사의 귀를 잡아당기며)성깔 좀 죽여! 알겠어?',
#  '씬 31 동 사무실',
#  '과장실 문을 열고 나오는 투캅스.',
#  '최형사:죄송해요, 선배님. 저 때문에…',
#  '이형사:아니, 괜찮아. 가지.',
#  '최형사:어딜요?',
#  '이형사:(손을 두두둑거리며)일해야지.',
#  '씬 32 대연회장 입구',
#  '<신영회 단합대회>라는 플랭카드가 걸린 대연회장의 주차장에 정차하는 차에서 내리는 이형사, 뒤따라 나오는 최형사를 보곤',
#  '이형사:이번엔 내 차례야.',
#  '최형사:네?',
#  '이형사:자네는 구경이나 하고 있어.',
#  '하고 걸어가는 이형사에게 다가오는 중년의 사장.',
#  '사장:(제지하듯 손을 내밀며)오늘은 예약손님만 받습니다.',
#  '이형사:(형사증을 내보이며)…',
#  '사장:아니, 저 형사님…',
#  '하는데 다가오는 양복차림의 건달 1, 2.',
#  '건달1 :뭐야?',
#  '하며 다가오는 건달1, 2를 보곤 곧장 퍼버벅! 주먹으로 눕히곤 안으로 들어가는 이형사.',
#  '씬 33 동 연회장 안',
#  '문을 열고 들어오는 이형사 뒤로 다가오는 사장.',
#  '사장:형사님… 여기서 이러지 말고 있다가….',
#  '이형사, 그런 사장을 밀치고 보면, 폭력 조직인듯한 놈들이 좌악 줄지어 앉아 있다가 일제히 휙 바라본다. 건달3의 고개짓에 따라 이형사를 향해 일제히 일어나는 건달들. 이형사, 손을 두두둑 거리며 미소를 지은 채 놈들에게 다가가면 울상이 된 채 이 모습을 바라보는 사장 뒤로 최형사가 들어온다.',
#  '야～아! 기합을 내지르며 덩치 좋은 건달들이 화면을 향해 달려온다. 순간, 구둣발 하나가 치솟아 오르더니 건달의 면상을 강타한다. 쿵! 어느 테이블을 박살내며 나자빠지는 건달. 보면, 이번엔 더 많은 놈들이 이형사를 향해 쇠파이프, 야구 방망이, 회칼 등을 들고 공격해온다. 이리저리 몸을 날리면서 놈들을 쓰러뜨리는 이형사. 순식간에 아수라장이 되는 연회장. 히익～ 울상이 된 채 바라보는 사장, 누군가가 던진 칼과 날아오는 몽둥이에 카운터 아래로 몸을 숙인다. 쿵! 쾅! 퍽! 부러지고 맞고, 박살나는 소리 속에 사장 주변으로 날아오는 온갖 병, 의자, 건달 등에 일어서려다 번번히 몸만 피하는 사장. 뒷편에서 지켜보던 두목과 몇몇 부하들, 안되겠다 싶은지 뒷문으로 도망간다. 이형사, 그놈들을 쫓아가려는 순간 뒷문으로 앞장서 도망가던 부하1이 면상을 맞고 뒤로 나자빠진다. 칼을 휘두르며 나서는 부하2 또한 복부를 맞고 움찔하는 사이 누군가의 단수가 우두둑! 손목뼈가 부러질 정도로 내려친다.',
#  "악! 비명을 지르며 나자빠지는 부하2. 보면 두목과 부하들 앞을 최형사가 막고 서 있다. 이형사, 의외인 듯 바라보며 다가가자 움찔했던 두목 등 중 부하3이 쇠파이프를 휘두르며 공격해 보지만 이형사의 화려한 발차기에 와장창 진열대를 박살내며 뻗고 만다. 이형사, 어깨를 두둑거리며 어떻냐는듯 최형사를 바라보는 순간 최형사를 향해 발차기를 하며 공격하는 부하4, 최형사의 맞발차기에 우두둑! 다리뼈라도 부러진 듯 하더니 비명을 지르며 다른 테이블을 박살내며 쓰러진다. 이번엔 최형사가 고개를 돌려가며 어떻냐는듯 이형사를 본다 완전히 갇혀 버린 두목과 부하 등, 양쪽으로 나뉘어 공격을 한다. 최형사와 이형사, 마치 경쟁하듯 달려드는 놈들을 처치한다. 이형사, 체인을 들고 달려드는 놈을 몸을 슬쩍 숙여 피하곤 멋진 훅 한방으로 박살을 내곤 이형사를 보며 '봤지?' 이형사, '어쭈?' 하곤 달려드는 엄청난 덩치를 잡아 빗장걸이 한판으로 창문으로 내던지곤 '이건 안될걸!' 하곤 보면, 최형사, '겨우 그 정도야?' 하곤 더욱 엄청난 덩치를 업어치기해 또 다른 창문으로 확 던져 버리곤, '난 이정도야!'.",
#  "'으잉? 제게 여자야?'하며 보다간 달려드는 놈에게 턱을 한 대 얻어맞는 이형사, 열이 확 받은듯 휘돌려 차기로 처리하곤 머쓱한 얼굴로 최형사를 보다간 휘둥그레지는 이형사, 한놈이 최형사를 향해 라이트 훅을 날리고 있다. 최형사, 급히 한팔을 들어 막으며 놈의 턱을 강타하곤 이단 옆차기로 마무리를 하며 '어때요?' 수차례 한번씩 서로의 멋진 공격이 교차하자 마지막으로 남은 두목이 둘 사이에 울상으로 서 있다. 최형사와 이형사가 마지막 남은 두목을 향해 동시에 주먹을 내지르려면, 털썩 바닥에 무릎을 꿇고 살려달라는 두목 위로 서로가 뻗은 주먹을 잡고 있는 최형사와 이형사, 서로를 노려본다. 이런 투캅스의 모습이 원경으로 보이면, 대롱대롱 매달린 형광등에 박살난 테이블, 의자, 깨진 유리창 등 완벽하게 폐허가 되버린 연회장의 모습이 과장되게 보여진다.",
#  '씬 34 경찰서 과장실',
#  '이형사의 멱살을 잡고 있는 과장.',
#  '과장:차라리 날 죽여라, 죽여. 야 이 인간아. 파트너 안바꿔준다고 나 짤리게 만들려는거지? 응?!',
#  '이형사:(고개를 숙인 채)죄송합니다.',
#  '과장:(마구 흔들며)이게 죄송하다고 될 일이야?! 나까지 감봉당했어, 인간아!?',
#  '씬 35 이형사 집 앞(N)',
#  '단아한 한옥 대문 옆의 초인종을 누르는 이형사.',
#  '소리: (엄마의)누구세요?',
#  '이형사:접니다. 경찰.',
#  '삐 소리와 함께 문이 열리면 안으로 들어가는 이형사.',
#  '씬 36 동 마당',
#  'ᄀ자 형태의 집에 작은 마당으로 걸어오는 이형사, 마당 한켠에서 태권도복을 입은 채 심호흡을 하더니 기왓장을 격파하는 아버지.',
#  '이형사:(지나치며)다녀왔습니다.',
#  '아버지:봤지? 응? 이제 여섯장까진 가뿐해. 어때? 내기 한번 할까? 응?',
#  '엄마:(마루에서 다가와)그만하세요. 태풍불면 지붕 날아가겠어요.',
#  '아버지:지붕이 중요해? 건강이 중요해?',
#  '이형사:(들어가며)들어가시죠, 아버지.',
#  '아버지:임마, 사내자식이 왜 젖은 풀빵처럼 축 늘어졌어?',
#  '씬 37 동 방안',
#  '군대용 식판이 놓인 술상에서 술잔을 90도로 절도있게 꺽어 들며 마시고 있는 아버지와 이형사.',
#  '아버지:야 이, 자식아 나가 죽어라! 죽어 내가 겨우 그 정도로밖에 못키웠어?',
#  '이형사:죄송합니다.',
#  '아버지:세상을 휘어잡아도 모자랄 사내놈이 그깟 여자하나 때문에 쩔쩔매다니….',
#  '이때 소주를 가져오는 엄마.',
#  '엄마:난 그래도 니가 일찍 오니 좋은데?',
#  '아버지:좋긴 뭐가 좋아?! 남자는 집에 있는 시간이 많을수록 밖에서 밀리는 법이야 하여튼 여자들은 단순하다니까!',
#  '엄마:요즘은 가정적인 남자가 성공한데요.',
#  '아버지:어떤 썩을 놈이 그런 말 해? 제발 티브이에서 하는 말 좀 믿지마! 응! 부자지간에 모처럼 이야기하는데 방해하지 말고 가서 노가리나 구워와.',
#  '으휴―. 눈을 흘기며 엄마가 일어나면 이형사에게 술을 따라주는 아버지.',
#  '아버지:임마, 여자는 초반에 기선 제압 못하면 끝장이야.',
#  '이형사:걘 자기가 쟌다르크인줄 알아요.',
#  '아버지:그래봤자, 여자야! 임마! 여자가 하자는 대로 일일이 받아주니까 피곤한거아냐? 임마.',
#  '이형사:그럼 어떻게요?',
#  '아버지:니 엄마 봐, 임마. 첨엔 대들더니 이젠 말 한마디면 되잖아? 임마! 상대방의 약점을 생각해! 여잔 여자일 수밖에 없다는 걸 보여줘. 알겠어?',
#  '이형사:아버님.',
#  '아버지:왜?',
#  '이형사:(두 손으로 잔을 들며)존경합니다.',
#  '아버지:(잔을 부닥치며)완 샷!',
#  '씬 38 고수부지',
#  '여명이 비추이는, 아직은 새벽인 고수부지에서 규칙적인 발소리에 따라 추리닝 차림으로 조깅을 하고 있는 이형사와 최형사.',
#  '이형사:(달리며)상쾌하지 않나? 좋은 경찰이 되려면 우선 체력이 강해야돼. 범인을 추적하다 보면 몇 일씩 밤새기 일쑤지.',
#  '최형사:(달리며)모처럼 같이 뛸 사람 있어서 좋은데요?',
#  '이형사:매일 조깅했나?',
#  '최형사:예 하루 10킬로씩요.',
#  '이형사:그으래?',
#  '최형사:이제 몸이 좀 풀리는데?',
#  '하며 빠르게 뛰어가는 최형사를 보며 달려가는 이형사.',
#  '씬 39 헬스장',
#  '땀에 젖은 채 헬스기구로 운동을 하는 투캅스. 서로 뒤지지 않을 듯 열심히 기구운동하는 모습이 보여진 뒤',
#  '이형사:(최형사를 보며)제법 하는데?(일어나는 최형사를 보곤)벌써 지친 건 아니지?',
#  '최형사:(다가와선)지치긴요?',
#  '하고 서로의 기구를 바꿔 운동하는 투캅스.',
#  '최형사:(기구로 운동을 하다간)할만 한데요? 좀 더 올려야겠군.',
#  '뒤지지 않고 이형사도 무게를 올린다. 투캅스, 땀에 뻘뻘 절은 채 서로를 노려보며 힘겹게 운동을 한다.',
#  '씬 40 수영장',
#  '출발점에서 수영복차림으로 몸을 풀고 있는 투캅스.',
#  '이형사:유연성과 지구력을 키우는덴 수영이 최고지. 열 번 왕복하고 한번 쉰다. 오케이?',
#  '최형사:그냥 하면 심심하니까 점심내기 할래요?',
#  '이형사:첫날부터 너무 무리하는 거 아냐?',
#  '최형사:(출발점에서 서며)괜찮아요. 어릴 적에 수영선수였어요.',
#  '인상이 찌푸려지는 이형사를 보며 수경을 쓰는 최형사. 동시에 풀로 점프해 들어가는 투캅스. 자유형으로 빠르게 허부적대는 이형사와 한참을 잠수한 뒤 불쑥 솟아오르는 최형사, 이형사를 한참 앞지른 채 헤엄친다.',
#  '자유형으로 꿋꿋하게 헤엄치는 이형사 맞은 편에서 버터플라이로 헤엄쳐오는 최형사, 중간에서 엇갈린 채 스쳐가는데',
#  '최형사:벌써 지친 건 아니죠?',
#  '여유만만하게 바라보면, 이를 악물고 지나쳐 가던 이형사가 으윽～ 다리에 쥐라도 난 듯 다리를 움켜쥔 채 물속으로 뽀르르 빠져든다. 최형사, 이런 이형사를 보곤 뒤돌아 헤엄쳐간다. 물 속에서 허부적거리는 이형사에게 다가가 물 속으로 더 쳐박아버리는 최형사, 힘이 빠진 듯 축 늘어지는 이형사를 보고서야 뒤에서 안은 채 밖으로 데려나간다.',
#  '씬 41 달리는 차 안',
#  '심각한 표정으로 말없이 운전을 하는 이형사, 하품을 쩌억 하다가 옆을 보면 최형사가 본다.',
#  '최형사:수영장에서부터 한마디도 안한 거 아세요? 아무리 여자한테 도움받았다 그래도 고맙단 말 정돈 해야되는 거 아녜요?',
#  '이형사:고마워.',
#  '최형사:(차를 한켠에 끼익 세우며)도대체 왜 그래요? 아침부터 불러내서 갑자기 조깅에, 헬스장에다 수영까지 강행군시키고. 그렇게 해서라도 날 그만두게 하고 싶은 거예요? 나랑 일하는게 그렇게 불편한가요?',
#  '이형사:좋아. 나도 최형사를 위해 솔직히 이야기하지. 최형사, 무술은 제법하는거 인정해. 하지만 그만둬. 아무리 개나 소나 경찰하는 세상이라지만 여자는 안돼. 경찰 일은 남자가 하는거야!',
#  '최형사:좋아요, 만약 여자가 해선 안되는 일이라면 그만두겠어요. 오케이?!',
#  '이형사:오케이!',
#  '씬 42 락까페 안',
#  '크지 않은 락까페에 음산한 음악에 맞춰 사람들이 북적거리며 오가고, 한켠에서 바라보는 이형사와 최형사.',
#  '이형사:여자들은 상황 판단이 느리지. 지금 이곳에서 무슨 일이 벌어지고 있나?',
#  '최형사:마약 거래군요.',
#  '이형사:잘찍는데? 어떤 놈인지 알겠나?',
#  '최형사:(쟈켓을 입고 나가는 한 놈을 보고 일어나며)지금 나가는군요.(이형사가 어떻게 알았냐는 듯 보면)여자의 직감은 가장 정확하죠.',
#  '씬 43 다른 거리',
#  '어느 편의점에서 계산을 하고 나오는 쟈켓을 바라보는 최형사와 이형사.',
#  '이형사:여자들은 미행할 때 금방 눈에 띄지.',
#  '나가는 쟈켓 뒤를 따라가는 최형사.',
#  '씬 44 어느 호텔 앞',
#  '걸어가는 쟈켓을 뒤따라가는 최형사. 쟈켓, 호텔 앞에서 침을 탁 뱉고는 힐끗 뒤돌아보곤 최형사에게 슬쩍 윙크를 하고는 호텔 안으로 들어간다. 최형사, 저 편에서 이형사가 다가오면',
#  '최형사:하지만 여자한텐 방심하게 마련이죠.',
#  '이형사:좋아. 하지만 여자들이 갈 수 없는 곳에서 놈들이 거래를 하는 경우가 많지.(호텔 사우나를 가리키며)잡을 수 있겠나?',
#  '씬 45 동 싸우나 안',
#  '옷을 벗고 있던 남자들, 카메라를 보곤 히익 놀란 채 몸을 가리기도 하는 속에 꿋꿋하게 걸어가는 최형사. 카메라, 탈의실을 지나 사우나 안으로 들어가는 최형사를 뒤따라가면 히익 놀라 물 속으로 뛰어드는 남자, 몸을 가리는 남자 등의 욕탕을 지나 한증막 안으로 들어간다. 그 안에서 수건을 교환하던 쟈켓의 남자와 문신을 한 남자가 뻥찐듯 최형사를 보면 곧장 경찰증을 보이는 최형사, 이런! 놀란 쟈켓과 문신이 최형사를 향해 덤비지만 최형사의 화려한 공격에 퍽! 두둑! 발차기와 엎어치기에 창문을 깨고 날아가는 놈들의 모습을 보며 뭐, 저런게 다 있지? 라는 듯 바라보는 이형사를 득의만만하게 바라보는 최형사.',
#  '씬 46 경찰서 사무실',
#  '최형사, 쟈켓과 문신을 데리고 들어와 다른 경찰에게 인도하는데 저 편에 앉아있는 투피스의 젊은 여자를 사이에 두고 중년의 남녀가 마구 다투고 있는 모습이 보인다.',
#  '중년여:(강사의 머리타락을 잡은 채)야 이, 자식아 내 딸 어떻게 할 꺼야? 너같은 놈은 콩밥을 먹어야돼!',
#  '강사:왜 이러시는 겁니까?',
#  '이런 두 사람에게 다가가 말리는 최형사와 이형사.',
#  '최형사:(미니에게)무슨 일입니까?',
#  '중년여:우리 애가 대학생인데, 이자식이 저녁 먹자고 꼬셔서 술을 먹인 뒤에(다시 강사를 덥치며)야이 나쁜 놈아!',
#  '강사:(뿌리치며, 점잖게)제가 억지로 데려간 게 아니라고 말씀드렸잖습니까?',
#  '중년여:술취했다고 거짓말하지마! 이 나쁜 놈아!',
#  '강사:명백하게 저항하지 않으면 강간으로 볼 수 없다는 판례아시죠? 물어보세요? 내가 강간했나? 응?',
#  '투피스:(고개를 흔들며)모르겠어요.',
#  '강사:보세요? 그리고 난 이혼상태니까 간통죄도 아닙니다. 법대로 해결하면 되잖습니까?',
#  '중년여:법? 그래? 이 더러운 놈아, 너 많이 배웠다!',
#  '하며 덤비는 중년여를 잡는 이형사.',
#  '이형사:이러지 마십시오, 저희가 알아서 하겠습니다.',
#  '강사:(여유있게)그럼, 법대로 하자구. 응?',
#  '하다간 갑자기 멱살을 움켜쥐는 손에 끌려 일어나는 강사. 보면 최형사가 강사를 잡고 있다.',
#  '강사:왜이래? 아가씬 뭐야?',
#  '최형사:나? 경찰!',
#  '하며 곧장 강사의 면상을 갈기면 뒤로 확 나자빠지는 강사.',
#  '최형사:(강사를 일으켜 도장 퍼버벅! 난타하며)일어나! 법보다 더 중요한 게 있어! 힘없는 여자에게 나쁜 짓을 하고도 뭐? 법대로?',
#  '주변의 형사들과 과장 등이 놀란 듯이 모습을 바라본다.',
#  '과장:(다가와서 잡으며)이봐, 최형사! 경찰이 이러면 안돼!',
#  '최형사:놓으세요! 이런 자식은 죽여 버려야 돼요!',
#  '하며 말리는 과장도 확 밀쳐버리자 뒤로 나자빠진다. 이형사, 안되겠는지 다가가서 강사에게 다시 주먹을 내지르는 최형사의 손목을 낚아챈다.',
#  '이형사:그만해!',
#  '최형사:놓으세요!',
#  '이형사:경찰서에서 이게 무슨 짓이야?! 당장 과장님하고, 이 남자분에게 사과해!',
#  '최형사:(노려보다가)좋아요. 사과하죠.',
#  '엉거주춤 일어나는 강사에게 다가가는 최형사, 다시 강사의 그 곳을 퍽! 발로 차버리곤 돌아서 나가버린다. 히익! 다시 고꾸라지는 강사, 돌아서 나가는 최형사를 뻥찐듯 바라보는 과장 등 경찰들.',
#  '이형사:(따라나가려 하며)최형사! 저게 정말….',
#  '과장:(괜히 이형사에게 귀를 잡으며)어딜 도망가? 야 이, 자식아, 다 누구 때문인데? 너하고 다니더니 최형사까지 개망나니가 됐잖아?! 임마!',
#  '팍 인상이 일그러지는 이형사의 모습에서―',
#  '형사들이 모두 빠져나간 텅 빈 사무실에서 최형사를 다그치는 이형사.',
#  '이형사:도대체 위계질서를 어떻게 아는거야? 군이나 경찰에게 제일 중요한 건 첫째도 복종! 둘째도 복종이란 거 모르나?! 하긴 여자라 군에 안갔다와서 모르겠군. 아무튼, 모든 팀웍은 부하의 절대 복종에서 나오는거야? 알겠나?',
#  '최형사:죄송합니다. 저 때문에 선배님까지 내근하게 되서….',
#  '이형사:(보지도 않은 채)됐어. 그 아주머니한테나 다음에 인사드려. 강사가 폭행죄로 최형사를 고소하겠다는 걸 아주머니가 나서서 서로 고소않는 걸로 합의해줬으니 망정이지 안 그럼 구속됐을 꺼야.',
#  '인상이 굳어지는 최형사.',
#  '최형사:그랬나요?',
#  '이형사:(혼잣말처럼)에휴, 이러니 여자들이 나서면 될 일도 안된다고 하지.',
#  '최형사:뭐라구요? 선배님 지금 말을 너무 심하게 하는 것 아닙니까?',
#  '이형사:또 대드는거야?! 방금 내 이야기 들은거야? 안들은거야?',
#  '화난 듯 서로를 노려보는 투캅스. 이때 울리는 전화벨소리에 동시에 손을 뻗는 투캅스. 최형사가 한발 빠르다.',
#  '최형사:예. 경찰서입니다.',
#  '소리:(아줌마의 절박한, Filter)우리 아이가 유괴당했어요.',
#  '최형사:예?!',
#  '씬 47 피해자 집 거실',
#  '의아한 표정으로 보는 이형사와 최형사에게 두 손을 내젖는―',
#  '아저씨:유괴라뇨? 그런 일 없습니다.',
#  '최형사:분명히 신고가 들어왔습니다.',
#  '아저씨:제가요? 다른 집이겠죠. 자, 그럼….',
#  '하며 투캅스를 막아서는 아저씨 뒤로 부엌에서 투캅스의 눈치를 보는 불안한 표정의 아줌마를 발견한',
#  '최형사:(다가서며)아주머니가 신고하셨죠?',
#  '아줌마:전, 전…',
#  '망설이는 아줌마, 뭔가 말을 하려 하자 아저씨가 먼저 말을 한다.',
#  '남편:어허, 어허, 자기 자식이 없어졌는데 그걸 숨길 부모가 어딨습니까?',
#  '이형사:최형사, 또 장난 전화에 속았구만, 도대체 일을 어떻게 하는거야?',
#  '최형사:아주머니, 사실대로 말씀해주세요. 저희가 해결하겠습니다.',
#  '남편:(안되겠다는 듯)전화한 적 없다니까 왜 이렇게 귀찮게 하는거야? 자, 이만 나가주세요.',
#  '최형사:아주머니, 왜 두려워하세요?',
#  '이형사:최형사, 남자분이 아니라는데 아줌마한테 왜 자꾸 물어?(아저씨에게)착오가 있었나봅니다. 죄송합니다.',
#  '남편:(현관으로 몰아내며)아닙니다. 괜한 걸음 하셨군요. 이거 약소하지만 차비나 하시고….',
#  '안주머니에서 돈을 꺼내 최형사에게 건내려하는 남편.',
#  '최형사:유괴범한테도 이렇게 돈으로 해결할껀가요?',
#  '이때 탁자위에 있는 전화가 울린다.',
#  '순간 남편과 아줌마가 긴장한 듯 전화기를 바라본다. 투캅스의 눈치를 보는 아줌마와 남편의 안절부절하는 모습을 보곤',
#  '최형사:제가 받을까요?',
#  '아줌마:(동시에)안돼!',
#  '남편:(동시에)안돼!',
#  '씬 48 유괴범의 아지트',
#  '화면 가득 겁에 질린 아이의 모습속에서',
#  '아이:(핸드폰을 대고)엄마 살려줘! 나 무서워!',
#  '소리: (아줌마의Filter)지선아! 지선아!',
#  '어둡고 허름한 창고 같은 곳에 있는 유괴범 세 명. 아이의 목을 팔로 조르고 있던 놈, 핸드폰을 빼앗는다.',
#  '유괴범:돈은 준비했나?…. 좋아, 설마 경찰에 신고는 안했겠지?',
#  '아이:(겁에 질린 채, 울먹이며)엄마!',
#  '유괴범:(아이를 때리며)시끄러!(핸드폰을 대고)만약 경찰 그림자라도 보이면 애는 죽어.',
#  '씬 49 어느 곳(N)',
#  '어둠을 가르며 달리는 그랜져가 지나치면 한적한 도로 변에서 커다란 가방을 들고 서있는 아줌마의 모습이 어둠속에 보인다. 주변의 편의점 안에서 직원 복장을 한 채 바라보는 형사1, 카세트테이프 가판대에서 장사를 하는 형사2, 그 옆에 주차한 어두운 차안에 엎드리다시피 숨어있는 형사 3, 4맞은 편 도로의 어두운 골목에 세워진 차 안에 있는 이형사 등의 모습이 빠르게 보여진다.',
#  '드문드문 오가는 사람을 바라보는 형사들의 눈빛들 너머의 건너편 도로로 그랜져가 천천히 지나간다.',
#  '형사1:(손목 시계에 대고)안 올것 같은데?',
#  '형사2:(귀에 찬 이어폰을 만지며)거기 히터 나오지? 지금이 몇월인데 왜 이리 추워? 젠장.',
#  '형사3:(바닥에 엎드려, 손목시계에 대고)그러게 사다리를 잘 타야지.',
#  '씬 50 달리는 차 안',
#  '천천히 이동하는 차 안의 시점으로 보이는 아줌마와 주변의 모습들. 운전을 하며 밖을 바라보는 유괴범1, 백미러로 보이는 아줌마의 모습이 작아져간다.',
#  '씬 51 동 어느 곳',
#  '어둠을 가르며 달려오는 자가용의 불빛이 비치자',
#  '형사2:(손목시계에 대고)뻐꾸기 하나, 뻐꾸기 하나….',
#  '형사1:진돗개 대기.',
#  '다가오던 자가용, 휭하니 지나쳐 가버리면 커다란 가방을 들고 서있는 아줌마의 모습이 어둠속에 보인다. 이때 저 편에서 도로에 비치는 불빛과 함께 달려오는 차가 내뿜는 헤드라이트에 비친 아줌마의 모습, 바로 변장한 최형사이다. 눈이 부신 듯 고개를 돌리는 최형사 앞으로 끼이익 멈춰서는 차. 재빠르게 내리는 유괴범1.',
#  '유괴범1:돈은?',
#  '최형사:(가방을 열어보이며)…',
#  '유괴범1:액수는 정확하겠지?',
#  '최형사:아이는 어딨어요?',
#  '유괴범1:다른 곳에 있어. 걱정하지 말고 돌아가',
#  '최형사:안돼요. 돈 가져왔으니까 아이도 풀어주세요.',
#  '유괴범1:(가방을 잡으며)시간없어! 10분 내로 안 돌아가면 애는 죽어.',
#  '최형사:(가방을 꽉 움켜쥐며)그럼 같이 가요. 내가 데려갈게요',
#  '하며 잡아 당기지만 가방을 꽉 감싸앉는 최형사. 긴장한 채 최형사와 유괴범을 지켜 보던',
#  '형사1:어떻게 하지?',
#  '형사2:애는 차안에 없어. 일단 최형사에게 맡겨.',
#  '최형사, 가방을 잡으려고 하는 유괴범1을 확 밀치며',
#  '최형사:애 풀어주기 전엔 절대 못줘.',
#  '유괴범1:안 놔? 이 개같은 년이 확～',
#  '하며 주먹을 내지르려는 유괴범1의 뺨에 번쩍 와닿는 최형사의 손. 퍽! 소리와 함께 고개가 돌아가는 유괴범1.',
#  '유괴범1:어쭈?',
#  '하며 다시 주먹을 내지르는 유괴범1. 하지만 어느새 최형사의 가방이 휙 날아와 유괴범의 머리를 내친다. 퍽! 뒤로 자빠지는 유괴범1',
#  '최형사:애 어딨어?',
#  '씬 52 동 부근',
#  '어느 나무 뒤의 오토바이에서 이 모습을 바라보고 있는 이형사와 아줌마, 놀란 표정이다.',
#  '아줌마:(작게)어머? 왜 저러는 거죠?',
#  '이형사:(작게)저도 몰라요.',
#  '아줌마:(나가려하며)저러면 우리 애 죽어요 안돼요.',
#  '이형사:(말리며)괜찮을겁니다. 안심하세요.',
#  '아줌마:(이형사를 퍽 치며)안심하긴 뭘 안심하란 말야? 놔!',
#  '이형사:(막으며)안됩니다!',
#  '나가려는 아줌마를 잡는 이형사, 아줌마의 몸부림에 마구 맞는다.',
#  '씬 53 동 그 곳',
#  '뒤로 자빠졌다가 일어나는 유괴범1',
#  '유괴범1:이게 누굴 패? 난 유괴범이야. 니 애를 데리고 있다고, 이 멍청한 년아',
#  '최형사:애 데리고 와. 안그러면 가방 못 줘',
#  '유괴범1:너 혹시 계모아냐? 빨리 안가면 애 죽는다니까 이 또라이 같은 년이….',
#  '하는 순간 저 편에서 패트롤카가 다가오자 멈칫하며 바라보는 두 사람.',
#  '유괴범1:이 년이 경찰을 불러?',
#  '최형사:아, 아냐. 내가 부른 게 아니에요',
#  '유괴범1:(작게)내가 잡히면 니 애는 바로 죽어, 알아?',
#  '하는데 멈춰지는 패트롤카에서 내리는 경찰1',
#  '경찰1:거기서 뭐하는 겁니까?',
#  '최형사:아, 아뇨.(유괴범을 툭치며)남편이 절 마중나와서 이제 가려는데요?',
#  '유괴범1:아, 예. 맞습니다.',
#  '경찰1:근데 이 가방은 뭡니까?',
#  '최형사:아? 이 가방요?',
#  '씬 54 동 근처',
#  '안절부절하며 이 모습을 바라보는 아줌마와 이형사.',
#  '아줌마:도대체 뭐하는 거에요?',
#  '이형사:걱정하지 마십시오. 잘될겁니다.',
#  '아줌마:잘 되긴 뭐가 잘돼?(이형사의 멱살을 잡으며)우리 애 잘못되면 죽을 줄 알아!',
#  '씬 55 동 그 곳',
#  '최형사와 유괴범1 앞에 서 있는 경찰1. 유괴범1, 뒷주머니에서 칼을 빼든다.',
#  '경찰1:두 분이 싸우는 것 같던데요?',
#  '최형사:아뇨. 그럴 리가 있나요?(팔짱을 끼며)그치? 자기?',
#  '유괴범1:(어색하게 웃으며)그럼요.',
#  '경찰, 이상한 듯 두 사람을 다시보자 어색한 미소를 짓는 최형사와 얼굴이 맞아 부어오른 유괴범1',
#  '경찰1:부부 싸움은 집에서 하세요.',
#  '하며 엉망이 된 유괴범1을 한심한 듯 보며 경찰차에 올라탄다. 최형사와 유괴범1, 긴장한 채 지나쳐 가는 경찰차를 본다.',
#  '씬 56 달리는 차 안',
#  '운전을 하는 유괴범1 옆에 최형사가 가방을 안고 있다.',
#  '유괴범1:모처럼 경찰 한 번 죽여보나 했더니…. 씨발.',
#  '최형사:경찰까지 죽인 적 있나요?',
#  '유괴범1:그럼, 날 귀찮게 쫓아다닌 놈이 있었거든, 야구방망이로 내리친 뒤 살려달라도 애원하는 걸 보며 생매장했지. 그때 느낀 건데 역시 경찰 죽일때가 제일 스릴있단 말야.',
#  '최형사:정말 죽일 놈이군.',
#  '유괴범1:뭐? 이 썅년이. 아까부터 계속 성질돋구네.',
#  '하고 때리려하면 먼저 최형사의 손바닥이 유괴범1의 뺨을 때린다.',
#  '최형사:운전이나 똑바로 해.',
#  '유괴범1:씨발…. 무슨 엄마가 이래?',
#  '씬 57 도로',
#  '인적없는 도로를 달리는 차 뒤로 라이트를 끈 채 이형사와 아줌마가 오토바이를 타고 간다.',
#  '씬 58 유괴범의 아지트',
#  '인적이 없는 한적한 야외의 어두컴컴하고 허름한 창고 앞에 멈춰서는 차에서 내리는 유괴범1과 최형사.',
#  '유괴범1:(문을 세 번, 한번 두드리곤)나야. 유괴범.',
#  '씬 59 아지트 안',
#  '문을 여는 유괴범2, 유괴범1 뒤로 최형사가 들어오자 놀란다. 최형사, 안을 보면 아이가 묶인 채 바닥에 앉아있는 옆에 유괴범3이 담배를 피우고 있다.',
#  '유괴범2:여잔 왜 데리고 왔어?',
#  '유괴법1:어차피 내 얼굴을 봤는데 애새끼랑 같이 죽여버려야지.',
#  '유괴범3:(아이를 툭 치며)임마, 니엄마 왔다.',
#  '최형사:(다가가며)지선아! 괜찮니?',
#  '아이:우리엄마 어딨어요?',
#  '휙 쳐다보는 유괴범 1, 2, 3',
#  '최형사:지선아, 엄마야.',
#  '아이:아줌만 누구야?',
#  '유괴범3, 다가오는 최형사를 보곤 재빨리 아이의 목에 칼을 갖다댄다.',
#  '유괴범3:움직이지마! 너 누구야?',
#  '최형사:도대체 아이한테 무슨 짓을 한거예요? 엄마도 못알아보잖아요? 임마, 자세히 봐! 엄마잖아?',
#  '유괴범3:(아이에게)니네 엄마 맞아?',
#  '아이:아냐, 우리엄마 어딨어?(울며)엄마! 엄마!',
#  '유괴범1:그럴 줄 알았다. 이 썅년.',
#  '유괴범3:죽여!',
#  '유괴범2, 재빠르게 칼을 꺼내드는데 유괴범2를 돌려차기로 날려버리는 최형사, 휘둥그레진 유괴범1, 금방이라도 팰 듯이 가다간 최형사가 휙 뒤돌아보면 겁에 질린 듯 멈칫한다.',
#  '유괴범3:뭐해? 새꺄?!',
#  '하는 순간 어느새 총을 꺼내 든 최형사, 유괴범3을 겨누며',
#  '최형사:(유괴범3을 겨눈 채)꼼짝마!',
#  '유괴범3:(아이의 목에 칼을 댄 채)총버려! 총안버리면 죽여버릴꺼야!(아이의 목에 댄 칼에 힘을 주며)하나! 두울!',
#  '최형사:(바라보다가)좋아, 대신 아이는 살려줘!',
#  '유괴범3:알았어. 약속하지.',
#  '총을 천천히 내려 총알을 밖으로 빼버린 채 저 편으로 던지는 최형사. 유괴범3, 신경질적으로 아이를 뒤로 밀치곤 최형사에게 다가간다.',
#  '유괴범3:이 년이 겁도 없이….',
#  '유괴범1:(바닥에 떨어진 총과 총알을 집으며)임마, 저 여자 싸움 졸나 잘 해!',
#  '유괴범3:병신같은 게 기집년한테 겁먹기는 비켜! 임마.',
#  '하며 칼을 휘두르며 공격해 들어가는 유괴범3. 최형사, 슬쩍 피하며 칼을 든 손을 우두둑 꺽으며 바닥에 내동댕이친다. 바닥에 널부러진 유괴범3을 보며 허겁지겁 총과 총알을 드는 유괴범1, 총알을 넣으려고 하지만 긴장한듯 번번히 떨어지기만 하는데 어느새 다가오는 최형사를 보곤 곧장 총을 바닥에 떨어뜨리고 손을 든다. 이와 동시에 문을 쾅 차고 들어오는 이형사와 아줌마, 울먹이는 아이와 엄마가 포옹하는 모습을 바라보는 투캅스의 모습속에…',
#  '씬 60 서장실',
#  '선행하는 박수 소리와 함께 정복 차림의 최형사의 어깨 위에 잎파리 세 개의 계급장을 달아주는 서장.',
#  '서장:(악수를 하며)축하해. 최경장, 최단 기간 승진 기록이야. 개망신 당할 뻔한 우리 경찰서를 최형사가 구해줬어.',
#  '최형사:감사합니다.',
#  '뒷편에서 박수를 치는 동료형사들 속에 이형사도 보인다.',
#  '씬 61 동 복도',
#  '커피 자판기 앞에 있는 최형사에게 다가가는 이형사.',
#  '이형사:축하해, 최형사!',
#  '최형사:(돌아보며)어? 고마워. 이형사. 한잔 하겠나?',
#  '이형사:뭐? 지금 나한테 반말하는 거야?',
#  '대뜸 나오는 최형사의 반말에 어이가 없다. 최형사, 돌아보며 이형사에게 뽑은 커피를 내밀며',
#  '최형사:같은 경장끼리 앞으로 잘해보자구. 응?',
#  '이형사:하루 잎파리 호봉 무서운 줄 모른다더니, 같은 경장이라고 맞먹자는거야?',
#  '최형사:응. 이젠 상사와 부하가 아닌 동등한 파트너 관계로 일해보자는 거야 똑같은 조건에서의 경쟁, 할만하지 않아?',
#  '이형사:(정면으로 노려보며)지금 나한테 도전하겠다는 거야?',
#  '최형사:(어깨를 툭툭 치며 지나치며)아니, 분발하라는 거야.(커피를 마시며)음, 커피 맛 좋은데?',
#  '휙, 고개를 돌려 지나치는 최형사를 노려보는 이형사, 커피를 곧장 휴지통에 확 버린다.',
#  '씬 62 은행 계단',
#  '은행의 유리문을 보며 계단으로 꺽어져 들어가는 흑장갑과 목장갑, 둘 다 모자를 눌러쓴 채 계단의 모퉁이에 멈춰선다.',
#  '흑장갑:지난 번 실패를 거울 삼아 이번엔 제대로 하자, 위험이 큰 만큼 더 짭짤하다. 남자가 은행 정도는 털어야 한다고 어릴 때부터 다짐하곤 했었다.',
#  '목장갑:형님 어릴 때 꿈이 은행강도였습니까?',
#  '흑장갑:(담배를 꺼내 물며)그래. 넌?',
#  '목장갑:제 꿈은 우리 같은 은행강도를 빵! 빵! 총으로 쏴죽이는 경찰이 되는 거였습니다.',
#  '흑장갑:(답배를 피우며 팰 듯이)개새꺄, 개소리 계속하면 개패듯이 패버릴꺼야, 알았어?',
#  '목장갑:(벽에 붙은 금연표시를 보곤)행님, 여기 금연구역인데요?',
#  '흑장갑:(휙 보더니 마구 때리며)씨발놈이, 법 지킬려면 경찰하지 미쳤다고 은행강도하냐?',
#  '하는데 계단에서 한 여자가 올라오자 멈칫하며 어색하게 목장갑이 옷을 털어주는 흑장갑. 목장갑의 소매에 숨긴 쇠파이프가 흘러나오자 쓸어올리며 자신의 소매에 숨긴 쇠파이프도 감추는 흑장갑. 치마를 입고 올라가는 여자를 보며 슬쩍 미소짓는 흑, 목. 위로 향하는 여자를 보며 고개를 숙이다간 둘이 눈이 마주치자',
#  '흑장갑:(모자를 다시 눌러쓰며)시작하자.(은행 안으로 들어가며)수표는 절대 챙기지마.',
#  '씬 63 동 은행 안',
#  '제법 사람들이 있는 은행의 뒷문으로 들어오는 흑장갑과 목장갑. 흑장갑의 신호에 따라 청원경찰 쪽으로 고개를 숙인채 다가가는 목장갑. 목장갑, 청원 경찰의 뒤로 다가가 소매안에 있는 쇠파이프를 꺼내려는데 팔꿈치에서 틱! 걸린다. 당황한 목장갑, 뒤돌아서는 청원경찰을 굳은 표정으로 바라보는 순간, 퍽～하는 소리와 함께 목장갑 앞으로 쓰러지는 청원경찰. 의아스레 바라보면, 은행강도1이 총을 들고 서있다. 이와 동시에 창구 위로 훌쩍 뛰어 올라가는 은행강도2.',
#  '강도2:(총을 꺼내들고)모두 엎드려! 움직이는 놈은 죽여버릴꺼야!',
#  '하며 천장에 대고 총을 쏜다.',
#  '꺄악! 비명을 지르며 바닥에 엎드리는 사람들 속에 흑장갑과 목장갑, 바닥에 엎드린 채 서로를 본다.',
#  '목장갑:(바닥에 엎드린 채)형님, 어떻게 된겁니까?',
#  '흑장갑:(바닥에 엎드린 채)내가 아냐? 임마.',
#  '목장갑:우리도 은행강도잖아요? 그냥 이렇게 당하고 있을 껍니까?',
#  '흑장갑:그럼 동업이라도 하자고 해봐. 임마!',
#  '강도1:(다가와선)조용히 안해?! 죽고싶어?!',
#  '겁에 질린 듯 바닥에 얼굴을 묻는 흑·목장갑의 모습에서….',
#  '씬 64 어느 은행 앞',
#  '많은 경찰차들과 경찰들이 북적거리는 곳으로 걸어 들어오는 투캅스. 한 경찰이 이형사를 알아보고 경례를 하면 통과하는 이형사 뒤로 걸어가는 최형사를 잡는 경찰. 최형사, 경찰증을 보이며 이형사를 뒤따라간다.',
#  '이형사:몇 명이야?',
#  '경찰2:두 놈입니다.',
#  '이형사:그래?',
#  '경찰2:인질들을 잡고 대치중입니다. 총을 가지고 있습니다.',
#  '이형사:(최형사에게)수준차이를 보여주지. 잘 봐.',
#  '하면서 권총을 뽑아들고 건물 뒤로 달려간다.',
#  '씬 65 동 은행 안',
#  '엎드려있는 사람들 속에 가방 두 개를 들고 불안스레 밖을 보는 강도1, 2.',
#  '소리:(경찰의 확성기)너희는 완전히 포위됐다. 무기를 버리고 투항하라!',
#  '강도2:어떡하지?',
#  '강도1:씨발, 어떡하긴…(흑장갑을 툭툭 차며)일어나!',
#  '흑장갑:예? 저요?',
#  '강도1:죽고 싶어?',
#  '흑장갑:(벌떡 일어나며)아뇨. 사실 우리도 당신처럼….',
#  '강도1:시끄러!(흑장갑의 뒷덜미를 잡아 일으켜 머리에 총을 대보이며)비켜! 안 그러면 1분마다 한 명씩 죽여버릴꺼야!',
#  '흑장갑:(겁먹은 채)살려주세요. 제, 제발….',
#  '목장갑, 이런 흑장갑이 모습을 보며 휴. 안도의 한숨을 내쉬는데 뒷문을 쾅 열고 들어오는 이형사, 총을 들고 있다.',
#  '이형사:(총을 겨누며)꼼짝마!',
#  '강도1:(흑장갑의 머리에 총을 겨눈 채)총 버려! 죽여버릴꺼야.',
#  '흑장갑:제발… 살려주세요.',
#  '이형사:여기가 미국인 줄 알아? 가짜총인지 알고 있어.',
#  '강도1:가짜 아냐!',
#  '하며 천장을 향해 총을 쏜다. 탕! 총에 맞아 깨지는 형광등. 총소리에 놀라 비명을 지르는 사람들. 다가가던 이형사 멈칫한다. 강도1에게 인질로 잡힌 흑장갑, 완전 사색이 된 채 오줌이라고 싼 듯 바지에서 물을 주루룩 흘러내린다.',
#  '강도1:이래도 장난처럼 보여?',
#  '이형사:나도 장난 아냐. 임마! 총 버려!',
#  '하며 천장에 대고 총을 쏘는 이형사. 탕! 총에 맞아 다른 형광등이 깨진다. 거의 실신한 흑장갑의 다리가 풀리자 강도1이 힘겹게 부축한다.',
#  '이형사:다음은 니 머리야! 빨리 총버려!',
#  '강도1:다가오지마!',
#  '흑장갑:제발…. 살려주세요.',
#  '이형사:사건에 따라 때론 약간의 희생은 불가피하지. 죄송합니다.',
#  '강도2:저거, 미친 놈 아냐?',
#  '이형사:셋, 둘.(노리쇠를 당긴 후)하..',
#  '하는 순간 뒤에서 누군가의 손이 이형사의 뒷덜미를 내리친다. 퍽! 힘없이 바닥으로 쓰러지는 이형사 뒤로 보이는 목장갑의 모습.',
#  '강도1:(총을 겨누며)넌 뭐야?!',
#  '목장갑:(움찔하며)총 좀 치워요. 저 형하고 나도 원래는….',
#  '강도1:아는 사이야?',
#  '목장갑:예. 사실 우리도 은행 털려고 왔는데 형씨들이…',
#  '강도2:(목장갑의 목에 총을 대고)개소리하지마. 시간없어. 새꺄, 따라와!',
#  '하며 끌고 뒷문 쪽으로 나가려하는데 문 앞에 최형사가 버티고 서있다.',
#  '강도2:뭐야? 비켜!',
#  '하며 최형사를 위협적으로 밀치고 가려는 순간 흑장갑의 부부를 퍽! 발로 차고는 읔…. 흑장갑이 앞으로 몸을 숙이는 순간 강도2의 면상을 그대로주먹으로 갈기는 최형사. 휘청! 비틀거리는 강도2를 화려한 발차기로 퍼억! 쓰러뜨리는 최형사. 히익! 놀란 듯 최형사에게 총을 겨누는 강도1.',
#  '순간 더 빠르게 총을 꺼내드는 최형사, 타앙! 총성과 함께 어깨에 총을 맞고 뒤로 튕겨나는 강도1. 쾅! 강도1의 총이 허공으로 쏴지는 순간, 재빠르게 강도1을 덥치는 최형사. 총을 집어드는 강도1의 손을 밟는 최형사. 두두둑! 아악! 비명을 지르는 강도1. 최형사, 강도1의 손에 철컥 수갑을 채우는 모습 뒤로 겁에 질린 채 옴짝달싹 못하고 있는 흑장갑을 부축해 빨리도 기어 도망가는 목장갑 등이 우스꽝스레 보인다.',
#  '씬 66 서장실',
#  '선행하는 박수소리 속에 최형사의 어깨에 잎파리 네 개의 계급장을 달아주는 서장.',
#  '서장:축하해. 최경사. 경찰 사상 최고 빠른 승진기록이야!',
#  '최형사:감사합니다. 서장님.',
#  '뒷편에서 박수를 치는 경찰들 속에 이형사의 모습도 보인다.',
#  '서장:여성 최초의 강력계 형사 반장이야. 잘 해낼 수 있겠지?',
#  '최형사:주위분들이 도와주셔야죠.',
#  '서장:(주위를 보며 호통을 치듯)모두 잘들어! 특히 형사 3반. 앞으로 나이 어린 여자라고 말 안 들으면 다 짤라버릴꺼야. 알았어?',
#  '경찰들:(힘차게)네!',
#  '씬 67 달리는 차안',
#  '보조석에 앉아있는 이형사. 옆에 운전하는 최형사.',
#  '이형사:(슬쩍 보곤)축하해, 최형사. 제대로 된 사람은 올라갈수록 겸손해진다더니, 최형사가 운전하겠다고 할 줄 몰랐어. 아무튼, 이번엔 내가 진 걸 인정하지. 최형사 말대로 앞으로 잘해보자구.',
#  '최형사:이형사, 반말하지마!',
#  '이형사:(놀라)뭐?',
#  '최형사:이전에도 상관한테 항상 반말했나?',
#  '이형사:아니. 하지만 최형사….',
#  '최형사:(말을 막으며)나한테 위계질서를 강조한 사람이 이형사 아니었나? 같이 일하는 동안에는 상사로써 대우하도록. 알겠나?',
#  '이형사:(끓는 듯 바라보며)….',
#  '최형사:만약 이형사가 평생 내 부하로 일할거라면 대답 안해도 돼.',
#  '이형사:(바라보기만 하며)…. 예 써.',
#  '씬 68 대학교 정문',
#  '경례하는 수위를 뒤로 한 채 학교로 들어가는 차.',
#  '씬 69 강의실',
#  '<여성의 사회적 지위 향상 …> 등이 쓰인 칠판 앞에서 강의하는 강사.',
#  '강사:어느 나라가 과연 얼마만큼 진보했는가를 알려면, 그 사회에서 여성의 지휘를 보면 된다 라고 했듯이….',
#  '하는 순간 문을 벌컥 열고 들어오는 최형사. 웅성거리는 학생들을 보며 당황하는 강사.',
#  '강사:(학생들에게)잠깐만…(최형사에게 다가가며)아니, 강의하는데 이렇게 들어오면 어떡합…',
#  '하는 순간 곧장 강사의 배를 퍽! 갈기는 최형사. 말을 하다가 곧장 힘없이 앞으로 쓰러지는 강사를 올려매는 최형사.',
#  '와～ 어머～ ……. 웅성거리는 학생들.',
#  '최형사:(강사를 올려맨 채)오늘 강의는 이것으로 마친다. 이상!',
#  '하며 밖으로 나가는 최형사.',
#  '씬 70 다른 곳',
#  '공사라도 하는 건물 벽에 양손과 발을 벌린 채 묶여있는 강사가 버럭 버럭 고함을 지른다.',
#  '강사:당장 풀어! 지난 번에 봐줬더니 또 무슨 짓이야? 불법 감금에 인권유린이라는 거 몰라?! 나가면 당장 고발할꺼야!',
#  '하며 고함을 지르는 강사 앞에 뒤돌아서있는 이형사.',
#  '이형사:(다시 뒤돌아서며)어쩔 수 없습니다. 잠시만 기다리십시오.',
#  '강사:이 여자 어디갔어? 당장 데려와!',
#  '하는데 선행하는 최형사의 목소리.',
#  '최형사:아직도 큰 소리군!',
#  '휙 뒤돌아보는 이형사.',
#  '이형사:최반장님. 우선 풀어주고 정식적인 절차를 밟아서….',
#  '최형사:(커다란 가위를 들어보이며)구해왔어.',
#  '이형사:(질겁해서)예? 최반장님… 설마….',
#  '최형사:(다가가며)법으로 악을 막을 수 없다면 힘으로 막아야 돼.',
#  '이형사:(잡으며)그건 경찰의 임무가 아닙니다.',
#  '최형사:때론 범인체포보다 범죄예방이 더 중요해.',
#  '이형사:안됩니다.',
#  '강사:(분위기 파악못한 채)지금 뭘 짜르겠다는 거야?',
#  '최형사:(뿌리치며)저런 놈은 화장실 갈 자격도 없어!(가위를 높이 들고)비켜!',
#  '강사:안돼! 잘못했어요. 제발… 이것만은…',
#  '최형사:(가위로 자크를 잘라내며)뭘 잘못해? 강간한 게 아니라며?',
#  '이형사:(다시 잡으며)최반장님!',
#  '강사:여자가 반항했어요. 제가 강간한거라구요. 제 가슴에 보면 상처도 있다구요. 제발 구속시켜주세요. 제발!',
#  '이런 강사를 보는 이형사와 최형사의 모습에서―',
#  '씬 71 달리는 차 안',
#  '운전을 하는 최형사 옆에 앉아있는 이형사.',
#  '이형사:최반장님.',
#  '최형사:왜?',
#  '이형사:사적인 질문 하나 해도 괜찮겠습니까?',
#  '최형사:뭐?',
#  '이형사:혹시 가족이나 친척 중에 아내를 버리고 도망간 남편이 있었습니까?',
#  '최형사:(바라보다간)지금― 시비거는 거야?',
#  '이형사:아뇨. 그냥 물어보고 싶었습니다.',
#  '최형사:아직까진 없어.',
#  '이형사:그럼 이전에 남자한테 심하게 배신당한 적 있습니까?',
#  '최형사:그 전에 내가 먼저 물어보지. 혹시 이형사 가족 중에 정신이상자는 없었나?',
#  '이형사:(바라보다간)됐습니다.',
#  '최형사:제발 바보같은 질문하지마. 알았어?',
#  '씬 72 어느 계곡',
#  '사람이 없는 야산에서 추리닝 차림으로 달리는 흑장갑과 목장갑.',
#  '목장갑:형님, 언제까지 달리기만 할껍니까?',
#  '흑장갑:백 번 성공하는 것 보단 한번 잡히지 않는 게 더 중요하다.',
#  '목장갑:전 잡혀도 좋으니 뭐든 딱 한번이라도 성공해봤으면 좋겠습니다.',
#  '흑장갑:새꺄, 깜빵들어간 대통령들 봐라, 몇 천억 있으면 뭐하냐? 써보지도 못하고 인생 쫑쳤잖아? 임마.',
#  '목장갑:그 사람들도 달리기를 못해서 잡혔습니까?',
#  '흑장갑:씨발 놈아, 말이 그렇다는거지… 근데, 이 개새끼가…',
#  '하며 휙～ 주먹을 휘두르면 피하는 목장갑, 재빨리 도망간다.',
#  '흑장갑:어쭈? 이리 안와?',
#  '목장갑:(산 쪽으로 도망가며)또 팰라구?',
#  '흑장갑:(쫓아가며)안 때릴게! 새꺄, 하나님을 걸고 맹세한다.',
#  '목장갑:(도망가며)형은 믿지도 않잖아요!',
#  '흑장갑:(바닥의 돌을 던지며)이 새끼가 맹세한다니까… 너 잡히면 죽었어!',
#  '하면서 산 쪽으로 빠르게 도망가는 목장갑, 무언가에 걸린 듯 우당탕 넘어지면 그 위로 덥치는 흑장갑.',
#  '흑장갑:(손을 두둑 꺽으며)넘어질 줄 알았다. 이 새끼가….',
#  '목장갑:(발 아래를 보곤, 경악스레)허억! 저기… 저기.',
#  '흑장갑:쨉쓰지마, 새꺄.',
#  '위협적으로 다가가던 흑장갑, 목장갑이 겁에 질린 눈으로 발 아래를 가리키는곳을 보면 나무가지들 속에서 누군가의 팔이 터억 나와있다. 으아악～ 비명을 내지르는 흑장갑과 목장갑의 모습에서…',
#  '타임 컷―',
#  '패트롤카의 사이렌 소리 속에 카메라, 빨간 불을 뿜으며 돌아가는 경광등의 경찰차 너머로 이동하면 검시관 등이 북적거리는 사이로 걸어가는 투캅스.',
#  '목과 머리에 피를 흘린 채 죽어있는 여자를 보며 다가가는 이형사.',
#  '이형사:(최형사를 힐끗 보며)어디 한 번 살펴볼까?',
#  '하며 여자의 눈동자를 살피곤 목에 깊이 패인 상처를 본다.',
#  '이형사:(목을 살피며)이런 잔인한 놈! 가위로 한 번에 목을 땄군. 칼로 그으면 오른쪽과 왼쪽의 깊이가 차이날 수밖에 없 죠.',
#  '검시관:(큰 가위를 보이며)범행 현장에서 발견된 겁니다.',
#  '이형사:날카로운 면이 왼 쪽에 있는 걸 보면 놈은 왼손잡이야.',
#  '이런 이형사 뒤로 다가와 바라보는 최형사. 이형사, 이번엔 목에 난 피를 스윽 닦아내 입가로 가져간다.',
#  '이형사:(피를 맛보며)하루 정도 지났군.',
#  '검시관:혈흔 채취를 저희가 했습니다.',
#  '최형사:이형사, 그런 건 검시관한테 맡겨.',
#  '하며 이형사를 보지만 아무런 반응이 없다.',
#  '이형사:(이번엔 더 깊숙이 찔러대며)아닌가? 이틀인가? 오늘 점심은 뭘 먹지? 내장탕 어때요?',
#  '최형사:(뒤로 팔을 확 꺽으며)하지 말라고 했잖아? 죽은 사람한테 무슨 짓이야! 당신 드라큐라야? 응?',
#  '이형사:이 사건은 제가 맡기로 했잖습니까?',
#  '최형사:사건 맡으라고 했지, 시체 주무르라고 했어?! 죽은 사람이라고 함부로 대해도 되는거야?(팔을 꺽은 채 이형사의 얼굴을 시체에게로 밀치며)당장 사과해!',
#  '이형사:(눈을 뜨고 죽은 시체와 얼굴을 맞댄 채)죄송합니다.',
#  '최형사:나한테 말고 이 여자한테!',
#  '이형사:(눈을 뜨고 죽은 시체를 코앞에서 보며)이 여자한테요?',
#  '최형사:그래, 빨리 해!',
#  '이형사:(시체를 보며)아가씨, 미안해.',
#  '최형사:더 크게!',
#  '이형사:(시체와 얼굴을 맞댄 채)미안하다구요!',
#  '씬 73 공사중인 건물 계단',
#  '공사중인 건물 계단으로 올라가는 투캅스.',
#  '최형사:여긴 왜 온거야?',
#  '공사장의 턱을 넘는 최형사의 모습 위로 선행하는',
#  '소리: (정보원들의)… 여덟. 아홉. 열. 번호 끝.',
#  '씬 74 동 안',
#  '의아한 표정으로 들어오는 최형사. 어깨에 잔뜩 힘이 들어간 이형사 앞에 일렬로 정열해 있는 인상 더러운 정보원들이 경례를 한다.',
#  '정보원들:추웅～성!',
#  '이형사:(정보원들 앞으로 걸으며)오늘 내가 제군들을 집합시킨 이유는…',
#  '최형사:이형사, 이 사람들 뭐야?',
#  '이형사:(최형사에게)저를 하늘처럼 믿고 따르는 정보원들입니다.(정보원들에게)우리 구역에서 발생한 살인사건을 모두 알 것이다….',
#  '이형사가 폼을 잡고 왔다갔다하며 말하는 동안 정보원들을 쭉 둘러보던 최형사, 가운데에 있는 한 정보원 앞에 서더니',
#  '최형사:너 이한구지?',
#  '정보원1:왜 그래?',
#  '최형사:절도에 특수강도. 합이 전과 5범. 맞지?',
#  '정보원1:근데, 왜?',
#  '최형사:(정보원1을 퍽 까곤)말높여! 임마. 나도 경찰이야.(또 한 명을 발견하곤)어? 너 강간폭행했던 김한일이지?',
#  '정보원2:그래. 왜?',
#  '최형사:(다시 퍽 까곤)말 높이라니까.',
#  '정보원2:(당황한 듯)이형사님!',
#  '최형사:(한명씩 툭툭 치며)강간, 폭행, 절도, 관내 우범자들을 모두 다 모여있잖아?(이형사에게)이게 뭐야?',
#  '이형사:(수갑을 채우려는 최형사를 잡으며)하지만 지금은 모두 손 씻고 제 정보원을 하고 있습니다.',
#  '최형사:뭐? 손을 끊어? 말도 안되는 소리하지마! 이런 놈들 다 필요 없어.(정보원들에게)모두 해산해!',
#  '어리둥절한 정보원들, 웅성거리며 이형사의 눈치를 본다. 이형사를 보며 어떻게 된거야? 등등을 말하며 웅성거리는 정보원들.',
#  '이형사:정보원 없이 무슨 수사를 한단 말입니까? 최반장님이 아직 현실을 몰라서…',
#  '최형사:그렇다고 범죄자들과 손잡으라곤 안했어. 3초내로 해산 안하면 모두 연행한다. 하나. 둘!',
#  '정보원들, 이형사님. 죄송합니다― 등을 말하며 가려하자',
#  '이형사:(정보원들에게)모두 움직이지마!(최형사에게)당신 정말 이런 식으로 할겁니까?!',
#  '최형사:지금 항명하는거야?!',
#  '이형사:(화난 듯)예 써!',
#  '최형사:한 번 해보겠다는 거야?!',
#  '이형사:(가소롭다는 듯 바라보며)허, 참….',
#  '하는 순간 날아오는 최형사의 주먹을 맞고 자빠지는 이형사. 정보원들, 일제히 이형사님, 죄송합니다. 따위를 말하며 일순간에 흩어지는 속에 일어나는 이형사.',
#  '정보2:야… 경찰에 신고해야 되는거 아냐?',
#  '정보2:놔둬. 지들끼리 싸우는데 뭐.',
#  '씬 75 무도관',
#  '텅빈 무도관, 무도복 차림의 최형사 앞에서 화려한 예비동작으로 몸이라도 푸는 이형사, 멈춰 뒤돌아서더니',
#  '이형사:여지껏 여자를 때리는 놈만큼 한심한 놈은 없다고 믿었지만, 지금은 예외야! 날 원망하지마!',
#  '최형사:그래? 말 끝났으면 시작하지?',
#  '이형사:선제 공격해! 그 정돈 접어주지.',
#  '최형사:각오해!',
#  '이형사:(기합을 내지르며)햐!',
#  '최형사의 빠른 발놀림을 피하는 이형사. 최형사가 내뻗는 주먹을 피하고 엎어치기라도 할 듯 가슴팍을 확 잡았다가는 놀란 듯 멈칫 하며 바라보면, 날아오는 최형사의 발차기에 뒤로 나자빠진다. 다시 겨루기를 하는 투캅스, 이번에도 서로의 공격을 잘 막다가 이형사가 주먹으로 최형사의 가슴을 때리려다 움찔하면 어느새 최형사가 퍼버벅! 연타 공격을 해 뒤로 나자빠지는 이형사.',
#  '이형사:더 이상 안봐줘!',
#  '이야! 고함을 지르며 최형사와 다시 겨루는 이형사. 두사람, 화려하게 공격을 하다간 서로 동시에 발차기에 맞고 넘어졌다간 동시에 훌쩍 일어난다.',
#  '그렇게 난타전을 벌이는 도중 서로 지친 상태에서 이형사가 최형사의 가슴팍을 때리곤 최형사가 가슴을 잡고 움찔하자 힘껏 올라오는 발이 이형사의 사타구니를 강타한다. 읔! 그 곳을 맞은 채 완전히 몸이 굳는 이형사, 손을 그 곳으로 가져가는 순간, 최형사의 주먹에 이은 발차기가 강타한다.',
#  '퍽! 뒤로 나자빠지는 이형사.',
#  '최형사:이건 상사로써가 아니라 여지껏 여자들을 무시한 대가예요. 억울하면 소문내고 다니세요.',
#  '하며 휙 돌아서가는 최형사 뒤로 그곳을 만지며 웅크리고 있는 이형사의 모습 속에―',
#  '씬 76 이형사 집 방 안(N)',
#  '화면 가득 멍이 든 눈을 한 이형사가 아버지와 술을 마시고 있다. 인상을 쓴 채 술을 마시고 잔을 내려놓는 아버지.',
#  '아버지:뭐? 사표?',
#  '이형사:더 이상 스타일 구기면서 다닐 수는 없습니다.',
#  '아버지:(뒷통수를 때리며)임마! 구겨졌으면 펴야지! 도망가면 어떡해? 너, 만약 최형사의 마수에서 벗어날 수만 있다면 뭐든 지 다 할 수 있어?',
#  '이형사:예. 뭐든지요.',
#  '아버지:그럼 됐어. 최형사, 애인있어?',
#  '이형사:그 성격에 남아날 남자가 있겠습니까?',
#  '아버지:그러니까 이를 갈잖아, 임마. 잘들어, 정공법이야! 남자로써 접근해',
#  '이형사:예?',
#  '아버지:니 엄마도 옛날엔 여장부였어, 임마. 약올리면 주먹부터 나갔는데 나도 한방에 기절했다니까. 그런데 어느날, 물레방앗간에서 같이 별을 보며 하룻밤을 보내고 난 뒤론 내가 말만 하면 고개 숙이고 예～ 딱, 그냥 한방에 바뀌더라니까.',
#  '이형사:예? 그럼 최형사하고…?(질겁하며)으… 안됩니다.',
#  '아버지:왜 안돼, 임마? 넌 결혼 안할꺼야? 니가 당한거 평생 복수하면서 살 수 있다니까?',
#  '할말이 없는 듯 아버지를 보는 이형사.',
#  '이형사:그냥 사표 쓰겠습니다. 아버지',
#  '씬 77 경찰서',
#  '깔끔한 정장을 쫙 빼입고 무스까지 뿌린 채 걸어오는 이형사. 주변의 형사들이 의아하게 바라보는 가운데 최형사도 힐끗 본다.',
#  '형사1:와～ 이형사, 멋진데? 오늘 선이라도 봐?',
#  '이형사:아뇨, 스타일 바꿨습니다.(미소)괜찮습니까? 최반장님.',
#  '최반장:(무시하고, 일어나며)자, 다 모였으면 조례 시작하겠습니다. 오늘은…',
#  '김빠지는 이형사. 이때, 배달원이 기웃거리며 다가와',
#  '배달원:저, 최형사님?',
#  '최형사:그런데요?',
#  '배달원:(꽃을 내밀며)어떤 남자 분이 전화로 주문하셨습니다.(서류를 내밀며)여기 사인 좀….',
#  '형사2:와… 죽이는데? 아침부터 꽃 선물받고….',
#  '이형사:(너스레)최반장님, 좋겠습니다.',
#  '최형사, 배달원이 인사를 하고 가면 재채기와 함께 꽃을 휴지통에 확 내던진다.',
#  '최형사:아이, 증말 어떤 놈이야? 꽃 알레르기 있는 사람 죽으란 거야? 뭐야? 아침부터 재수없게! 에취!',
#  '이런 최형사를 보며 인상을 쓴 채 고개를 돌리는 이형사.',
#  '씬 78 달리는 차 안',
#  '부드러운 음악이 흐르는 속에 운전을 하는 이형사 옆에 앉은 최형사.',
#  '이형사:날씨 정말 좋다. 이런 날엔 산과 강이 쫘악～ 펼쳐진 야외로 드라이브나 가면 끝내주겠군. 안 그래요?',
#  '최형사:(재채기를 하곤 인상을 쓰며)이형사, 향수 뿌렸나?',
#  '이형사:네, 어떻습니까?',
#  '최형사:(창문을 열며)갑자기 왜 안하던 짓 하고 그래? 나 토할려고 하잖아?!',
#  '씬 79 어느 골목',
#  '작은 골목의 어느 꽃집 건너편에 천천히 멈춰서는 투캅스의 차.',
#  '씬 80 차 안',
#  '천천히 정차하는 차를 운전하는 이형사 옆에 앉아있는 최형사.',
#  '최형사:(놀란 듯)그게 사실이야?',
#  '이형사:예. 확실한 정보원의 제보입니다. 현재로선 가장 유력한 용의자입니다.',
#  '최형사:어떤 놈이야?',
#  '이형사:(어느 꽃집을 가리키며)저기… 저 놈입니다.',
#  '하고 보면, 험악하게 생긴 놈이 큰 가위를 들고 꽃가지를 쳐대고 있다.',
#  '이형사:바람피운 마누라가 잠든 순간, 가위로 목을 따 살인하고 얼마 전에 출소했는데 항상 가위가 든 가방을 들고 다닌다고 합니다.',
#  '최형사:그래?(나가려하며)그럼, 잡아야지.',
#  '이형사:(잡으며)지금 체포하면 안됩니다. 확실한 물증을 잡아야죠!',
#  '씬 81 꽃집',
#  '이형사, 어느 장미를 가리키자 용의자, 장미를 빼내 가위로 자르곤 뒷쪽에서 포장하는 동안 한켠에 놓은 가방으로 다가가는 이형사, 몰래 가방옆 쪽에 작은 기계를 부착한다. 슬쩍 보는 용의자와 눈이 마주치면 윙크를 하는 이형사와 고개를 끄덕이며 장미를 포장하는 용의자.',
#  '씬 82 차 안(D―N)',
#  '들어오는 이형사, 꽃을 최형사에게 건네며',
#  '이형사:설치했습니다.',
#  '최형사:(재채기를 하며)에취!(고개를 돌린 채)저리 치워!',
#  '타임 컷 ―',
#  '어느덧 밤이 된 거리를 바라보며 앉아있는 최형사. 꽃가게도 불이 켜져 있고, 한 여자가 용의자와 웃음을 교환하더니 용의자와 같이 나온다. 가게불을 끄는 용의자를 보곤, 졸고있는 이형사를 툭툭 치는 최형사.',
#  '최형사:놈이 움직여!',
#  '이형사:(졸다가 깨선, 시동을 걸며)저도 봤습니다.',
#  '씬 83 러브텔 안',
#  '망원경으로 보이는―',
#  '여자의 속옷을 가위로 자르는 용의자.',
#  '?소리:꼭 이렇게 해야 돼?',
#  '?소리:난 가위가 없으면 흥분이 안돼.',
#  '?소리: (키스를 하며)오빠가 속옷 사 줘야돼.',
#  '불이 꺼진 방안에서 망원경으로 건너편을 바라보고 있는 최형사와 소형카세트를 조작하는 이형사.',
#  '최형사:(다가와선)이런 건 언제 구했어?',
#  '이형사:항상 비상용으로 가지고 다니죠.(망원경을 뺏으며)이젠 내가 감시하죠.',
#  '최형사:(다시 뺏으며)보긴 뭘 봐?',
#  '곧이어 뽀뽀하는 소리가 여자의 간드러지는 소리에서 신음소리로 바뀌면 이형사와 최형사, 서로 눈이 마주치자 뒤로 물러나 앉는다.',
#  '최형사:이제 끄지?',
#  '이형사:껐습니다.',
#  '최형사:계속 들리잖아?',
#  '이형사:도청기 소리가 아닙니다.',
#  '양 쪽 벽에서 들리는 여자의 신음소리에 어색한 듯 일어나는 최형사. 방을 둘러보다간 다시 앉는다. 이형사, 이런 최형사를 보다간 침대 한켠에 걸터앉는다. 투캅스, 옆방에서 들리는 신음소리 속에 침대 양 구석에 서로 앉아 있다가 아무래도 어색한 듯 일어나는 이형사.',
#  '이형사:티브이 켤까요?',
#  '최형사:(재빠르게)그래, 그게 좋겠어.',
#  '이형사, 앞쪽의 티브이를 켜고 다시 앉으면 티브이에서도 애로영화가 숨가쁘게 진행중이다. 투캅스, 그런 티브이를 보다가 다시 눈이 마주치면',
#  '최형사:(괜히 시비쪼로)뭐해? 안끄구?!',
#  '이형사:본 겁니까?',
#  '최형사:보긴 뭘 봐?! 나도 안본거야.',
#  '최형사, 말하고 보니 이상한 듯 다시 이형사와 눈이 마주친다.',
#  '이형사:그럼 볼까요? 특별히 할 것도 없잖습니까?',
#  '최형사:그래, 알아서 해.',
#  '하고 다시 화면을 보면 더 육감적인 살결이 오가고, 옆방의 소리는 점점 고조되고 있다. 투캅스, 서로 티브이를 보지 않는 척 고개를 갸웃거리면서 힐끔힐끔 화면을 보다가 침을 꿀꺽 삼키는 소리가 과장되게 들린다. 점점 극에 달하는 화면. 이형사, 이런 티브이를 보다가 최형사를 슬쩍 보다간',
#  '이형사:음료수 드시겠습니까?',
#  '최형사:됐어.',
#  '이형사:혹시… 제가 필요한 일 없습니까?',
#  '최형사:없어.',
#  '이형사, 콜라 캔을 뒤로 마구 흔든 뒤 최형사 쪽에서 따는 순간, 뿜어져 나오는 거품이 최형사의 옷을 덥친다.',
#  '이형사:이런!(최형사의 옷을 닦아주며)닦아줄께요',
#  '최형사:(이형사의 손을 치고 닦으며)괜찮아. 됐어.',
#  '이형사:괜찮긴요. 휴지론 안되겠는데요? 벗으세요. 얼룩지기 전에 닦아내고 오겠습니다.',
#  '최형사:여기서 벗으라구?',
#  '이형사:뭐 어떻습니까? 동료끼리 같이 일하다 보면 그럴 수도 있지요.',
#  '최형사:됐어! 내 옷을 이형사한테 왜 맡겨? 이형사 옷이나 신경써!',
#  '이형사:(옷을 보다가)이런… 나도 엉망이군요.',
#  '하며 웃통을 벗고 최형사 앞에서 근육질의 몸을 괜히 으쓱해 보이곤 최형사에게 다가와 진지한 표정으로 바라본다.',
#  '이형사:최형사님.',
#  '최형사:왜 그래?',
#  '이형사:(다시 으쓱하며)살다보면 때론 이성보단 본능에 충실하고 싶을 때가 있지 않습니까?',
#  '최형사:무슨 말하고 싶은거야?',
#  '이형사:다시 묻겠습니다. 전 이미 마음의 준비가 돼 있으니 편하게 대답하십시오. 정말 저한테 원하는 거 없습니까?',
#  '최형사:있어.',
#  '이형사:(다가오며)뭡니까?',
#  '최형사:보기 흉하니까 벌거벗고 다닐려면 욕실 가서 벗어!',
#  '이형사:(활짝 미소로)예 써～!(가다가 뒤돌아보며)비디오 보고 계십시오. 샤워하고 얼른 나오죠.',
#  '이형사가 욕실로 들어가면 불이 꺼진 건너편 방을 보는 최형사. 소형 카세트를 작동시키면 계속 여자의 신음소리가 들린다.',
#  '씬 84 건너편 모텔 방',
#  '규칙적으로 반동을 줘 삐그덕거리는 불꺼진 방의 침대에 떨어져 앉아 있는 용의자와 여자, 가방을 앞에 두고 신음소리를 내고 있다.',
#  '여자:아～ 아～(작게)목 아파.～ 아～(작게)언제까지 이래야 돼?',
#  '용의자:으….(슬쩍 건너편의 불꺼진 방을 보며, 작게)조금만 더 해.',
#  '여자:아….',
#  '하는 순간, 문을 박차고 들어오는 최형사.',
#  '최형사:(총을 겨눈 채)꼼짝마!',
#  '하고 보면, 용의자와 여자가 침대에 걸터 앉아있다가 손을 든다.',
#  '씬 85 모텔 방 안',
#  '문을 열고 들어오는 최형사, 방안을 보면 이형사가 팬티만 입은 채 침대에 점프하듯 눕는다.',
#  '이형사:(고통스러운 신음소리를 내며)아… 어디 갔다 왔습니까?',
#  '최형사:왜 그래?',
#  '이형사:(엎어져 누운 채)목욕탕에서 미끌어졌습니다. 아무래도 겹질린 것 같아요.',
#  '최형사:(다가오며)그래? 내가 치료해 줄까?',
#  '이형사:그래 주시겠습니까?',
#  '최형사:(어깨를 만지며)이쪽이야?',
#  '이형사:아뇨. 약간 더 아래…',
#  '하는 순간 이형사의 두 팔을 확 꺽는 최형사.',
#  '이형사:(고통스러운 듯)왜 이러십니까?',
#  '하고 돌아보면 문 앞에 용의자와 여자가 고개를 숙인 채 서있다.',
#  '이형사:어?',
#  '하는 순간 더 세게 팔을 꺽는 최형사, 이형사의 등짝에 손바닥을 찌억! 소리나게 때린다. 흐윽! 벌겋게 손자국이 남은 등짝에 굳은 표정으로 비명을 지르는 이형사.',
#  '최형사:일어나!',
#  '이형사:자, 잘못했….',
#  '하는 순간 이형사의 면상에 쩌억～ 정통으로 강타하는 최형사의 손바닥.',
#  '뒤로 나자빠져 침대에서 떨어지는 이형사를 보곤 겁에 질린 용의자와 여자, 슬금슬금 문밖으로 도망친다.',
#  '최형사:아침에 꽃 보낸 것도 너지?',
#  '이형사:(멍이든 채 고개를 끄덕이며)사실은 제가…',
#  '최형사:(어느새 이형사의 등짝에 발을 내리꽂으며)필요없어! 하루 종일 공무집행 방해에다 상사 성희롱까지 할려구 해?',
#  '이형사:(바닥에 완전 퍼진 채)잠깐… 잠깐…',
#  '최형사:흥～ 당장 사표에다 구속시킬 수도 있지만, 그건 내 성질에 안맞아. 아까부터 옷벗고 싶어했지? 따라나와!',
#  '하며 이형사의 머리를 잡아 일으킨다.',
#  '이형사:아니… 최형사님….',
#  '최형사:(퍼억～ 이형사의 배에 주먹을 꽂으며)시끄러! 확실히 버릇을 고쳐주지.',
#  '씬 86 거리',
#  '지나가는 사람들이 키키덕거리며 웃는 곳을 보면, 운전을 하고 있는 최형사의 차 백미러에 연결된 수갑을 손목에 찬 채 팬티차림으로 빠르게 쫓아가는 이형사, 등짝과 얼굴에 멍이 들어있다. 손짓도 해가며 키키덕거리는 사람들이 시선을 피하며 창문을 두들기기도 하는 속에 무표정하게 운전을 하는 최형사.',
#  '이형사, 난감한 듯 고개를 숙이고 가는데 사람들이 많은 곳에서 점점 속도를 줄이는 차, 화려한 네온사인 속에 조명까지 받는 이형사. 이런 이형사를 바라보는 최형사의 모습 위로 들리는',
#  '?무전:여기는 HQ, 여기는 HQ ….',
#  '씬 87 강변 어느 곳',
#  '누군가의 손이 가운을 벗기면, 목에 상처를 입고 발가벗겨진 채 눈을 뜨고 죽은 여자 시체의 모습 뒤로 최형사가 살펴보는 뒤로 최형사를 이글거리는 증오감속에 바라보는 이형사.',
#  '최형사:(휙 뒤돌아보며)공과 사도 구분 못해? 일 안할거면 당장 사표 써. 불명예퇴직 시켜줄테니!',
#  '이형사:좋습니다. 일단 사건 해결하고 봅시다.',
#  '하며 시체 옆으로 다가가는 이형사, 눈을 뜨고 죽은 시체의 목에 난 상처를 살핀다.',
#  '이형사:같은 놈이군.(하다간 시체의 얼굴 가까이 다가가 냄새를 맡는다.)',
#  '최형사:(뒤로 다가와서)또 뭐하는 거야?',
#  '이형사:(휙 뒤돌아보곤)그냥 보는 것도 안됩니까? 또 사과할까요?(다시 시체에 대고, 장난스레)아가씨, 미안해. 응? 미안하다구.',
#  '하며 최형사를 노려보며 지나치는 이형사.',
#  '씬 88 경찰서 사무실(D)',
#  '피곤한 듯 하품을 쩍쩍해대는 형사들에게 호통을 치고 있는 최형사.',
#  '최형사:도대체 뭘 하는 겁니까?! 그깟 몇 일 야근한 걸 갖고 벌써 지치면 어떡해요?!',
#  '형사1:이봐, 최반장, 집에 좀 가자구, 속옷도 좀 갈아입고….',
#  '이런 형사들 앞에서 전화기를 붙잡고 있는 어딘가와 통화하고 있는',
#  '이형사:(수화기를 든 채)그럼 사체에서 발견된 화학약품은 없습니까? 분명 이상한 냄새가 났다니까요.',
#  '이와 동시에 뒷모습으로 보이는 최형사 등의 모습',
#  '최형사:범인 잡기 전에 집에 들어갈 생각마세요! 알겠습니까?!',
#  '형사1:예.',
#  '형사2:(고개를 돌린 채, 작게)정말 악질이다. 악질.',
#  '이형사:(수화기를 든 채)아직도 조사 안하고 뭐하는 겁니까? 일 좀 하세요!',
#  '하며 수화기를 끊자 최형사 등 형사들이 바라본다.',
#  '형사1:왜 그래?',
#  '이형사:아닙니다.(하며 다시 전화버튼을 누른다)',
#  '최형사:(박수를 탁탁 치며)자, 그럼 모두들 힘내세요!',
#  "형사들, 모두 '아이구―' 등의 한숨을 쉬며 일어난다.",
#  '형사1:도대체 몇 일째야? 이러다 밖에서 우리 마누라 봐도 못알아 보겠네, 젠장.',
#  '형사2:전 집이나 제대로 찾아갈 수 있을 지 모르겠어요― 으휴―',
#  '하며 나가는 형사들.',
#  '이형사:(수화기를 들고)예. 경찰입니다. 몇가지 물어 볼 게 있어서….',
#  '이때, 제복을 입은 여경찰이 지나가자 휙 뒤돌아보는 이형사.',
#  '이형사:(벌떡 일어나며)잠깐 잠깐만!',
#  '여경:(뒤돌아보며)예? 저 말예요?',
#  '이형사:(다가가 머리카락을 킁킁거리며)흠― 흠―',
#  '여경:왜 이러세요?',
#  '이형사:이게 무슨 냄새지? 응? 흠― 흠―',
#  '여경:(움찔해 물러나며)왜요? 어제 파마했는데… 왜 그러세요?',
#  '최형사:(다가서며)왜 그래?!',
#  '이형사:(진지한 표정으로)미용실이야! 피해자들 모두 파마약 냄새가 났어. 갑시다!',
#  '하며 나가는 이형사를 뒤쫓아가는 최형사의 모습에서―',
#  '씬 89 동 미용실 안',
#  '어느 여자의 머리를 만지고 있는 느글느글하게 생긴 커트김 옆에 서있는 이형사와 최형사. 대기중인 한 여자손님(다음 피해자)과 여종업원들이 힐끗힐끗 본다.',
#  '커트김:(사진을 건네주며)처음보는 얼굴이라니까요.',
#  '이형사:친구들을 통해 이 미용실에 자주 왔다는 거 알고 있습니다. 다시 한 번 보십시오.',
#  '커트김:글세 모른다니까―(하다간 어떤 사진을 보곤)아, 잠깐만요. 이 언니는 이 미용실이 아니라…. 잠깐만 나오시죠?',
#  '하며 투캅스를 데리고 밖으로 나간다.',
#  '씬 90 동 밖 복도',
#  '가게안이 보이지 않는 코너에 서있는 미용사와 투캅스.',
#  '커트김:이 여자들이 모두 여기 단골인 건 사실입니다. 하지만 정말 우리 가게하곤 아무런 상관없어요. 이런 불미스런 일에 우리 가게가 어떻게건 관련된게 알려지면 우린 끝장이예요.(어느 종이를 내밀며)여기 나 뿐만이 아니라 우리 애들 연락처 다 있어요. 협조가 필요하면 영업 마치고 와주세요.(표정을 바꿔)그게 아니면 영장가지고 오시든지요. 그럼 이만…',
#  '하며 안으로 들어가버리는 커트김. 이형사, 뒤쫓아가려 하면 최형사가 붙잡는다.',
#  '최형사:그만둬.',
#  ...]

# %%
word_count
# Out:
# [('형사', 637.495123488858),
#  ('장갑', 67.4818976523597),
#  ('목장갑', 59.10778548169973),
#  ('여자', 49.76553961958852),
#  ('유괴', 48.32788464603059),
#  ('경찰', 47.85793138201888),
#  ('소리', 39.060901292946596),
#  ('과장', 38.859694922850856),
#  ('사람', 34.64332659053126),
#  ('모습', 29.444213936131657),
#  ('사장', 28.622265568714038),
#  ('고개', 24.25366844773219),
#  ('순간', 24.155018603050273),
#  ('미용', 23.935365334337508),
#  ('강사', 22.771670693344337),
#  ('투캅스', 22.358192968549854),
#  ('꼴통', 22.338680883991263),
#  ('아버지', 20.539283410600166),
#  ('정보원', 19.990421601732976),
#  ('경찰서', 19.444029195134917),
#  ('아줌마', 18.747819547979066),
#  ('강도', 18.65901733754711),
#  ('두목', 17.744495959796023),
#  ('회장', 16.73654945507797),
#  ('아이', 16.709449492438914),
#  ('엄마', 15.108555449241486),
#  ('표정', 14.76722509216091),
#  ('가위', 14.724897739696242),
#  ('보스', 14.254840870658896),
#  ('가방', 13.696820232732916),
#  ('남자', 13.472942374215279),
#  ('주먹', 13.28435260951563),
#  ('운전', 13.136437229929726),
#  ('트레일러', 13.059322674618558),
#  ('서장', 12.870423624371996),
#  ('자식', 12.730207966032333),
#  ('머리', 12.356667914241545),
#  ('도굴', 12.03390138026782),
#  ('커트', 12.027101520211815),
#  ('반장', 11.787646826903783),
#  ('인상', 11.654948287508272),
#  ('얼굴', 11.444922889258663),
#  ('중국', 11.439168543749055),
#  ('아가리', 11.376070996697505),
#  ('오늘', 11.305104248632055),
#  ('어깨', 11.1012323129954),
#  ('이때', 10.648174809301516),
#  ('당장', 10.403924073780548),
#  ('바닥', 10.062673024261684),
#  ('이번', 9.610430252634956),
#  ('때문', 9.146971539082609),
#  ('골목', 9.08381752122423),
#  ('건물', 9.01509269398902),
#  ('거리', 8.845862292470851),
#  ('도로', 8.68439109632903),
#  ('차림', 8.425772374116466),
#  ('시체', 8.33605874965379),
#  ('형님', 8.324516691577745),
#  ('공격', 8.111489856870612),
#  ('아래', 8.048357839208968),
#  ('검시관', 8.019715766517425),
#  ('미용실', 7.928464619124775),
#  ('사실', 7.8229300090935965),
#  ('침대', 7.75852088846705),
#  ('생각', 7.756547463250695),
#  ('운동', 7.689094025191783),
#  ('남편', 7.616964712716335),
#  ('은행', 7.593404191178632),
#  ('전경', 7.425791430369889),
#  ('금고', 7.390213567783236),
#  ('비명', 7.32395774012663),
#  ('용의자', 7.258089826012708),
#  ('박수', 7.058684561243377),
#  ('조폭', 6.978822111973085),
#  ('새끼', 6.968511746201283),
#  ('중년', 6.869567102024879),
#  ('선행', 6.811119577062493),
#  ('건달', 6.800654801134304),
#  ('부하', 6.771487343629743),
#  ('화면', 6.769335021262992),
#  ('멱살', 6.701029257115088),
#  ('아저씨', 6.694553586776538),
#  ('운전수', 6.533926450232397),
#  ('양복', 6.350312829743529),
#  ('창문', 6.316360519564454),
#  ('이익', 6.312311625638072),
#  ('박찬호', 6.245417968059419),
#  ('주변', 6.16425811989367),
#  ('수갑', 6.114352604824129),
#  ('난간', 6.079215613791835),
#  ('고함', 6.053194793244507),
#  ('동시', 6.006565741368917),
#  ('사이', 5.95860540994198),
#  ('박스', 5.945582656572075),
#  ('서로', 5.941322765158546),
#  ('미소', 5.6057016058584255),
#  ('신음', 5.371435987815645),
#  ('정도', 5.346809956543088),
#  ('뒷편', 5.086020085313764),
#  ('박살', 3.5636564103322343)]

# %%
words
# Out:
# ['형사',
#  '하다',
#  '최',
#  '장갑',
#  '보다',
#  '있다',
#  '씬',
#  '놈',
#  '목',
#  '뒤',
#  '채',
#  '안',
#  '사의',
#  '들다',
#  '이',
#  '여자',
#  '그렇다',
#  '총',
#  '듯',
#  '속',
#  '소리',
#  '경찰',
#  '유괴',
#  '차',
#  '되다',
#  '다시',
#  '사람',
#  '범',
#  '손',
#  '바라보다',
#  '모습',
#  '잡다',
#  '없다',
#  '뭐',
#  '앞',
#  '왜',
#  '순간',
#  '이렇다',
#  '과장',
#  '내',
#  '알다',
#  '말',
#  '고개',
#  '문',
#  '돼다',
#  '저',
#  '가다',
#  '다가가다',
#  '투캅스',
#  '임마',
#  '이형',
#  '그',
#  '아니다',
#  '버리다',
#  '서다',
#  '예',
#  '들어오다',
#  '맞다',
#  '보이다',
#  '보스',
#  '지르다',
#  '죽다',
#  '옆',
#  '다가오다',
#  '어떻다',
#  '들어가다',
#  '등',
#  '나가다',
#  '두목',
#  '몸',
#  '겁',
#  '곳',
#  '꼴통',
#  '거',
#  '오다',
#  '더',
#  '우리',
#  '도망가다',
#  '미용',
#  '다른',
#  '강사',
#  '운전',
#  '편',
#  '가위',
#  '앉다',
#  '죽이다',
#  '내미다',
#  '아줌마',
#  '일',
#  '향',
#  '돈',
#  '것',
#  '돌아보다',
#  '나오다',
#  '달려가다',
#  '아이',
#  '수',
#  '꺼내다',
#  '정보원',
#  '제',
#  '강도',
#  '이다',
#  '회장',
#  '빠르다',
#  '두',
#  '표정',
#  '일어나다',
#  '사장',
#  '치다',
#  '좋다',
#  '달리다',
#  '때',
#  '아버지',
#  '받다',
#  '좀',
#  '가방',
#  '나',
#  '번',
#  '주먹',
#  '서로',
#  '모두',
#  '않다',
#  '거리',
#  '열다',
#  '공격',
#  '트레일러',
#  '휙',
#  '같다',
#  '응',
#  '확',
#  '남자',
#  '위로',
#  '눈',
#  '안되다',
#  '칼',
#  '멈추다',
#  '나다',
#  '집',
#  '대다',
#  '얼굴',
#  '바닥',
#  '먹다',
#  '비명',
#  '끼',
#  '무슨',
#  '엄마',
#  '게',
#  '경찰서',
#  '도굴',
#  '머리',
#  '또',
#  '곧장',
#  '방',
#  '어깨',
#  '인상',
#  '전',
#  '작다',
#  '난',
#  '줄',
#  '부하',
#  '애',
#  '지금',
#  '알',
#  '도로',
#  '건달',
#  '주다',
#  '밖',
#  '정말',
#  '너',
#  '쪽',
#  '해',
#  '놓다',
#  '때리다',
#  '이번',
#  '퍽',
#  '김',
#  '들리다',
#  '새꺄',
#  '아가리',
#  '모르다',
#  '말다',
#  '쏘다',
#  '중국말',
#  '죄송하다',
#  '발',
#  '아래',
#  '내리다',
#  '하나',
#  '쓰다',
#  '서장',
#  '침대',
#  '돌아서다',
#  '돌리다',
#  '놀란',
#  '지다',
#  '팔',
#  '보고',
#  '뜨다',
#  '질린다',
#  '살리다',
#  '꺽',
#  '숙이다',
#  '도대체',
#  '커트',
#  '쾅',
#  '오늘',
#  '덥다',
#  '내다',
#  '이르다',
#  '위',
#  '열리다',
#  '자다',
#  '당장',
#  '자식',
#  '떨어지다',
#  '양복',
#  '거기',
#  '걸',
#  '씨발',
#  '강',
#  '그만두다',
#  '박사',
#  '실',
#  '사이',
#  '이익',
#  '요',
#  '걸어가다',
#  '박살',
#  '창문',
#  '박수',
#  '시키다',
#  '쓰러지다',
#  '노려보다',
#  '괜찮다',
#  '미소',
#  '달려오다',
#  '해보다',
#  '동시',
#  '화면',
#  '나자빠지다',
#  '싶다',
#  '용의자',
#  '여기',
#  '켜다',
#  '끄다',
#  '짓',
#  '살피다',
#  '리',
#  '운동',
#  '크다',
#  '간다',
#  '금고',
#  '대고',
#  '조폭',
#  '제발',
#  '전경',
#  '주변',
#  '골목',
#  '차림',
#  '따르다',
#  '모이다',
#  '아뇨',
#  '막다',
#  '시체',
#  '형님',
#  '개',
#  '입다',
#  '많다',
#  '때문',
#  '미용실',
#  '생각',
#  '한번',
#  '그냥',
#  '지나치다',
#  '날',
#  '건',
#  '두다',
#  '잡히다',
#  '피하',
#  '니',
#  '들이다',
#  '당신',
#  '신음',
#  '밀치다',
#  '새끼',
#  '술',
#  '불',
#  '간',
#  '지나가다',
#  '보지',
#  '박스',
#  '놀라다',
#  '사실',
#  '박찬호',
#  '수갑',
#  '벗다',
#  '종업원',
#  '다니다',
#  '의',
#  '선',
#  '사과',
#  '써다',
#  '건물',
#  '휘두르다',
#  '화려하다',
#  '어느새다',
#  '점점',
#  '움찔',
#  '멱살',
#  '어디',
#  '던지다',
#  '남편',
#  '장님',
#  '검시관',
#  '갑자기',
#  '중년',
#  '옷',
#  '고함',
#  '정도',
#  '쫓아가다',
#  '잠깐',
#  '익',
#  '쓸다',
#  '보이',
#  '몇',
#  '올라가다',
#  '가득',
#  '못',
#  '아저씨',
#  '선행',
#  '올리다',
#  '가지',
#  '마',
#  '겨누',
#  '고맙다',
#  '스레',
#  '난간',
#  '입',
#  '누구',
#  '라면',
#  '넘어지다',
#  '정문',
#  '찬',
#  '선배',
#  '버스',
#  '음악',
#  '꼼짝',
#  '아지트',
#  '차안',
#  '가리키다',
#  '멈칫',
#  '발견',
#  '곤',
#  '끌다',
#  '바꾸다',
#  '두둑',
#  '강간',
#  '웨이터',
#  '시위',
#  '누군가',
#  '전화',
#  '쌕',
#  '부러지다',
#  '책상',
#  '잡고',
#  '자기',
#  '은행',
#  '년',
#  '풀다',
#  '엎드리다',
#  '빠지다',
#  '마구',
#  '채우다',
#  '시오',
#  '경찰차',
#  '이제',
#  '넌',
#  '사건',
#  '누르다',
#  '패',
#  '계속',
#  '사표',
#  '이야기',
#  '발차기',
#  '명',
#  '네',
#  '완전하다',
#  '구',
#  '바로',
#  '사도',
#  '자',
#  '어딨다',
#  '짓다',
#  '걸리다',
#  '쟈켓',
#  '날리다',
#  '해주다',
#  '졸다',
#  '둘',
#  '열',
#  '꽃',
#  '룸',
#  '돌아가다',
#  '인사',
#  '수건',
#  '뒷문',
#  '파이프',
#  '불다',
#  '쇠',
#  '석',
#  '사무실',
#  '구조대',
#  '시작',
#  '따다',
#  '집다',
#  '카메라',
#  '강타',
#  '먼저',
#  '벌떡',
#  '햄버거',
#  '절대',
#  '데리',
#  '날아오다',
#  '총알',
#  '마주치다',
#  '왕복',
#  '자네',
#  '재빠르다',
#  '만들다',
#  '매달리다',
#  '벽',
#  '치',
#  '스포츠카',
#  '티브이',
#  '뭘',
#  '마약상',
#  '눈치',
#  '일어나며',
#  '자르다',
#  '닦다',
#  '짜다',
#  '어색하다',
#  '따위',
#  '정신',
#  '피',
#  '일제',
#  '흔들다',
#  '뒤따르다',
#  '거의',
#  '올라오다',
#  '버럭',
#  '상처',
#  '세',
#  '중요하다',
#  '선동렬',
#  '지치다',
#  '낚아채다',
#  '건너편',
#  '뛰어내리다',
#  '계단',
#  '폼',
#  '늘다',
#  '숨다',
#  '기도',
#  '다음',
#  '젠장',
#  '귀',
#  '맡다',
#  '울리다',
#  '위해',
#  '미안하다',
#  '명의',
#  '당황',
#  '뻗다',
#  '그게',
#  '여',
#  '핸드폰',
#  '파트너',
#  '데',
#  '제법',
#  '스치다',
#  '아무',
#  '당기다',
#  '굳다',
#  '악',
#  '하루',
#  '도둑',
#  '점프',
#  '힘없다',
#  '흠',
#  '차다',
#  '하자',
#  '걱정',
#  '배',
#  '걸다',
#  '방해',
#  '가버리다',
#  '안해',
#  '화난',
#  '혼자',
#  '가슴',
#  '테이블',
#  '여기다',
#  '형',
#  '반장',
#  '상사',
#  '얼마',
#  '창밖',
#  '넘어가다',
#  '구형',
#  '를',
#  '휘청거리다',
#  '가져가다',
#  '긴장',
#  '가게',
#  '바람',
#  '살다',
#  '기다',
#  '아가씨',
#  '면상',
#  '역시',
#  '가운데',
#  '겨눈',
#  '믿다',
#  '겁니다',
#  '성공하다',
#  '냄새',
#  '웃다',
#  '적',
#  '다리',
#  '제대로',
#  '움직이다',
#  '오케이',
#  '젖히다',
#  '대신',
#  '당하다',
#  '볼펜',
#  '툭툭',
#  '축하',
#  '승진',
#  '울다',
#  '우두둑',
#  '휘둥그레지다',
#  '은행강도',
#  '시선',
#  '가져오다',
#  '병',
#  '싸우다',
#  '따라오다',
#  '갈다',
#  '나쁘다',
#  '한숨',
#  '빼다',
#  '비실',
#  '완전',
#  '아깝다',
#  '수화기',
#  '일단',
#  '너머',
#  '끄덕',
#  '위험하다',
#  '덤비다',
#  '범인',
#  '혹시',
#  '구기다',
#  '체포',
#  '증',
#  '퍼버벅',
#  '눕다',
#  '야구',
#  '질',
#  '의자',
#  '학교',
#  '허겁지겁',
#  '남다',
#  '인간',
#  '걸어오다',
#  '바뀌다',
#  '법',
#  '뒷덜미',
#  '손님',
#  '나서다',
#  '최고',
#  '미용사',
#  '션',
#  '클락',
#  '더럽다',
#  '떨구다',
#  '물',
#  '울먹이다',
#  '힘',
#  '공사',
#  '해오다',
#  '쿵',
#  '부닥치다',
#  '급회전',
#  '뛰다',
#  '너희',
#  '소원',
#  '살',
#  '치우다',
#  '훌쩍',
#  '비키다',
#  '잘못',
#  '유리',
#  '지갑',
#  '꾼',
#  '장난',
#  '드리다',
#  '뭔가',
#  '동안',
#  '부축',
#  '위협',
#  '조물',
#  '방안',
#  '오해',
#  '그대로',
#  '만지다',
#  '깨지다',
#  '통수',
#  '아침',
#  '밀다',
#  '학생',
#  '커다랗다',
#  '끝',
#  '어리다',
#  '짐',
#  '멋지다',
#  '긁다',
#  '뿌리치다',
#  '뛰어들다',
#  '커피',
#  '주머니',
#  '안심',
#  '해결',
#  '듯이',
#  '세우다',
#  '일으키다',
#  '갈기',
#  '기다리다',
#  '오가다',
#  '찌르다',
#  '아주머니',
#  '구속',
#  '달',
#  '미치다',
#  '달다',
#  '거실',
#  '언제',
#  '묶이다',
#  '보조',
#  '턱',
#  '항상',
#  '웅성거리다',
#  '서류',
#  '개월',
#  '벌컥',
#  '로써',
#  '삐',
#  '이상',
#  '덕',
#  '뛰어넘다',
#  '어쭈',
#  '쏜다',
#  '마치',
#  '반말',
#  '중',
#  '사진',
#  '싸움',
#  '자신',
#  '보이지',
#  '대치',
#  '코피',
#  '손가락',
#  '대형',
#  '내쉬다',
#  '탕',
#  '싫다',
#  '온',
#  '질겁',
#  '분위기',
#  '스윽',
#  '쳐다보다',
#  '계시다',
#  '입구',
#  '배달',
#  '증말',
#  '확실하다',
#  '올려놓다',
#  '속옷',
#  '양',
#  '잡',
#  '뒷모습',
#  '폭력',
#  '캔',
#  '밟다',
#  '콜라',
#  '출발',
#  '밤',
#  '등짝',
#  '근처',
#  '널',
#  '나가떨어지다',
#  '끝나다',
#  '쫓다',
#  '붙잡다',
#  '사내',
#  '멍',
#  '리치',
#  '물러나다',
#  '터',
#  '머리카락',
#  '팍',
#  '그녀',
#  '다가서다',
#  '저기',
#  '쥐다',
#  '사이렌',
#  '여유',
#  '볼',
#  '나타나다',
#  '달려들다',
#  '타다',
#  '몰다',
#  '이유',
#  '척',
#  '구경',
#  '손목',
#  '날아가다',
#  '뻥',
#  '기자',
#  '수사',
#  '치기',
#  '룸싸롱',
#  '놓이다',
#  '생기다',
#  '밀',
#  '늘어지다',
#  '북적',
#  '축',
#  '젖다',
#  '움켜쥐다',
#  '피해자',
#  '심하다',
#  '꽉',
#  '뭐라다',
#  '엉망',
#  '린다',
#  '나무',
#  '만약',
#  '뒤지다',
#  '차갑다',
#  '녜',
#  '챙기다',
#  '총구',
#  '모처럼',
#  '몰래',
#  '넣다',
#  '뺨',
#  '시간',
#  '잖다',
#  '세상',
#  '한마디',
#  '신고',
#  '키우다',
#  '잔',
#  '고수부지',
#  '헤엄',
#  '오토바이',
#  '자막',
#  '금방',
#  '어둠',
#  '빼앗다',
#  '처리',
#  '며',
#  '달라',
#  '물어보다',
#  '발생',
#  '밉다',
#  '호텔',
#  '빼',
#  '지선',
#  '시끄럽다',
#  '어제',
#  '좌우',
#  '끼다',
#  '거짓말',
#  '허다',
#  '자꾸',
#  '마당',
#  '뭡',
#  '맨',
#  '날카롭다',
#  '어떡하다',
#  '불빛',
#  '힘겹다',
#  '다시다',
#  '감사하다',
#  '험악하다',
#  '아파트',
#  '지은',
#  '뒹',
#  '담',
#  '섹스',
#  '서고',
#  '얼른',
#  '꾸벅',
#  '돌려주다',
#  '찌다',
#  '기대다',
#  '마스크',
#  '겁나다',
#  '목숨',
#  '방아쇠',
#  '튀어',
#  '서서',
#  '어지럽다',
#  '박차다',
#  '사격',
#  '망',
#  '특유',
#  '훔치다',
#  '털다',
#  '헬멧',
#  '팰',
#  '쫓아오다',
#  '후진',
#  '달리',
#  '경쾌하다',
#  '누가',
#  '타이틀',
#  '마약',
#  '내려놓다',
#  '씩씩하다',
#  '마시다',
#  '바라다',
#  '가볍다',
#  '포장마차',
#  '한심하다',
#  '아프다',
#  '관내',
#  '손잡이',
#  '요청',
#  '휴지통',
#  '전과',
#  '궤짝',
#  '길',
#  '진짜',
#  '치켜들다',
#  '보여주다',
#  '대의',
#  '졸업',
#  '감다',
#  '인생',
#  '저으',
#  '질리다',
#  '고생',
#  '끼어들다',
#  '표창장',
#  '기록',
#  '깨다',
#  '웃통',
#  '피다',
#  '조용하다',
#  '끄덕이다',
#  '우산',
#  '만원',
#  '청진기',
#  '금',
#  '밑',
#  '떨다',
#  '휴일',
#  '치면',
#  '누굴',
#  '희다',
#  '사랑',
#  '어딘가',
#  '변하다',
#  '요즘',
#  '흥분',
#  '모으다',
#  '인정',
#  '풍구',
#  '환',
#  '자고',
#  '넘기다',
#  '비',
#  '초인종',
#  '탁',
#  '식이',
#  '뺑',
#  '관',
#  '일이',
#  '가득하다',
#  '회사',
#  '무시',
#  '면허증',
#  '면허',
#  '몇몇',
#  '멀어지다',
#  '친구',
#  '수석',
#  '빵빵',
#  '쓰다듬다',
#  '막히다',
#  '안고',
#  '푹',
#  '핫팬츠',
#  '빈',
#  '별',
#  '땐',
#  '안내',
#  '달리기',
#  '살피',
#  '측정기',
#  '브레이크',
#  '핸드백',
#  '새롭다',
#  '이란',
#  '갈리다',
#  '굳어지다',
#  '깡패',
#  '여러',
#  '천원',
#  '병신',
#  '덮다',
#  '쉬다',
#  '꿈',
#  '함부로',
#  '어이',
#  '사회',
#  '마르다',
#  '도',
#  '빛',
#  '사체',
#  '갖다',
#  '제일',
#  '번번하다',
#  '처음',
#  '보내다',
#  '천장',
#  '묻다',
#  '경례',
#  '혼잣말',
#  '복종',
#  '인질',
#  '겨우',
#  '분명하다',
#  '군',
#  '차기',
#  '급하다',
#  '형광등',
#  '바지',
#  '텅빈',
#  '접다',
#  '빠져나가다',
#  '때론',
#  '의아',
#  '몽둥이',
#  '음',
#  '물어',
#  '붙다',
#  '친',
#  '엎어지다',
#  '장미',
#  '범의',
#  '전화기',
#  '감봉',
#  '괜',
#  '꽃집',
#  '에취',
#  '뿌리다',
#  '재채기',
#  '플랭카드',
#  '청원경찰',
#  '차례',
#  '가면',
#  '불안하다',
#  '울상',
#  '기합',
#  '가요',
#  '약간',
#  '후',
#  '해산',
#  '쓰이다',
#  '이전',
#  '빨갛다',
#  '컷',
#  '타임',
#  '산',
#  '문신',
#  '개새끼',
#  '야산',
#  '한참',
#  '돌다',
#  '식',
#  '하품',
#  '강의',
#  '벌린',
#  '따라가다',
#  ...]

# %%
result,result.shape
# Out:
# (array([[ 0.12178555,  0.12479661],
#         [ 0.05218937,  0.32850546],
#         [ 0.29400787, -0.02675696],
#         ...,
#         [-0.20369457, -0.0818887 ],
#         [-0.30212626, -0.20033444],
#         [-0.5324327 , -0.3787713 ]], dtype=float32),
#  (1589, 2))

# %%
labels,labels.shape
# Out:
# (array([0, 0, 0, ..., 0, 0, 0], dtype=int64), (1589,))

# %%
words_all
# Out:
# ['씬',
#  '달리다',
#  '버스',
#  '안',
#  '타이틀',
#  '끝나다',
#  '되다',
#  '경쾌하다',
#  '달려오다',
#  '서다',
#  '시내버스',
#  '치익',
#  '소리',
#  '문',
#  '열리다',
#  '기다리다',
#  '있다',
#  '사람',
#  '올라타다',
#  '버스',
#  '카드',
#  '현금',
#  '함',
#  '앞',
#  '오가다',
#  '손',
#  '바라보다',
#  '운전',
#  '수',
#  '그냥',
#  '지나치다',
#  '사람',
#  '발견',
#  '곤',
#  '아저씨',
#  '차비',
#  '내다',
#  '하다',
#  '운전',
#  '수가',
#  '노려보다',
#  '가방',
#  '메다',
#  '지나치다',
#  '가다가',
#  '뒤',
#  '돌아보다',
#  '꼴통',
#  '특유',
#  '인상',
#  '긁다',
#  '들다',
#  '볼펜',
#  '울다',
#  '내미다',
#  '시선',
#  '피하',
#  '차',
#  '출발',
#  '시키다',
#  '운전',
#  '수',
#  '꼴통',
#  '버스',
#  '가운데',
#  '서서',
#  '가방',
#  '털썩',
#  '내려놓다',
#  '볼펜',
#  '자루',
#  '치켜들다',
#  '꼴통',
#  '뒤뚱뒤뚱',
#  '인사',
#  '하다',
#  '차',
#  '안',
#  '계시다',
#  '신사',
#  '숙녀',
#  '여러분',
#  '안녕하십니까',
#  '저',
#  '홧김',
#  '폭력',
#  '겁',
#  '유괴',
#  '불타다',
#  '가슴',
#  '강간',
#  '등',
#  '전과',
#  '이범',
#  '얼마',
#  '전',
#  '추다',
#  '소한',
#  '대책',
#  '없다',
#  '어리다',
#  '양',
#  '이다',
#  '시선',
#  '피',
#  '승객',
#  '볼펜',
#  '자루',
#  '올려놓다',
#  '아프다',
#  '과거',
#  '잊다',
#  '꼬',
#  '딱지',
#  '포장마차',
#  '장만',
#  '하다',
#  '하니',
#  '액땜',
#  '하다',
#  '생각',
#  '하다',
#  '가볍다',
#  '지갑',
#  '열다',
#  '바라다',
#  '여러분',
#  '가정',
#  '불행',
#  '없다',
#  '간절하다',
#  '소망',
#  '하다',
#  '볼펜',
#  '들다',
#  '보이',
#  '이',
#  '볼펜',
#  '단돈',
#  '삼천원',
#  '드리다',
#  '감사하다',
#  '인사',
#  '돈',
#  '거둬들이다',
#  '돌아다니다',
#  '꼴통',
#  '험악하다',
#  '인상',
#  '써다',
#  '보이',
#  '순순하다',
#  '돈',
#  '주다',
#  '아가씨',
#  '깐깐하다',
#  '보이다',
#  '남자',
#  '볼펜',
#  '돌려주다',
#  '꼴통',
#  '난',
#  '열',
#  '받다',
#  '입',
#  '주먹',
#  '먼저',
#  '나가다',
#  '놓다',
#  '하다',
#  '사내',
#  '앞',
#  '주먹',
#  '내미다',
#  '얼른',
#  '지갑',
#  '돈',
#  '꺼내다',
#  '주다',
#  '사내',
#  '이번',
#  '꾸벅',
#  '꾸벅',
#  '졸다',
#  '있다',
#  '고등학생',
#  '다가가다',
#  '꼴통',
#  '툭툭',
#  '깨지다',
#  '않다',
#  '통수',
#  '퍽퍽치',
#  '꼴통',
#  '임마',
#  '자다',
#  '척',
#  '하다',
#  '학생',
#  '왜',
#  '그렇다',
#  '꼴통',
#  '삼천원',
#  '내',
#  '학생',
#  '왜',
#  '꼴통',
#  '라면',
#  '내',
#  '안내',
#  '고등학생',
#  '돈',
#  '꺼내다',
#  '다음',
#  '넘어가다',
#  '꼴통',
#  '아이',
#  '안고',
#  '창밖',
#  '보다',
#  '척',
#  '하다',
#  '아줌마',
#  '보다',
#  '아이',
#  '머리',
#  '쓰다듬다',
#  '꼴통',
#  '귀엽다',
#  '아줌마',
#  '돌아보다',
#  '꼴통',
#  '저',
#  '겁',
#  '유괴',
#  '를',
#  '두',
#  '번',
#  '하다',
#  '죽이다',
#  '놓다',
#  '하다',
#  '이번',
#  '겁',
#  '먹다',
#  '아이',
#  '볼',
#  '살짝',
#  '꼬집다',
#  '아줌마',
#  '얼른',
#  '손',
#  '쥐',
#  '있다',
#  '돈',
#  '주다',
#  '아이',
#  '끌어안다',
#  '꼴통',
#  '몇몇',
#  '사람',
#  '순순하다',
#  '돈',
#  '받다',
#  '자리',
#  '향',
#  '하다',
#  '버스',
#  '안',
#  '일어나다',
#  '사태',
#  '전혀',
#  '의식',
#  '하다',
#  '못',
#  '채',
#  '귀',
#  '이어폰',
#  '끼',
#  '창',
#  '밖',
#  '보다',
#  '뭔가',
#  '메모',
#  '있다',
#  '하다',
#  '여자',
#  '앞',
#  '다가서다',
#  '꼴통',
#  '다짜고짜',
#  '그녀',
#  '어깨',
#  '손',
#  '올려놓다',
#  '특유',
#  '인상',
#  '긁다',
#  '깜짝',
#  '놀라다',
#  '돌아보다',
#  '기다',
#  '생머리',
#  '시원스럽다',
#  '얼굴',
#  '여자',
#  '바로',
#  '이',
#  '영화',
#  '신임',
#  '형사',
#  '최',
#  '형사',
#  '꼴통',
#  '나',
#  '강간',
#  '도',
#  '하다',
#  '여자',
#  '머리카락',
#  '배배',
#  '꼬',
#  '세',
#  '번',
#  '하다',
#  '어이',
#  '없다',
#  '쳐다보다',
#  '최',
#  '형사',
#  '겁',
#  '먹다',
#  '줄',
#  '알',
#  '핸드백',
#  '자기',
#  '손',
#  '열다',
#  '돈',
#  '꺼내다',
#  '수갑',
#  '권총',
#  '발견',
#  '곤',
#  '굳어지다',
#  '꼴통',
#  '상대',
#  '이다',
#  '지라',
#  '표정',
#  '다시',
#  '정리',
#  '하다',
#  '꼴통',
#  '너',
#  '경찰',
#  '자다',
#  '만나다',
#  '난',
#  '경찰',
#  '라면',
#  '이',
#  '갈리다',
#  '놈',
#  '순간',
#  '턱',
#  '쪼인트',
#  '맞다',
#  '꼴통',
#  '신음',
#  '고개',
#  '치켜들다',
#  '꼴통',
#  '어쭈',
#  '치다',
#  '이',
#  '내',
#  '알',
#  '말',
#  '끝나다',
#  '전',
#  '곧장',
#  '날아오다',
#  '최',
#  '사의',
#  '주먹',
#  '퍽',
#  '뒤',
#  '나자빠지다',
#  '꼴통',
#  '코피',
#  '쓰윽',
#  '닦다',
#  '질겁',
#  '곤',
#  '일어나며',
#  '피다',
#  '이',
#  '씨',
#  '웃통',
#  '벗다',
#  '끼어들다',
#  '놈',
#  '있다',
#  '죽이다',
#  '버리다',
#  '겁',
#  '질리다',
#  '피하',
#  '사람',
#  '꼴통',
#  '버스',
#  '머리',
#  '받다',
#  '씨발',
#  '사고',
#  '치기',
#  '싫다',
#  '내',
#  '인생',
#  '왜',
#  '꼬이다',
#  '휙',
#  '손가락',
#  '가리키다',
#  '것',
#  '니',
#  '잘못',
#  '하다',
#  '최',
#  '형사',
#  '향',
#  '하다',
#  '저돌',
#  '돌진',
#  '하다',
#  '꼴통',
#  '달려오다',
#  '꼴통',
#  '멋지다',
#  '업다',
#  '받다',
#  '넘기다',
#  '최',
#  '형사',
#  '버스',
#  '바닥',
#  '찌그러지다',
#  '정도',
#  '떨어지다',
#  '꼴통',
#  '꼴통',
#  '자신',
#  '패',
#  '인정',
#  '곤',
#  '최',
#  '형사',
#  '향',
#  '하다',
#  '손',
#  '모으다',
#  '빌다',
#  '꼴통',
#  '제',
#  '흥분',
#  '하다',
#  '최',
#  '형사',
#  '표정',
#  '변하다',
#  '않다',
#  '채',
#  '뚜둑',
#  '뚜둑',
#  '몸',
#  '풀다',
#  '다가서다',
#  '꼴통',
#  '휘둥그레지다',
#  '아니다',
#  '왜',
#  '이르다',
#  '잘못',
#  '하다',
#  '최',
#  '형사',
#  '멱살',
#  '잡다',
#  '일으키다',
#  '세우다',
#  '안',
#  '끝나다',
#  '씬',
#  '거리',
#  '달리다',
#  '버스',
#  '과장',
#  '들려오다',
#  '꼴통',
#  '비명',
#  '소리',
#  '퍽',
#  '퍽',
#  '우두둑',
#  '맞다',
#  '소리',
#  '좌우',
#  '요동치다',
#  '버스',
#  '우지끈',
#  '어딘가',
#  '부러지다',
#  '듯',
#  '소리',
#  '끼',
#  '이익',
#  '멈추다',
#  '서다',
#  '버스',
#  '위로',
#  '덥다',
#  '타이틀',
#  '투캅스',
#  '씬',
#  '집',
#  '거실',
#  '자막',
#  '사라지다',
#  '선행',
#  '하다',
#  '초인종',
#  '소리',
#  '속',
#  '화면',
#  '가득',
#  '현관문',
#  '반투명',
#  '유리',
#  '남자',
#  '형체',
#  '보이다',
#  '속',
#  '끼',
#  '리릭',
#  '끼',
#  '리릭',
#  '소리',
#  '고리',
#  '탁',
#  '하다',
#  '위로',
#  '젖히다',
#  '스르르',
#  '열리다',
#  '문',
#  '들어오다',
#  '구두',
#  '카메라',
#  '틸업하',
#  '손',
#  '목',
#  '장갑',
#  '끼다',
#  '사내',
#  '열다',
#  '있다',
#  '문',
#  '장갑',
#  '끼다',
#  '사내',
#  '쌕',
#  '맨',
#  '채',
#  '들어오다',
#  '장갑',
#  '날카롭다',
#  '눈매',
#  '고개',
#  '휙',
#  '저으',
#  '빠르다',
#  '움직이다',
#  '목',
#  '장갑',
#  '방문',
#  '어보',
#  '다가',
#  '방',
#  '앞',
#  '장갑',
#  '보다',
#  '고개',
#  '끄덕이다',
#  '곳',
#  '걸어가다',
#  '장갑',
#  '씬',
#  '방안',
#  '금고',
#  '청진기',
#  '대다',
#  '채',
#  '번호판',
#  '돌리다',
#  '있다',
#  '장갑',
#  '뒤',
#  '각종',
#  '그림',
#  '도자기',
#  '등',
#  '널린',
#  '방',
#  '서랍',
#  '따위',
#  '뒤지다',
#  '있다',
#  '목',
#  '장갑',
#  '천원',
#  '짜다',
#  '몇',
#  '장',
#  '은장도',
#  '씨거',
#  '엽전',
#  '등',
#  '쌕',
#  '넣다',
#  '장갑',
#  '눈치',
#  '보다',
#  '몰래',
#  '천원',
#  '짜다',
#  '리',
#  '주머니',
#  '챙기다',
#  '기도',
#  '하다',
#  '목',
#  '장갑',
#  '장갑',
#  '청진기',
#  '대다',
#  '채',
#  '하다',
#  '껀',
#  '하다',
#  '돈',
#  '함부로',
#  '쓰다',
#  '마르다',
#  '상법',
#  '왜',
#  '잡히다',
#  '아',
#  '돈',
#  '생기다',
#  '친구',
#  '데리',
#  '룸싸롱',
#  '쭉쭉',
#  '빵빵',
#  '죽이다',
#  '년',
#  '끼',
#  '술',
#  '졸다',
#  '퍼마셨',
#  '이',
#  '친구',
#  '란',
#  '새끼',
#  '아침',
#  '해장국',
#  '먹다',
#  '갑자기',
#  '이렇다',
#  '생각',
#  '들다',
#  '자기',
#  '어제',
#  '하다',
#  '번',
#  '얻어먹다',
#  '저',
#  '새',
#  '끼다',
#  '그렇다',
#  '데',
#  '처',
#  '먹다',
#  '끄다',
#  '생각',
#  '하다',
#  '열',
#  '받다',
#  '씨발',
#  '경찰',
#  '수상한',
#  '놈',
#  '있다',
#  '찌르다',
#  '잡히다',
#  '절대',
#  '친하다',
#  '놈',
#  '돈',
#  '쓰다',
#  '마르다',
#  '알다',
#  '목',
#  '장갑',
#  '예',
#  '장갑',
#  '보다',
#  '꼬불치다',
#  '생각',
#  '하다',
#  '마르다',
#  '나중',
#  '죽다',
#  '목',
#  '장갑',
#  '주머니',
#  '돈',
#  '꺼내다',
#  '예',
#  '하다',
#  '다시',
#  '천원',
#  '지폐',
#  '꺼내다',
#  '쌕',
#  '안',
#  '밀다',
#  '놓다',
#  '딸칵',
#  '소리',
#  '미소',
#  '지다',
#  '금고',
#  '손잡이',
#  '잡다',
#  '여',
#  '장갑',
#  '목',
#  '장갑',
#  '뒤',
#  '다가오다',
#  '장갑',
#  '미소',
#  '지은',
#  '채',
#  '금고',
#  '열다',
#  '잉',
#  '표정',
#  '확',
#  '변하다',
#  '뒤',
#  '어어',
#  '고개',
#  '들이다',
#  '밉다',
#  '목',
#  '장갑',
#  '표정',
#  '확',
#  '굳다',
#  '보다',
#  '열리다',
#  '문',
#  '안',
#  '금고',
#  '하나',
#  '더',
#  '보이다',
#  '목',
#  '장갑',
#  '씨발',
#  '이',
#  '새끼',
#  '금고',
#  '사하나',
#  '장갑',
#  '아니다',
#  '도굴',
#  '목',
#  '장갑',
#  '예',
#  '그게',
#  '뭡',
#  '장갑',
#  '몰래',
#  '남',
#  '무덤',
#  '졸다',
#  '파서',
#  '골동품',
#  '챙기다',
#  '팔',
#  '먹다',
#  '놈',
#  '목',
#  '장갑',
#  '한마디',
#  '벼락',
#  '맞다',
#  '새끼',
#  '들이다',
#  '장갑',
#  '자',
#  '방출',
#  '간걸',
#  '보다',
#  '또',
#  '어떻다',
#  '놈',
#  '무덤',
#  '졸다',
#  '파고',
#  '있다',
#  '씬',
#  '밖',
#  '끼',
#  '이익',
#  '멈추다',
#  '봉고',
#  '박스',
#  '등',
#  '들다',
#  '내리다',
#  '도굴',
#  '꾼',
#  '제법',
#  '크다',
#  '집의',
#  '대문',
#  '열다',
#  '짐',
#  '들다',
#  '조심',
#  '스레',
#  '안',
#  '들어가다',
#  '속',
#  '그',
#  '뒤',
#  '멈추다',
#  '서다',
#  '차',
#  '열리다',
#  '차문',
#  '내리다',
#  '누군가',
#  '발',
#  '틸업하',
#  '바로',
#  '우리',
#  '형사',
#  '도굴',
#  '꾼',
#  '보다',
#  '빠르다',
#  '다가가다',
#  '씬',
#  '안',
#  '다시',
#  '청진기',
#  '대고',
#  '있다',
#  '장갑',
#  '뒤',
#  '시계',
#  '보고',
#  '있다',
#  '목',
#  '장갑',
#  '목',
#  '장갑',
#  '형님',
#  '안',
#  '금고',
#  '하나',
#  '더',
#  '있다',
#  '게',
#  '하자',
#  '휙',
#  '보다',
#  '장갑',
#  '목',
#  '장갑',
#  '머리',
#  '배',
#  '따위',
#  '마구',
#  '팬',
#  '장갑',
#  '재수없다',
#  '소리',
#  '하다',
#  '임마',
#  '안',
#  '금고',
#  '또',
#  '있다',
#  '너',
#  '죽다',
#  '알',
#  '금고',
#  '문',
#  '여',
#  '순간',
#  '또',
#  '다른',
#  '금고',
#  '있다',
#  '장갑',
#  '목',
#  '장갑',
#  '팰',
#  '듯이',
#  '가다',
#  '리',
#  '새꺄',
#  '하다',
#  '순간',
#  '현관문',
#  '열리다',
#  '소리',
#  '들리다',
#  '표정',
#  '굳다',
#  '장갑',
#  '목',
#  '장갑',
#  '쪽',
#  '바라보다',
#  '씬',
#  '거실',
#  '문',
#  '열다',
#  '들어오다',
#  '도굴',
#  '뒤',
#  '돌아보다',
#  '도굴',
#  '조심하다',
#  '얼마',
#  '짜다',
#  '린',
#  '줄',
#  '알',
#  '무겁다',
#  '듯',
#  '박스',
#  '등',
#  '들다',
#  '들어오다',
#  '도굴',
#  '의',
#  '모습',
#  '속',
#  '들리다',
#  '소리',
#  '이형',
#  '사의',
#  '꼼작마',
#  '경찰',
#  '휙',
#  '뒤',
#  '돌아보다',
#  '도굴',
#  '꾼',
#  '인상',
#  '확',
#  '변하다',
#  '어느새다',
#  '안',
#  '뛰어들다',
#  '형사',
#  '박스',
#  '던지다',
#  '피하',
#  '형사',
#  '뒤',
#  '벽',
#  '맞다',
#  '깨지다',
#  '도자기',
#  '도굴',
#  '형사',
#  '향',
#  '하다',
#  '칼',
#  '호미',
#  ...]
