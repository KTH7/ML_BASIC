# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import NMF,LatentDirichletAllocation

dataset=fetch_20newsgroups(shuffle=True,random_state=1,remove=('headers','footers','quotes'))
documents=dataset.data
from sklearn.feature_extraction.text import TfidfTransformer,CountVectorizer

# %%
no_features=1000
#LDA can only use raw term cpunts for LDA because it is a probabilistic graphical model

tf_vectorizer=CountVectorizer(max_df=0.95,min_df=2,max_features=no_features,stop_words='english')
tf=tf_vectorizer.fit_transform(documents)
tf_feature_names=tf_vectorizer.get_feature_names()
# Out:
# c:\Users\taehwan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
tf_feature_names
# Out:
# ['00',
#  '000',
#  '01',
#  '02',
#  '03',
#  '04',
#  '0d',
#  '0t',
#  '10',
#  '100',
#  '11',
#  '12',
#  '128',
#  '13',
#  '14',
#  '145',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1d9',
#  '1st',
#  '1t',
#  '20',
#  '200',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '250',
#  '26',
#  '27',
#  '28',
#  '29',
#  '2di',
#  '2tm',
#  '30',
#  '300',
#  '31',
#  '32',
#  '33',
#  '34',
#  '34u',
#  '35',
#  '36',
#  '37',
#  '38',
#  '39',
#  '3d',
#  '3t',
#  '40',
#  '42',
#  '43',
#  '44',
#  '45',
#  '50',
#  '500',
#  '55',
#  '60',
#  '64',
#  '6ei',
#  '70',
#  '75',
#  '75u',
#  '7ey',
#  '7u',
#  '80',
#  '800',
#  '86',
#  '90',
#  '91',
#  '92',
#  '93',
#  '9v',
#  'a86',
#  'able',
#  'ac',
#  'accept',
#  'access',
#  'according',
#  'act',
#  'action',
#  'actually',
#  'add',
#  'addition',
#  'address',
#  'administration',
#  'advance',
#  'age',
#  'ago',
#  'agree',
#  'ah',
#  'air',
#  'al',
# ...

# %%
lda=LatentDirichletAllocation(n_components=20,max_iter=5,learning_method='online').fit(tf)

# %%
lda
# Out:
# LatentDirichletAllocation(learning_method='online', max_iter=5, n_components=20)

# %%
#20개의 토픽에 대하여 상위 10개의 단어 출력
no_top_words=10

for topic_idx,topic in enumerate(lda.components_):
    print('topic:',topic_idx)
    print(" ".join([tf_feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
# Out:
# topic: 0
# point value cause rules likely number line certainly actually does
# topic: 1
# people israel jews war israeli world history young men jewish
# topic: 2
# game team year play games season win hockey league players
# topic: 3
# ax 145 b8f 3t giz 2tm 7ey 9v sl 75u
# topic: 4
# don think know people like just want way going work
# topic: 5
# good db time years high got like just old ve
# topic: 6
# max g9v a86 pl b8f 1d9 34u 0t wm cx
# topic: 7
# use case make means current don court second thing isn
# topic: 8
# know thanks just don post window read problem like want
# topic: 9
# said did went 17 didn day told got time president
# topic: 10
# evidence does black normal non books read source int claim
# topic: 11
# law government gun control people right public guns police rights
# topic: 12
# car power money health cars room speed cases white gas
# topic: 13
# ve heard seen like going hear science tv event building
# topic: 14
# ...
