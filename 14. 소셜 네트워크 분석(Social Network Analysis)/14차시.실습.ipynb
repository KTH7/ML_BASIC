# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

G=nx.Graph()
G.add_weighted_edges_from([('a','b',10.0),('b','c',1.0),('a','c',100.0),('a','d',10.0)])
nx.draw_networkx(G)
plt.axis('on')
# Out:
# (-0.6313069142521162,
#  0.7013064372790445,
#  -1.0806818095439215,
#  1.1977118461557574)

# %%
#노드별 중개중심성 구하기
nx.betweenness_centrality(G,normalized=True,endpoints=True)
# Out:
# {'a': 0.8333333333333333, 'b': 0.5, 'c': 0.5, 'd': 0.5}

# %%
#노드별 근접중심성 구하기
nx.closeness_centrality(G)
# Out:
# {'a': 1.0, 'b': 0.75, 'c': 0.75, 'd': 0.6}

# %%
#노드별 eigenvector 중심성
nx.eigenvector_centrality(G)
# Out:
# {'a': 0.6116286437343044,
#  'b': 0.5227204550943347,
#  'c': 0.5227204550943347,
#  'd': 0.28184579793865727}

# %%
#노드별 degree
[G.degree(v) for v in G]
# Out:
# [3, 2, 2, 1]

# %%
#가장 큰 컴포넌트
components=nx.connected_components(G)
largest_component=max(components,key=len)
components
# Out:
# <generator object connected_components at 0x0000029D31680890>

# %%
largest_component
# Out:
# {'a', 'b', 'c', 'd'}
